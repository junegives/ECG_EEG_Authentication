# %%
import os
import pickle
import argparse

import hpbandster.core.nameserver as hpns
import hpbandster.core.result as hpres

from hpbandster.optimizers import BOHB

import import_ipynb
from bohb_worker_1to3_8 import KerasWorker as worker

parser = argparse.ArgumentParser(description='bohb_server')
parser.add_argument('--min_budget',   type=float, help='Minimum number of epochs for training.',    default=50)
parser.add_argument('--max_budget',   type=float, help='Maximum number of epochs for training.',    default=200)
parser.add_argument('--n_iterations', type=int,   help='Number of iterations performed by the optimizer', default=100)
parser.add_argument('--worker', help='Flag to turn this into a worker process', action='store_true')
parser.add_argument('--run_id', type=str, help='A unique run id for this optimization run. An easy option is to use the job id of the clusters scheduler.')
parser.add_argument('--nic_name',type=str, help='Which network interface to use for communication.', default='lo')
parser.add_argument('--shared_directory',type=str, help='A directory that is accessible for all processes, e.g. a NFS share.', default='../BOHB_LAB_5CNN/result/8')

args=parser.parse_args(args=[])
    
# Every process has to lookup the hostname
host = hpns.nic_name_to_host(args.nic_name)


if args.worker:
    import time
    time.sleep(5)   # short artificial delay to make sure the nameserver is already running
    w = worker(run_id=args.run_id, host=host, timeout=120)
    w.load_nameserver_credentials(working_directory=args.shared_directory)
    w.run(background=False)
    exit(0)

# This example shows how to log live results. This is most useful
# for really long runs, where intermediate results could already be
# interesting. The core.result submodule contains the functionality to
# read the two generated files (results.json and configs.json) and
# create a Result object.
result_logger = hpres.json_result_logger(directory=args.shared_directory, overwrite=False)

# Start a nameserver:
NS = hpns.NameServer(run_id=args.run_id, host=host, port=0, working_directory=args.shared_directory)
ns_host, ns_port = NS.start()
# NS = hpns.NameServer(run_id=args.run_id, host='127.0.0.1', port=None, working_directory=args.shared_directory)
# ns_host, ns_port = NS.start()

# Start local worker
w = worker(run_id=args.run_id, host=host, nameserver=ns_host, nameserver_port=ns_port, timeout=120)
w.run(background=True)

# Run an optimizer
bohb = BOHB(  configspace = worker.get_configspace(),
                      run_id = args.run_id,
                      host=host,
                      nameserver=ns_host,
                      nameserver_port=ns_port,
                      result_logger=result_logger,
                      min_budget=args.min_budget, max_budget=args.max_budget,
               )
res = bohb.run(n_iterations=args.n_iterations)

# store results
with open(os.path.join(args.shared_directory, 'results.pkl'), 'wb') as fh:
    pickle.dump(res, fh)

# shutdown
bohb.shutdown(shutdown_workers=True)
NS.shutdown()
# Out:
# importing Jupyter notebook from bohb_worker_1to3_8.ipynb
# (11, 504960, 2)
# (11, 101280, 2)
# DEBUG:hpbandster:wait_for_workers trying to get the condition
# INFO:hpbandster:DISPATCHER: started the 'discover_worker' thread
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: Connected to nameserver <Pyro4.core.Proxy at 0x7fa8c8b0ec88; connected IPv4; for PYRO:Pyro.NameServer@127.0.0.1:41685>
# INFO:hpbandster:DISPATCHER: started the 'job_runner' thread
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: No dispatcher found. Waiting for one to initiate contact.
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: start listening for jobs
# INFO:hpbandster:DISPATCHER: Pyro daemon running on 127.0.0.1:41447
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 0 currently in the pool.
# INFO:hpbandster:DISPATCHER: discovered new worker, hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:HBMASTER: number of workers changed to 1
# DEBUG:hpbandster:Enough workers to start this run!
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:adjust_queue_size: lock accquired
# INFO:hpbandster:HBMASTER: starting run at 1628992204.2935514
# INFO:hpbandster:HBMASTER: adjusted queue size to (0, 1)
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 0
# DEBUG:hpbandster:HBMASTER: trying submitting job (0, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (0, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (0, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (0, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (0, 0, 0) on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: start processing job (0, 0, 0)
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: kwargs: {'config': {'dropout_rate': 0.8627275836736681, 'lr': 0.004104413029733756, 'lstm_units': 66, 'num_conv_layers': 3, 'num_fc_layers': 2, 'num_fc_units_1': 33, 'num_filters_1': 242, 'optimizer': 'Adam', 'num_fc_units_2': 24, 'num_filters_2': 32, 'num_filters_3': 205}, 'budget': 66.66666666666666, 'working_directory': '.'}
# (11572, 480, 2)
# (2321, 480, 2)
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: done with job (0, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: registered result for job (0, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 0) on hpbandster.run_None.worker.74c293875977.63453140375501109056 finished
# DEBUG:hpbandster:job_id: (0, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.8627275836736681, 'lr': 0.004104413029733756, 'lstm_units': 66, 'num_conv_layers': 3, 'num_fc_layers': 2, 'num_fc_units_1': 33, 'num_filters_1': 242, 'optimizer': 'Adam', 'num_fc_units_2': 24, 'num_filters_2': 32, 'num_filters_3': 205}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.10171103477478027, 'info': {'test accuracy': 0.8661137223243713, 'train accuracy': 0.964195191860199, 'validation accuracy': 0.8982889652252197, 'number of parameters': 119703}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (0, 0, 0) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (0, 0, 0) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:Only 1 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (0, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 0
# DEBUG:hpbandster:HBMASTER: trying submitting job (0, 0, 1) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (0, 0, 1) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (0, 0, 1)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (0, 0, 1) submitted to dispatcher
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (0, 0, 1) on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 1) dispatched on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: start processing job (0, 0, 1)
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: kwargs: {'config': {'dropout_rate': 0.0113656772402424, 'lr': 0.0016841042110045234, 'lstm_units': 134, 'num_conv_layers': 1, 'num_fc_layers': 3, 'num_fc_units_1': 36, 'num_filters_1': 6, 'optimizer': 'Adam', 'num_fc_units_2': 102, 'num_fc_units_3': 8}, 'budget': 66.66666666666666, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: done with job (0, 0, 1), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: registered result for job (0, 0, 1) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 1) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 1) on hpbandster.run_None.worker.74c293875977.63453140375501109056 finished
# DEBUG:hpbandster:job_id: (0, 0, 1)
# kwargs: {'config': {'dropout_rate': 0.0113656772402424, 'lr': 0.0016841042110045234, 'lstm_units': 134, 'num_conv_layers': 1, 'num_fc_layers': 3, 'num_fc_units_1': 36, 'num_filters_1': 6, 'optimizer': 'Adam', 'num_fc_units_2': 102, 'num_fc_units_3': 8}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.13307982683181763, 'info': {'test accuracy': 0.8139810562133789, 'train accuracy': 0.8963878154754639, 'validation accuracy': 0.8669201731681824, 'number of parameters': 85085}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (0, 0, 1) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (0, 0, 1) got condition
# DEBUG:hpbandster:Only 2 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (0, 0, 1) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 0
# DEBUG:hpbandster:HBMASTER: trying submitting job (0, 0, 2) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (0, 0, 2) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (0, 0, 2)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (0, 0, 2) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (0, 0, 2) on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 2) dispatched on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: start processing job (0, 0, 2)
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: kwargs: {'config': {'dropout_rate': 0.07834074310887267, 'lr': 6.461848111252795e-05, 'lstm_units': 117, 'num_conv_layers': 5, 'num_fc_layers': 1, 'num_fc_units_1': 90, 'num_filters_1': 12, 'optimizer': 'SGD', 'num_filters_2': 26, 'num_filters_3': 10, 'num_filters_4': 10, 'num_filters_5': 7, 'sgd_momentum': 0.7137604234541666}, 'budget': 66.66666666666666, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: done with job (0, 0, 2), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: registered result for job (0, 0, 2) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 2) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 2) on hpbandster.run_None.worker.74c293875977.63453140375501109056 finished
# DEBUG:hpbandster:job_id: (0, 0, 2)
# kwargs: {'config': {'dropout_rate': 0.07834074310887267, 'lr': 6.461848111252795e-05, 'lstm_units': 117, 'num_conv_layers': 5, 'num_fc_layers': 1, 'num_fc_units_1': 90, 'num_filters_1': 12, 'optimizer': 'SGD', 'num_filters_2': 26, 'num_filters_3': 10, 'num_filters_4': 10, 'num_filters_5': 7, 'sgd_momentum': 0.7137604234541666}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.26330798864364624, 'info': {'test accuracy': 0.75, 'train accuracy': 0.7544360160827637, 'validation accuracy': 0.7366920113563538, 'number of parameters': 71574}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (0, 0, 2) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (0, 0, 2) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:Only 3 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (0, 0, 2) finished
# DEBUG:hpbandster:ITERATION: Advancing config (0, 0, 0) to next budget 200.000000
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 0
# DEBUG:hpbandster:HBMASTER: trying submitting job (0, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (0, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (0, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (0, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (0, 0, 0) on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63453140375501109056
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: start processing job (0, 0, 0)
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: kwargs: {'config': {'dropout_rate': 0.8627275836736681, 'lr': 0.004104413029733756, 'lstm_units': 66, 'num_conv_layers': 3, 'num_fc_layers': 2, 'num_fc_units_1': 33, 'num_filters_1': 242, 'optimizer': 'Adam', 'num_fc_units_2': 24, 'num_filters_2': 32, 'num_filters_3': 205}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: done with job (0, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: registered result for job (0, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 0) on hpbandster.run_None.worker.74c293875977.63453140375501109056 finished
# DEBUG:hpbandster:job_id: (0, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.8627275836736681, 'lr': 0.004104413029733756, 'lstm_units': 66, 'num_conv_layers': 3, 'num_fc_layers': 2, 'num_fc_units_1': 33, 'num_filters_1': 242, 'optimizer': 'Adam', 'num_fc_units_2': 24, 'num_filters_2': 32, 'num_filters_3': 205}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.11596959829330444, 'info': {'test accuracy': 0.8590047359466553, 'train accuracy': 0.983523428440094, 'validation accuracy': 0.8840304017066956, 'number of parameters': 119703}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (0, 0, 0) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (0, 0, 0) got condition
# DEBUG:hpbandster:Only 1 run(s) for budget 200.000000 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (0, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 1
# DEBUG:hpbandster:HBMASTER: trying submitting job (1, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (1, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (1, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (1, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (1, 0, 0) on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: start processing job (1, 0, 0)
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: kwargs: {'config': {'dropout_rate': 0.6962899453335142, 'lr': 0.0016398687417877786, 'lstm_units': 104, 'num_conv_layers': 2, 'num_fc_layers': 3, 'num_fc_units_1': 211, 'num_filters_1': 6, 'optimizer': 'Adam', 'num_fc_units_2': 180, 'num_fc_units_3': 38, 'num_filters_2': 25}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: done with job (1, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: registered result for job (1, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 0) on hpbandster.run_None.worker.74c293875977.63453140375501109056 finished
# DEBUG:hpbandster:job_id: (1, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.6962899453335142, 'lr': 0.0016398687417877786, 'lstm_units': 104, 'num_conv_layers': 2, 'num_fc_layers': 3, 'num_fc_units_1': 211, 'num_filters_1': 6, 'optimizer': 'Adam', 'num_fc_units_2': 180, 'num_fc_units_3': 38, 'num_filters_2': 25}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.10361218452453613, 'info': {'test accuracy': 0.8518957495689392, 'train accuracy': 0.980038046836853, 'validation accuracy': 0.8963878154754639, 'number of parameters': 121829}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (1, 0, 0) started
# DEBUG:hpbandster:job_callback for (1, 0, 0) got condition
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:Only 2 run(s) for budget 200.000000 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (1, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 1
# DEBUG:hpbandster:HBMASTER: trying submitting job (1, 0, 1) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (1, 0, 1) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (1, 0, 1)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (1, 0, 1) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (1, 0, 1) on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 1) dispatched on hpbandster.run_None.worker.74c293875977.63453140375501109056
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: start processing job (1, 0, 1)
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: kwargs: {'config': {'dropout_rate': 0.196300561140242, 'lr': 1.9906181944074653e-05, 'lstm_units': 59, 'num_conv_layers': 1, 'num_fc_layers': 2, 'num_fc_units_1': 8, 'num_filters_1': 138, 'optimizer': 'Adam', 'num_fc_units_2': 106}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: done with job (1, 0, 1), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: registered result for job (1, 0, 1) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 1) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 1) on hpbandster.run_None.worker.74c293875977.63453140375501109056 finished
# DEBUG:hpbandster:job_id: (1, 0, 1)
# kwargs: {'config': {'dropout_rate': 0.196300561140242, 'lr': 1.9906181944074653e-05, 'lstm_units': 59, 'num_conv_layers': 1, 'num_fc_layers': 2, 'num_fc_units_1': 8, 'num_filters_1': 138, 'optimizer': 'Adam', 'num_fc_units_2': 106}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.17015206813812256, 'info': {'test accuracy': 0.7973933815956116, 'train accuracy': 0.8494930267333984, 'validation accuracy': 0.8298479318618774, 'number of parameters': 49235}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (1, 0, 1) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (1, 0, 1) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:Only 3 run(s) for budget 200.000000 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (1, 0, 1) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 2
# DEBUG:hpbandster:HBMASTER: trying submitting job (2, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (2, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (2, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (2, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (2, 0, 0) on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: start processing job (2, 0, 0)
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: kwargs: {'config': {'dropout_rate': 0.2134519478365955, 'lr': 0.00011898930583190774, 'lstm_units': 153, 'num_conv_layers': 5, 'num_fc_layers': 1, 'num_fc_units_1': 41, 'num_filters_1': 150, 'optimizer': 'SGD', 'num_filters_2': 4, 'num_filters_3': 21, 'num_filters_4': 125, 'num_filters_5': 110, 'sgd_momentum': 0.2536409280117778}, 'budget': 66.66666666666666, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: done with job (2, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: registered result for job (2, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 0) on hpbandster.run_None.worker.74c293875977.63453140375501109056 finished
# DEBUG:hpbandster:job_id: (2, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.2134519478365955, 'lr': 0.00011898930583190774, 'lstm_units': 153, 'num_conv_layers': 5, 'num_fc_layers': 1, 'num_fc_units_1': 41, 'num_filters_1': 150, 'optimizer': 'SGD', 'num_filters_2': 4, 'num_filters_3': 21, 'num_filters_4': 125, 'num_filters_5': 110, 'sgd_momentum': 0.2536409280117778}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.26330798864364624, 'info': {'test accuracy': 0.75, 'train accuracy': 0.7544360160827637, 'validation accuracy': 0.7366920113563538, 'number of parameters': 220411}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (2, 0, 0) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (2, 0, 0) got condition
# DEBUG:hpbandster:Only 4 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (2, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 2
# DEBUG:hpbandster:HBMASTER: trying submitting job (2, 0, 1) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (2, 0, 1) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (2, 0, 1)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (2, 0, 1) submitted to dispatcher
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (2, 0, 1) on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 1) dispatched on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: start processing job (2, 0, 1)
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: kwargs: {'config': {'dropout_rate': 0.36714698344092567, 'lr': 2.5412324504755688e-05, 'lstm_units': 203, 'num_conv_layers': 4, 'num_fc_layers': 3, 'num_fc_units_1': 14, 'num_filters_1': 5, 'optimizer': 'Adam', 'num_fc_units_2': 170, 'num_fc_units_3': 76, 'num_filters_2': 73, 'num_filters_3': 77, 'num_filters_4': 18}, 'budget': 66.66666666666666, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: done with job (2, 0, 1), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: registered result for job (2, 0, 1) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 1) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 1) on hpbandster.run_None.worker.74c293875977.63453140375501109056 finished
# DEBUG:hpbandster:job_id: (2, 0, 1)
# kwargs: {'config': {'dropout_rate': 0.36714698344092567, 'lr': 2.5412324504755688e-05, 'lstm_units': 203, 'num_conv_layers': 4, 'num_fc_layers': 3, 'num_fc_units_1': 14, 'num_filters_1': 5, 'optimizer': 'Adam', 'num_fc_units_2': 170, 'num_fc_units_3': 76, 'num_filters_2': 73, 'num_filters_3': 77, 'num_filters_4': 18}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.13973385095596313, 'info': {'test accuracy': 0.8601895570755005, 'train accuracy': 0.8786438703536987, 'validation accuracy': 0.8602661490440369, 'number of parameters': 221062}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (2, 0, 1) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (2, 0, 1) got condition
# DEBUG:hpbandster:Only 5 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (2, 0, 1) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 2
# DEBUG:hpbandster:HBMASTER: trying submitting job (2, 0, 2) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (2, 0, 2) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (2, 0, 2)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (2, 0, 2) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (2, 0, 2) on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 2) dispatched on hpbandster.run_None.worker.74c293875977.63453140375501109056
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: start processing job (2, 0, 2)
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: kwargs: {'config': {'dropout_rate': 0.375329117580582, 'lr': 1.1007500694156837e-06, 'lstm_units': 33, 'num_conv_layers': 5, 'num_fc_layers': 2, 'num_fc_units_1': 131, 'num_filters_1': 49, 'optimizer': 'Adam', 'num_fc_units_2': 106, 'num_filters_2': 34, 'num_filters_3': 192, 'num_filters_4': 6, 'num_filters_5': 181}, 'budget': 66.66666666666666, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: done with job (2, 0, 2), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: registered result for job (2, 0, 2) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 2) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 2) on hpbandster.run_None.worker.74c293875977.63453140375501109056 finished
# DEBUG:hpbandster:job_id: (2, 0, 2)
# kwargs: {'config': {'dropout_rate': 0.375329117580582, 'lr': 1.1007500694156837e-06, 'lstm_units': 33, 'num_conv_layers': 5, 'num_fc_layers': 2, 'num_fc_units_1': 131, 'num_filters_1': 49, 'optimizer': 'Adam', 'num_fc_units_2': 106, 'num_filters_2': 34, 'num_filters_3': 192, 'num_filters_4': 6, 'num_filters_5': 181}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.26330798864364624, 'info': {'test accuracy': 0.75, 'train accuracy': 0.7544360160827637, 'validation accuracy': 0.7366920113563538, 'number of parameters': 78985}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (2, 0, 2) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (2, 0, 2) got condition
# DEBUG:hpbandster:Only 6 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (2, 0, 2) finished
# DEBUG:hpbandster:ITERATION: Advancing config (2, 0, 1) to next budget 200.000000
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 2
# DEBUG:hpbandster:HBMASTER: trying submitting job (2, 0, 1) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (2, 0, 1) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (2, 0, 1)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (2, 0, 1) submitted to dispatcher
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (2, 0, 1) on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 1) dispatched on hpbandster.run_None.worker.74c293875977.63453140375501109056
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: start processing job (2, 0, 1)
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: kwargs: {'config': {'dropout_rate': 0.36714698344092567, 'lr': 2.5412324504755688e-05, 'lstm_units': 203, 'num_conv_layers': 4, 'num_fc_layers': 3, 'num_fc_units_1': 14, 'num_filters_1': 5, 'optimizer': 'Adam', 'num_fc_units_2': 170, 'num_fc_units_3': 76, 'num_filters_2': 73, 'num_filters_3': 77, 'num_filters_4': 18}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: done with job (2, 0, 1), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: registered result for job (2, 0, 1) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 1) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 1) on hpbandster.run_None.worker.74c293875977.63453140375501109056 finished
# ...
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: done with job (98, 0, 2), trying to register it.
# DEBUG:hpbandster:DISPATCHER: job (98, 0, 2) finished
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: registered result for job (98, 0, 2) with dispatcher
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (98, 0, 2) on hpbandster.run_None.worker.74c293875977.63453140375501109056 finished
# DEBUG:hpbandster:job_id: (98, 0, 2)
# kwargs: {'config': {'dropout_rate': 0.8354025478741179, 'lr': 8.759823435300635e-06, 'lstm_units': 174, 'num_conv_layers': 1, 'num_fc_layers': 3, 'num_fc_units_1': 233, 'num_filters_1': 21, 'optimizer': 'Adam', 'num_fc_units_2': 107, 'num_fc_units_3': 43}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.26425856351852417, 'info': {'test accuracy': 0.75, 'train accuracy': 0.7525348663330078, 'validation accuracy': 0.7357414364814758, 'number of parameters': 207064}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (98, 0, 2) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (98, 0, 2) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (98, 0, 2) finished
# DEBUG:hpbandster:ITERATION: Advancing config (98, 0, 0) to next budget 200.000000
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 98
# DEBUG:hpbandster:HBMASTER: trying submitting job (98, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (98, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (98, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (98, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (98, 0, 0) on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: job (98, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63453140375501109056
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: start processing job (98, 0, 0)
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: kwargs: {'config': {'dropout_rate': 0.07534398870158358, 'lr': 0.00033026761110051776, 'lstm_units': 44, 'num_conv_layers': 3, 'num_fc_layers': 1, 'num_fc_units_1': 57, 'num_filters_1': 68, 'optimizer': 'Adam', 'num_filters_2': 15, 'num_filters_3': 5}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: done with job (98, 0, 0), trying to register it.
# DEBUG:hpbandster:DISPATCHER: job (98, 0, 0) finished
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: registered result for job (98, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (98, 0, 0) on hpbandster.run_None.worker.74c293875977.63453140375501109056 finished
# DEBUG:hpbandster:job_id: (98, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.07534398870158358, 'lr': 0.00033026761110051776, 'lstm_units': 44, 'num_conv_layers': 3, 'num_fc_layers': 1, 'num_fc_units_1': 57, 'num_filters_1': 68, 'optimizer': 'Adam', 'num_filters_2': 15, 'num_filters_3': 5}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.08365017175674438, 'info': {'test accuracy': 0.8388625383377075, 'train accuracy': 0.963878333568573, 'validation accuracy': 0.9163498282432556, 'number of parameters': 15204}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (98, 0, 0) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (98, 0, 0) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:done building a new model for budget 200.000000 based on 22/125 split
# Best loss for this budget:0.072243
#
#
#
#
#
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (98, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:best_vector: [0.07707125810137966, 0.21069570441476196, 0.5220988502023894, 0.47370354317608154, 0.8187725451242923, 0.8980877728338807, 0.33072217284187727, 0, 0.7739456986982978, 0.2215299676075897, 0.8217722464134555, 0.7771780531535811, 0.927340967887526, 0.5538200007964895, 0.6506094939371568], 0.00038893779579835674, 860.6237129044454, 0.33472908990885275
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 99
# DEBUG:hpbandster:HBMASTER: trying submitting job (99, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (99, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (99, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (99, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (99, 0, 0) on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: start processing job (99, 0, 0)
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: kwargs: {'config': {'dropout_rate': 0.06936413229124169, 'lr': 1.1310414525752472e-05, 'lstm_units': 138, 'num_conv_layers': 3, 'num_fc_layers': 3, 'num_fc_units_1': 179, 'num_filters_1': 14, 'optimizer': 'Adam', 'num_fc_units_2': 115, 'num_fc_units_3': 16, 'num_filters_2': 119, 'num_filters_3': 99}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: done with job (99, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: registered result for job (99, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 0) on hpbandster.run_None.worker.74c293875977.63453140375501109056 finished
# DEBUG:hpbandster:job_id: (99, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.06936413229124169, 'lr': 1.1310414525752472e-05, 'lstm_units': 138, 'num_conv_layers': 3, 'num_fc_layers': 3, 'num_fc_units_1': 179, 'num_filters_1': 14, 'optimizer': 'Adam', 'num_fc_units_2': 115, 'num_fc_units_3': 16, 'num_filters_2': 119, 'num_filters_3': 99}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.0960075855255127, 'info': {'test accuracy': 0.8625592589378357, 'train accuracy': 0.9220532178878784, 'validation accuracy': 0.9039924144744873, 'number of parameters': 219487}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (99, 0, 0) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (99, 0, 0) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:done building a new model for budget 200.000000 based on 22/126 split
# Best loss for this budget:0.072243
#
#
#
#
#
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (99, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:best_vector: [0.3388235561334022, 0.56642668593078, 0.3147641874920847, 0.05673493638832118, 0.21011801489405604, 0.5077989268122608, 0.73481635556424, 0, 0.4323629538261662, 0.43492262368126594, 0.7862498162208349, 0.9848585994543171, 0.10347845091147152, 0.3083762719473423, 0.6517483262904463], 4.426208406673613e-05, 444.87301141048886, 0.01969100663007312
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 99
# DEBUG:hpbandster:HBMASTER: trying submitting job (99, 0, 1) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (99, 0, 1) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (99, 0, 1)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (99, 0, 1) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (99, 0, 1) on hpbandster.run_None.worker.74c293875977.63453140375501109056
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 1) dispatched on hpbandster.run_None.worker.74c293875977.63453140375501109056
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: start processing job (99, 0, 1)
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: kwargs: {'config': {'dropout_rate': 0.304941200520062, 'lr': 0.0006794123385355675, 'lstm_units': 86, 'num_conv_layers': 1, 'num_fc_layers': 1, 'num_fc_units_1': 45, 'num_filters_1': 82, 'optimizer': 'Adam'}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: done with job (99, 0, 1), trying to register it.
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 1) finished
# INFO:hpbandster.run_None.worker.74c293875977.63453:WORKER: registered result for job (99, 0, 1) with dispatcher
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 1) on hpbandster.run_None.worker.74c293875977.63453140375501109056 finished
# DEBUG:hpbandster:job_id: (99, 0, 1)
# kwargs: {'config': {'dropout_rate': 0.304941200520062, 'lr': 0.0006794123385355675, 'lstm_units': 86, 'num_conv_layers': 1, 'num_fc_layers': 1, 'num_fc_units_1': 45, 'num_filters_1': 82, 'optimizer': 'Adam'}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.1178707480430603, 'info': {'test accuracy': 0.8412322402000427, 'train accuracy': 0.9955639839172363, 'validation accuracy': 0.8821292519569397, 'number of parameters': 62671}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (99, 0, 1) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (99, 0, 1) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:done building a new model for budget 200.000000 based on 22/127 split
# Best loss for this budget:0.072243
#
#
#
#
#
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (99, 0, 1) finished
# DEBUG:hpbandster:HBMASTER: shutdown initiated, shutdown_workers = True
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: shutting down now!
# INFO:hpbandster:DISPATCHER: Dispatcher shutting down
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: job_runner shutting down
# DEBUG:hpbandster:DISPATCHER: discover_workers shutting down
# DEBUG:hpbandster:DISPATCHER: 'discover_worker' thread exited
# DEBUG:hpbandster:DISPATCHER: 'job_runner' thread exited
# INFO:hpbandster:DISPATCHER: shut down complete
# DEBUG:hpbandster.run_None.worker.74c293875977.63453:WORKER: shutting down now!

# %%
# Step 5: Analysis
# Each optimizer returns a hpbandster.core.result.Result object.
# It holds informations about the optimization run like the incumbent (=best) configuration.
# For further details about the Result object, see its documentation.
# Here we simply print out the best config and some statistics about the performed runs.
id2config = res.get_id2config_mapping()
incumbent = res.get_incumbent_id()

print('Best found configuration:', id2config[incumbent]['config'])
print('A total of %i unique configurations where sampled.' % len(id2config.keys()))
print('A total of %i runs where executed.' % len(res.get_all_runs()))
print('Total budget corresponds to %.1f full function evaluations.'%(sum([r.budget for r in res.get_all_runs()])/args.max_budget))
# Out:
# Best found configuration: {'dropout_rate': 0.5254390056631926, 'lr': 0.00021455459389909653, 'lstm_units': 166, 'num_conv_layers': 3, 'num_fc_layers': 2, 'num_fc_units_1': 11, 'num_filters_1': 188, 'optimizer': 'Adam', 'num_fc_units_2': 223, 'num_filters_2': 117, 'num_filters_3': 183}
# A total of 250 unique configurations where sampled.
# A total of 300 runs where executed.
# Total budget corresponds to 200.0 full function evaluations.
