# %%
import os
import pickle
import argparse

import hpbandster.core.nameserver as hpns
import hpbandster.core.result as hpres

from hpbandster.optimizers import BOHB

import import_ipynb
from bohb_worker_1to3_4 import KerasWorker as worker

parser = argparse.ArgumentParser(description='bohb_server')
parser.add_argument('--min_budget',   type=float, help='Minimum number of epochs for training.',    default=50)
parser.add_argument('--max_budget',   type=float, help='Maximum number of epochs for training.',    default=200)
parser.add_argument('--n_iterations', type=int,   help='Number of iterations performed by the optimizer', default=100)
parser.add_argument('--worker', help='Flag to turn this into a worker process', action='store_true')
parser.add_argument('--run_id', type=str, help='A unique run id for this optimization run. An easy option is to use the job id of the clusters scheduler.')
parser.add_argument('--nic_name',type=str, help='Which network interface to use for communication.', default='lo')
parser.add_argument('--shared_directory',type=str, help='A directory that is accessible for all processes, e.g. a NFS share.', default='../BOHB_LAB_5CNN/result/4')

args=parser.parse_args(args=[])
    
# Every process has to lookup the hostname
host = hpns.nic_name_to_host(args.nic_name)


if args.worker:
    import time
    time.sleep(5)   # short artificial delay to make sure the nameserver is already running
    w = worker(run_id=args.run_id, host=host, timeout=120)
    w.load_nameserver_credentials(working_directory=args.shared_directory)
    w.run(background=False)
    exit(0)

# This example shows how to log live results. This is most useful
# for really long runs, where intermediate results could already be
# interesting. The core.result submodule contains the functionality to
# read the two generated files (results.json and configs.json) and
# create a Result object.
result_logger = hpres.json_result_logger(directory=args.shared_directory, overwrite=False)

# Start a nameserver:
NS = hpns.NameServer(run_id=args.run_id, host=host, port=0, working_directory=args.shared_directory)
ns_host, ns_port = NS.start()
# NS = hpns.NameServer(run_id=args.run_id, host='127.0.0.1', port=None, working_directory=args.shared_directory)
# ns_host, ns_port = NS.start()

# Start local worker
w = worker(run_id=args.run_id, host=host, nameserver=ns_host, nameserver_port=ns_port, timeout=120)
w.run(background=True)

# Run an optimizer
bohb = BOHB(  configspace = worker.get_configspace(),
                      run_id = args.run_id,
                      host=host,
                      nameserver=ns_host,
                      nameserver_port=ns_port,
                      result_logger=result_logger,
                      min_budget=args.min_budget, max_budget=args.max_budget,
               )
res = bohb.run(n_iterations=args.n_iterations)

# store results
with open(os.path.join(args.shared_directory, 'results.pkl'), 'wb') as fh:
    pickle.dump(res, fh)

# shutdown
bohb.shutdown(shutdown_workers=True)
NS.shutdown()
# Out:
# importing Jupyter notebook from bohb_worker_1to3_4.ipynb
# (11, 504960, 2)
# (11, 101280, 2)
# INFO:hpbandster:DISPATCHER: started the 'discover_worker' thread
# DEBUG:hpbandster:wait_for_workers trying to get the condition
# INFO:hpbandster:DISPATCHER: started the 'job_runner' thread
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: Connected to nameserver <Pyro4.core.Proxy at 0x7fc632335c88; connected IPv4; for PYRO:Pyro.NameServer@127.0.0.1:44419>
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: No dispatcher found. Waiting for one to initiate contact.
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: start listening for jobs
# INFO:hpbandster:DISPATCHER: Pyro daemon running on 127.0.0.1:45381
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 0 currently in the pool.
# INFO:hpbandster:DISPATCHER: discovered new worker, hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:HBMASTER: number of workers changed to 1
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:Enough workers to start this run!
# DEBUG:hpbandster:adjust_queue_size: lock accquired
# INFO:hpbandster:HBMASTER: starting run at 1628992195.8881032
# INFO:hpbandster:HBMASTER: adjusted queue size to (0, 1)
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 0
# DEBUG:hpbandster:HBMASTER: trying submitting job (0, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (0, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (0, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (0, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (0, 0, 0) on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63403140501825271616
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: start processing job (0, 0, 0)
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: args: ()
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: kwargs: {'config': {'dropout_rate': 0.1468337225599328, 'lr': 0.0003247136197205112, 'lstm_units': 37, 'num_conv_layers': 1, 'num_fc_layers': 3, 'num_fc_units_1': 39, 'num_filters_1': 247, 'optimizer': 'Adam', 'num_fc_units_2': 66, 'num_fc_units_3': 30}, 'budget': 66.66666666666666, 'working_directory': '.'}
# (11572, 480, 2)
# (2321, 480, 2)
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: done with job (0, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: registered result for job (0, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 0) on hpbandster.run_None.worker.74c293875977.63403140501825271616 finished
# DEBUG:hpbandster:job_id: (0, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.1468337225599328, 'lr': 0.0003247136197205112, 'lstm_units': 37, 'num_conv_layers': 1, 'num_fc_layers': 3, 'num_fc_units_1': 39, 'num_filters_1': 247, 'optimizer': 'Adam', 'num_fc_units_2': 66, 'num_fc_units_3': 30}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.09980988502502441, 'info': {'test accuracy': 0.9087677597999573, 'train accuracy': 0.9188846349716187, 'validation accuracy': 0.9001901149749756, 'number of parameters': 50072}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (0, 0, 0) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (0, 0, 0) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:Only 1 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (0, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 0
# DEBUG:hpbandster:HBMASTER: trying submitting job (0, 0, 1) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (0, 0, 1) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (0, 0, 1)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (0, 0, 1) submitted to dispatcher
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (0, 0, 1) on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 1) dispatched on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: start processing job (0, 0, 1)
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: kwargs: {'config': {'dropout_rate': 0.6710192668517061, 'lr': 0.00011457395778734591, 'lstm_units': 232, 'num_conv_layers': 3, 'num_fc_layers': 2, 'num_fc_units_1': 20, 'num_filters_1': 139, 'optimizer': 'Adam', 'num_fc_units_2': 21, 'num_filters_2': 7, 'num_filters_3': 27}, 'budget': 66.66666666666666, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: done with job (0, 0, 1), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: registered result for job (0, 0, 1) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 1) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 1) on hpbandster.run_None.worker.74c293875977.63403140501825271616 finished
# DEBUG:hpbandster:job_id: (0, 0, 1)
# kwargs: {'config': {'dropout_rate': 0.6710192668517061, 'lr': 0.00011457395778734591, 'lstm_units': 232, 'num_conv_layers': 3, 'num_fc_layers': 2, 'num_fc_units_1': 20, 'num_filters_1': 139, 'optimizer': 'Adam', 'num_fc_units_2': 21, 'num_filters_2': 7, 'num_filters_3': 27}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.09125477075576782, 'info': {'test accuracy': 0.9277251362800598, 'train accuracy': 0.9363117814064026, 'validation accuracy': 0.9087452292442322, 'number of parameters': 250896}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (0, 0, 1) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (0, 0, 1) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:Only 2 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (0, 0, 1) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 0
# DEBUG:hpbandster:HBMASTER: trying submitting job (0, 0, 2) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (0, 0, 2) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (0, 0, 2)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (0, 0, 2) submitted to dispatcher
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (0, 0, 2) on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 2) dispatched on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: start processing job (0, 0, 2)
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: kwargs: {'config': {'dropout_rate': 0.4398586741932919, 'lr': 1.705002360808457e-05, 'lstm_units': 249, 'num_conv_layers': 4, 'num_fc_layers': 1, 'num_fc_units_1': 140, 'num_filters_1': 4, 'optimizer': 'Adam', 'num_filters_2': 135, 'num_filters_3': 4, 'num_filters_4': 10}, 'budget': 66.66666666666666, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: done with job (0, 0, 2), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: registered result for job (0, 0, 2) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 2) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 2) on hpbandster.run_None.worker.74c293875977.63403140501825271616 finished
# DEBUG:hpbandster:job_id: (0, 0, 2)
# kwargs: {'config': {'dropout_rate': 0.4398586741932919, 'lr': 1.705002360808457e-05, 'lstm_units': 249, 'num_conv_layers': 4, 'num_fc_layers': 1, 'num_fc_units_1': 140, 'num_filters_1': 4, 'optimizer': 'Adam', 'num_filters_2': 135, 'num_filters_3': 4, 'num_filters_4': 10}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.15874522924423218, 'info': {'test accuracy': 0.8767772316932678, 'train accuracy': 0.8396704792976379, 'validation accuracy': 0.8412547707557678, 'number of parameters': 297638}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (0, 0, 2) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (0, 0, 2) got condition
# DEBUG:hpbandster:Only 3 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (0, 0, 2) finished
# DEBUG:hpbandster:ITERATION: Advancing config (0, 0, 1) to next budget 200.000000
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 0
# DEBUG:hpbandster:HBMASTER: trying submitting job (0, 0, 1) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (0, 0, 1) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (0, 0, 1)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (0, 0, 1) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (0, 0, 1) on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 1) dispatched on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: start processing job (0, 0, 1)
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: kwargs: {'config': {'dropout_rate': 0.6710192668517061, 'lr': 0.00011457395778734591, 'lstm_units': 232, 'num_conv_layers': 3, 'num_fc_layers': 2, 'num_fc_units_1': 20, 'num_filters_1': 139, 'optimizer': 'Adam', 'num_fc_units_2': 21, 'num_filters_2': 7, 'num_filters_3': 27}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: done with job (0, 0, 1), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: registered result for job (0, 0, 1) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 1) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 1) on hpbandster.run_None.worker.74c293875977.63403140501825271616 finished
# DEBUG:hpbandster:job_id: (0, 0, 1)
# kwargs: {'config': {'dropout_rate': 0.6710192668517061, 'lr': 0.00011457395778734591, 'lstm_units': 232, 'num_conv_layers': 3, 'num_fc_layers': 2, 'num_fc_units_1': 20, 'num_filters_1': 139, 'optimizer': 'Adam', 'num_fc_units_2': 21, 'num_filters_2': 7, 'num_filters_3': 27}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.07604563236236572, 'info': {'test accuracy': 0.9395734667778015, 'train accuracy': 0.9607097506523132, 'validation accuracy': 0.9239543676376343, 'number of parameters': 250896}}
# exception: None
# DEBUG:hpbandster:job_callback for (0, 0, 1) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (0, 0, 1) got condition
# DEBUG:hpbandster:Only 1 run(s) for budget 200.000000 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (0, 0, 1) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 1
# DEBUG:hpbandster:HBMASTER: trying submitting job (1, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (1, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (1, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (1, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (1, 0, 0) on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63403140501825271616
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: start processing job (1, 0, 0)
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: kwargs: {'config': {'dropout_rate': 0.22147858870100906, 'lr': 0.01665328009108491, 'lstm_units': 130, 'num_conv_layers': 3, 'num_fc_layers': 1, 'num_fc_units_1': 81, 'num_filters_1': 154, 'optimizer': 'SGD', 'num_filters_2': 157, 'num_filters_3': 11, 'sgd_momentum': 0.7014797306275332}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: done with job (1, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: registered result for job (1, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 0) on hpbandster.run_None.worker.74c293875977.63403140501825271616 finished
# DEBUG:hpbandster:job_id: (1, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.22147858870100906, 'lr': 0.01665328009108491, 'lstm_units': 130, 'num_conv_layers': 3, 'num_fc_layers': 1, 'num_fc_units_1': 81, 'num_filters_1': 154, 'optimizer': 'SGD', 'num_filters_2': 157, 'num_filters_3': 11, 'sgd_momentum': 0.7014797306275332}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.057984769344329834, 'info': {'test accuracy': 0.9620853066444397, 'train accuracy': 1.0, 'validation accuracy': 0.9420152306556702, 'number of parameters': 163494}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (1, 0, 0) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (1, 0, 0) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:Only 2 run(s) for budget 200.000000 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (1, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 1
# DEBUG:hpbandster:HBMASTER: trying submitting job (1, 0, 1) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (1, 0, 1) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (1, 0, 1)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (1, 0, 1) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (1, 0, 1) on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 1) dispatched on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: start processing job (1, 0, 1)
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: kwargs: {'config': {'dropout_rate': 0.17974515890458498, 'lr': 9.596850138214157e-06, 'lstm_units': 87, 'num_conv_layers': 3, 'num_fc_layers': 1, 'num_fc_units_1': 99, 'num_filters_1': 102, 'optimizer': 'SGD', 'num_filters_2': 43, 'num_filters_3': 233, 'sgd_momentum': 0.15019511660243065}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: done with job (1, 0, 1), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: registered result for job (1, 0, 1) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 1) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 1) on hpbandster.run_None.worker.74c293875977.63403140501825271616 finished
# DEBUG:hpbandster:job_id: (1, 0, 1)
# kwargs: {'config': {'dropout_rate': 0.17974515890458498, 'lr': 9.596850138214157e-06, 'lstm_units': 87, 'num_conv_layers': 3, 'num_fc_layers': 1, 'num_fc_units_1': 99, 'num_filters_1': 102, 'optimizer': 'SGD', 'num_filters_2': 43, 'num_filters_3': 233, 'sgd_momentum': 0.15019511660243065}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.26330798864364624, 'info': {'test accuracy': 0.75, 'train accuracy': 0.7544360160827637, 'validation accuracy': 0.7366920113563538, 'number of parameters': 164725}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (1, 0, 1) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (1, 0, 1) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:Only 3 run(s) for budget 200.000000 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (1, 0, 1) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 2
# DEBUG:hpbandster:HBMASTER: trying submitting job (2, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (2, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (2, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (2, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (2, 0, 0) on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: start processing job (2, 0, 0)
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: kwargs: {'config': {'dropout_rate': 0.18917008940315827, 'lr': 0.003454493456149795, 'lstm_units': 19, 'num_conv_layers': 5, 'num_fc_layers': 2, 'num_fc_units_1': 98, 'num_filters_1': 70, 'optimizer': 'Adam', 'num_fc_units_2': 98, 'num_filters_2': 62, 'num_filters_3': 17, 'num_filters_4': 4, 'num_filters_5': 243}, 'budget': 66.66666666666666, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: done with job (2, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: registered result for job (2, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 0) on hpbandster.run_None.worker.74c293875977.63403140501825271616 finished
# DEBUG:hpbandster:job_id: (2, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.18917008940315827, 'lr': 0.003454493456149795, 'lstm_units': 19, 'num_conv_layers': 5, 'num_fc_layers': 2, 'num_fc_units_1': 98, 'num_filters_1': 70, 'optimizer': 'Adam', 'num_fc_units_2': 98, 'num_filters_2': 62, 'num_filters_3': 17, 'num_filters_4': 4, 'num_filters_5': 243}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.11501902341842651, 'info': {'test accuracy': 0.8969194293022156, 'train accuracy': 0.9930291771888733, 'validation accuracy': 0.8849809765815735, 'number of parameters': 51867}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (2, 0, 0) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (2, 0, 0) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:Only 4 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (2, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 2
# DEBUG:hpbandster:HBMASTER: trying submitting job (2, 0, 1) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (2, 0, 1) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (2, 0, 1)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (2, 0, 1) submitted to dispatcher
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (2, 0, 1) on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 1) dispatched on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: start processing job (2, 0, 1)
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: kwargs: {'config': {'dropout_rate': 0.5409742242544298, 'lr': 6.338066924556011e-06, 'lstm_units': 35, 'num_conv_layers': 4, 'num_fc_layers': 3, 'num_fc_units_1': 90, 'num_filters_1': 28, 'optimizer': 'Adam', 'num_fc_units_2': 20, 'num_fc_units_3': 162, 'num_filters_2': 70, 'num_filters_3': 18, 'num_filters_4': 6}, 'budget': 66.66666666666666, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: done with job (2, 0, 1), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: registered result for job (2, 0, 1) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 1) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 1) on hpbandster.run_None.worker.74c293875977.63403140501825271616 finished
# DEBUG:hpbandster:job_id: (2, 0, 1)
# kwargs: {'config': {'dropout_rate': 0.5409742242544298, 'lr': 6.338066924556011e-06, 'lstm_units': 35, 'num_conv_layers': 4, 'num_fc_layers': 3, 'num_fc_units_1': 90, 'num_filters_1': 28, 'optimizer': 'Adam', 'num_fc_units_2': 20, 'num_fc_units_3': 162, 'num_filters_2': 70, 'num_filters_3': 18, 'num_filters_4': 6}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.26330798864364624, 'info': {'test accuracy': 0.75, 'train accuracy': 0.7544360160827637, 'validation accuracy': 0.7366920113563538, 'number of parameters': 24779}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (2, 0, 1) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (2, 0, 1) got condition
# DEBUG:hpbandster:Only 5 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (2, 0, 1) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 2
# DEBUG:hpbandster:HBMASTER: trying submitting job (2, 0, 2) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (2, 0, 2) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (2, 0, 2)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (2, 0, 2) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (2, 0, 2) on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 2) dispatched on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: start processing job (2, 0, 2)
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: kwargs: {'config': {'dropout_rate': 0.24557585418849873, 'lr': 1.434391294582442e-05, 'lstm_units': 38, 'num_conv_layers': 5, 'num_fc_layers': 1, 'num_fc_units_1': 62, 'num_filters_1': 47, 'optimizer': 'Adam', 'num_filters_2': 8, 'num_filters_3': 8, 'num_filters_4': 16, 'num_filters_5': 45}, 'budget': 66.66666666666666, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: done with job (2, 0, 2), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: registered result for job (2, 0, 2) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 2) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 2) on hpbandster.run_None.worker.74c293875977.63403140501825271616 finished
# DEBUG:hpbandster:job_id: (2, 0, 2)
# kwargs: {'config': {'dropout_rate': 0.24557585418849873, 'lr': 1.434391294582442e-05, 'lstm_units': 38, 'num_conv_layers': 5, 'num_fc_layers': 1, 'num_fc_units_1': 62, 'num_filters_1': 47, 'optimizer': 'Adam', 'num_filters_2': 8, 'num_filters_3': 8, 'num_filters_4': 16, 'num_filters_5': 45}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.26330798864364624, 'info': {'test accuracy': 0.75, 'train accuracy': 0.7544360160827637, 'validation accuracy': 0.7366920113563538, 'number of parameters': 19519}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (2, 0, 2) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (2, 0, 2) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:Only 6 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (2, 0, 2) finished
# DEBUG:hpbandster:ITERATION: Advancing config (2, 0, 0) to next budget 200.000000
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 2
# DEBUG:hpbandster:HBMASTER: trying submitting job (2, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (2, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (2, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (2, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (2, 0, 0) on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: start processing job (2, 0, 0)
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: kwargs: {'config': {'dropout_rate': 0.18917008940315827, 'lr': 0.003454493456149795, 'lstm_units': 19, 'num_conv_layers': 5, 'num_fc_layers': 2, 'num_fc_units_1': 98, 'num_filters_1': 70, 'optimizer': 'Adam', 'num_fc_units_2': 98, 'num_filters_2': 62, 'num_filters_3': 17, 'num_filters_4': 4, 'num_filters_5': 243}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: done with job (2, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: registered result for job (2, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 0) on hpbandster.run_None.worker.74c293875977.63403140501825271616 finished
# DEBUG:hpbandster:job_id: (2, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.18917008940315827, 'lr': 0.003454493456149795, 'lstm_units': 19, 'num_conv_layers': 5, 'num_fc_layers': 2, 'num_fc_units_1': 98, 'num_filters_1': 70, 'optimizer': 'Adam', 'num_fc_units_2': 98, 'num_filters_2': 62, 'num_filters_3': 17, 'num_filters_4': 4, 'num_filters_5': 243}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.10741442441940308, 'info': {'test accuracy': 0.9087677597999573, 'train accuracy': 0.9980988502502441, 'validation accuracy': 0.8925855755805969, 'number of parameters': 51867}}
# exception: None
# DEBUG:hpbandster:job_callback for (2, 0, 0) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (2, 0, 0) got condition
# DEBUG:hpbandster:Only 4 run(s) for budget 200.000000 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (2, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 3
# DEBUG:hpbandster:HBMASTER: trying submitting job (3, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (3, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (3, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (3, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (3, 0, 0) on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: job (3, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63403140501825271616
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: start processing job (3, 0, 0)
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: kwargs: {'config': {'dropout_rate': 0.13209872340915776, 'lr': 0.0004136017777560947, 'lstm_units': 18, 'num_conv_layers': 5, 'num_fc_layers': 3, 'num_fc_units_1': 169, 'num_filters_1': 194, 'optimizer': 'SGD', 'num_fc_units_2': 17, 'num_fc_units_3': 69, 'num_filters_2': 9, 'num_filters_3': 9, 'num_filters_4': 168, 'num_filters_5': 9, 'sgd_momentum': 0.16316651439235746}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# ...
# DEBUG:hpbandster:DISPATCHER: trying to submit job (98, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (98, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (98, 0, 0) on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: job (98, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: start processing job (98, 0, 0)
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: kwargs: {'config': {'dropout_rate': 0.5325520441200738, 'lr': 0.0003972970259679344, 'lstm_units': 239, 'num_conv_layers': 2, 'num_fc_layers': 3, 'num_fc_units_1': 39, 'num_filters_1': 103, 'optimizer': 'Adam', 'num_fc_units_2': 19, 'num_fc_units_3': 74, 'num_filters_2': 180}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: done with job (98, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: registered result for job (98, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (98, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (98, 0, 0) on hpbandster.run_None.worker.74c293875977.63403140501825271616 finished
# DEBUG:hpbandster:job_id: (98, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.5325520441200738, 'lr': 0.0003972970259679344, 'lstm_units': 239, 'num_conv_layers': 2, 'num_fc_layers': 3, 'num_fc_units_1': 39, 'num_filters_1': 103, 'optimizer': 'Adam', 'num_fc_units_2': 19, 'num_fc_units_3': 74, 'num_filters_2': 180}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.06558936834335327, 'info': {'test accuracy': 0.9443128108978271, 'train accuracy': 1.0, 'validation accuracy': 0.9344106316566467, 'number of parameters': 469716}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (98, 0, 0) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (98, 0, 0) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:done building a new model for budget 200.000000 based on 22/125 split
# Best loss for this budget:0.055133
#
#
#
#
#
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (98, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:best_vector: [0.10858177193016008, 0.8242117145792823, 0.8263263673560559, 0.517411881605741, 0.20665339369088231, 0.7179761116600004, 0.4615636386078862, 1, 0.24519830908397322, 0.8310894658838488, 0.5325015667597969, 0.21402173683912634, 0.005204461636444446, 0.6359885836888196, 0.8770477992171316], 0.00012891183196741, 28.95568002775523, 0.003732729758240072
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 99
# DEBUG:hpbandster:HBMASTER: trying submitting job (99, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (99, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (99, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (99, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (99, 0, 0) on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63403140501825271616
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: start processing job (99, 0, 0)
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: kwargs: {'config': {'dropout_rate': 0.09772359473714408, 'lr': 0.013214738481282028, 'lstm_units': 213, 'num_conv_layers': 3, 'num_fc_layers': 1, 'num_fc_units_1': 95, 'num_filters_1': 25, 'optimizer': 'SGD', 'num_filters_2': 34, 'num_filters_3': 9, 'sgd_momentum': 0.8682773212249603}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: done with job (99, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: registered result for job (99, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 0) on hpbandster.run_None.worker.74c293875977.63403140501825271616 finished
# DEBUG:hpbandster:job_id: (99, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.09772359473714408, 'lr': 0.013214738481282028, 'lstm_units': 213, 'num_conv_layers': 3, 'num_fc_layers': 1, 'num_fc_units_1': 95, 'num_filters_1': 25, 'optimizer': 'SGD', 'num_filters_2': 34, 'num_filters_3': 9, 'sgd_momentum': 0.8682773212249603}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.07604563236236572, 'info': {'test accuracy': 0.9395734667778015, 'train accuracy': 0.999683141708374, 'validation accuracy': 0.9239543676376343, 'number of parameters': 214108}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (99, 0, 0) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (99, 0, 0) got condition
# DEBUG:hpbandster:done building a new model for budget 200.000000 based on 22/126 split
# Best loss for this budget:0.055133
#
#
#
#
#
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (99, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:best_vector: [0.5255491393268814, 0.38534835484751173, 0.2529486966265737, 0.562029224360781, 0.12818643446360078, 0.9813974199944567, 0.6011664303275419, 0, 0.7678407501169038, 0.14914448669011138, 0.6665232073791469, 0.06020016738036427, 0.8911225380953455, 0.6990344983087978, 0.9003222025696498], 0.0012011205432662252, 1.2301465397040308, 0.0014775542800663725
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 99
# DEBUG:hpbandster:HBMASTER: trying submitting job (99, 0, 1) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (99, 0, 1) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (99, 0, 1)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (99, 0, 1) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (99, 0, 1) on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 1) dispatched on hpbandster.run_None.worker.74c293875977.63403140501825271616
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: start processing job (99, 0, 1)
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: kwargs: {'config': {'dropout_rate': 0.4729942253941933, 'lr': 8.447764029116214e-05, 'lstm_units': 70, 'num_conv_layers': 3, 'num_fc_layers': 1, 'num_fc_units_1': 240, 'num_filters_1': 46, 'optimizer': 'Adam', 'num_filters_2': 61, 'num_filters_3': 5}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: done with job (99, 0, 1), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63403:WORKER: registered result for job (99, 0, 1) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 1) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 1) on hpbandster.run_None.worker.74c293875977.63403140501825271616 finished
# DEBUG:hpbandster:job_id: (99, 0, 1)
# kwargs: {'config': {'dropout_rate': 0.4729942253941933, 'lr': 8.447764029116214e-05, 'lstm_units': 70, 'num_conv_layers': 3, 'num_fc_layers': 1, 'num_fc_units_1': 240, 'num_filters_1': 46, 'optimizer': 'Adam', 'num_filters_2': 61, 'num_filters_3': 5}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.06749051809310913, 'info': {'test accuracy': 0.9372037649154663, 'train accuracy': 0.9664131999015808, 'validation accuracy': 0.9325094819068909, 'number of parameters': 48282}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (99, 0, 1) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (99, 0, 1) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:done building a new model for budget 200.000000 based on 22/127 split
# Best loss for this budget:0.055133
#
#
#
#
#
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (99, 0, 1) finished
# DEBUG:hpbandster:HBMASTER: shutdown initiated, shutdown_workers = True
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: shutting down now!
# INFO:hpbandster:DISPATCHER: Dispatcher shutting down
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: job_runner shutting down
# DEBUG:hpbandster:DISPATCHER: discover_workers shutting down
# DEBUG:hpbandster:DISPATCHER: 'discover_worker' thread exited
# DEBUG:hpbandster:DISPATCHER: 'job_runner' thread exited
# INFO:hpbandster:DISPATCHER: shut down complete
# DEBUG:hpbandster.run_None.worker.74c293875977.63403:WORKER: shutting down now!

# %%
# Step 5: Analysis
# Each optimizer returns a hpbandster.core.result.Result object.
# It holds informations about the optimization run like the incumbent (=best) configuration.
# For further details about the Result object, see its documentation.
# Here we simply print out the best config and some statistics about the performed runs.
id2config = res.get_id2config_mapping()
incumbent = res.get_incumbent_id()

print('Best found configuration:', id2config[incumbent]['config'])
print('A total of %i unique configurations where sampled.' % len(id2config.keys()))
print('A total of %i runs where executed.' % len(res.get_all_runs()))
print('Total budget corresponds to %.1f full function evaluations.'%(sum([r.budget for r in res.get_all_runs()])/args.max_budget))
# Out:
# Best found configuration: {'dropout_rate': 0.6835712527260434, 'lr': 0.001646253038527969, 'lstm_units': 19, 'num_conv_layers': 2, 'num_fc_layers': 1, 'num_fc_units_1': 162, 'num_filters_1': 53, 'optimizer': 'Adam', 'num_filters_2': 68}
# A total of 250 unique configurations where sampled.
# A total of 300 runs where executed.
# Total budget corresponds to 200.0 full function evaluations.
