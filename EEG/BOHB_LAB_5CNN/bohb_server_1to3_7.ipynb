# %%
import os
import pickle
import argparse

import hpbandster.core.nameserver as hpns
import hpbandster.core.result as hpres

from hpbandster.optimizers import BOHB

import import_ipynb
from bohb_worker_1to3_7 import KerasWorker as worker

parser = argparse.ArgumentParser(description='bohb_server')
parser.add_argument('--min_budget',   type=float, help='Minimum number of epochs for training.',    default=50)
parser.add_argument('--max_budget',   type=float, help='Maximum number of epochs for training.',    default=200)
parser.add_argument('--n_iterations', type=int,   help='Number of iterations performed by the optimizer', default=100)
parser.add_argument('--worker', help='Flag to turn this into a worker process', action='store_true')
parser.add_argument('--run_id', type=str, help='A unique run id for this optimization run. An easy option is to use the job id of the clusters scheduler.')
parser.add_argument('--nic_name',type=str, help='Which network interface to use for communication.', default='lo')
parser.add_argument('--shared_directory',type=str, help='A directory that is accessible for all processes, e.g. a NFS share.', default='../BOHB_LAB_5CNN/result/7')

args=parser.parse_args(args=[])
    
# Every process has to lookup the hostname
host = hpns.nic_name_to_host(args.nic_name)


if args.worker:
    import time
    time.sleep(5)   # short artificial delay to make sure the nameserver is already running
    w = worker(run_id=args.run_id, host=host, timeout=120)
    w.load_nameserver_credentials(working_directory=args.shared_directory)
    w.run(background=False)
    exit(0)

# This example shows how to log live results. This is most useful
# for really long runs, where intermediate results could already be
# interesting. The core.result submodule contains the functionality to
# read the two generated files (results.json and configs.json) and
# create a Result object.
result_logger = hpres.json_result_logger(directory=args.shared_directory, overwrite=False)

# Start a nameserver:
NS = hpns.NameServer(run_id=args.run_id, host=host, port=0, working_directory=args.shared_directory)
ns_host, ns_port = NS.start()
# NS = hpns.NameServer(run_id=args.run_id, host='127.0.0.1', port=None, working_directory=args.shared_directory)
# ns_host, ns_port = NS.start()

# Start local worker
w = worker(run_id=args.run_id, host=host, nameserver=ns_host, nameserver_port=ns_port, timeout=120)
w.run(background=True)

# Run an optimizer
bohb = BOHB(  configspace = worker.get_configspace(),
                      run_id = args.run_id,
                      host=host,
                      nameserver=ns_host,
                      nameserver_port=ns_port,
                      result_logger=result_logger,
                      min_budget=args.min_budget, max_budget=args.max_budget,
               )
res = bohb.run(n_iterations=args.n_iterations)

# store results
with open(os.path.join(args.shared_directory, 'results.pkl'), 'wb') as fh:
    pickle.dump(res, fh)

# shutdown
bohb.shutdown(shutdown_workers=True)
NS.shutdown()
# Out:
# importing Jupyter notebook from bohb_worker_1to3_7.ipynb
# (11, 504960, 2)
# (11, 101280, 2)
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: Connected to nameserver <Pyro4.core.Proxy at 0x7fdb98659c88; connected IPv4; for PYRO:Pyro.NameServer@127.0.0.1:33837>
# DEBUG:hpbandster:wait_for_workers trying to get the condition
# INFO:hpbandster:DISPATCHER: started the 'discover_worker' thread
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: No dispatcher found. Waiting for one to initiate contact.
# INFO:hpbandster:DISPATCHER: started the 'job_runner' thread
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: start listening for jobs
# INFO:hpbandster:DISPATCHER: Pyro daemon running on 127.0.0.1:40505
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 0 currently in the pool.
# INFO:hpbandster:DISPATCHER: discovered new worker, hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:HBMASTER: number of workers changed to 1
# DEBUG:hpbandster:Enough workers to start this run!
# DEBUG:hpbandster:adjust_queue_size: lock accquired
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# INFO:hpbandster:HBMASTER: starting run at 1628992202.2846298
# INFO:hpbandster:HBMASTER: adjusted queue size to (0, 1)
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 0
# DEBUG:hpbandster:HBMASTER: trying submitting job (0, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (0, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: trying to submit job (0, 0, 0)
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (0, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (0, 0, 0) on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: start processing job (0, 0, 0)
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: kwargs: {'config': {'dropout_rate': 0.6512486686936398, 'lr': 0.015162501202588777, 'lstm_units': 71, 'num_conv_layers': 2, 'num_fc_layers': 3, 'num_fc_units_1': 30, 'num_filters_1': 215, 'optimizer': 'SGD', 'num_fc_units_2': 16, 'num_fc_units_3': 26, 'num_filters_2': 14, 'sgd_momentum': 0.3875715660828014}, 'budget': 66.66666666666666, 'working_directory': '.'}
# (11572, 480, 2)
# (2321, 480, 2)
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: done with job (0, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: registered result for job (0, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 0) on hpbandster.run_None.worker.74c293875977.63436140593734223680 finished
# DEBUG:hpbandster:job_id: (0, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.6512486686936398, 'lr': 0.015162501202588777, 'lstm_units': 71, 'num_conv_layers': 2, 'num_fc_layers': 3, 'num_fc_units_1': 30, 'num_filters_1': 215, 'optimizer': 'SGD', 'num_fc_units_2': 16, 'num_fc_units_3': 26, 'num_filters_2': 14, 'sgd_momentum': 0.3875715660828014}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.2376425862312317, 'info': {'test accuracy': 0.758293867111206, 'train accuracy': 0.7788339853286743, 'validation accuracy': 0.7623574137687683, 'number of parameters': 38098}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (0, 0, 0) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (0, 0, 0) got condition
# DEBUG:hpbandster:Only 1 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (0, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 0
# DEBUG:hpbandster:HBMASTER: trying submitting job (0, 0, 1) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (0, 0, 1) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (0, 0, 1)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (0, 0, 1) submitted to dispatcher
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (0, 0, 1) on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 1) dispatched on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: start processing job (0, 0, 1)
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: kwargs: {'config': {'dropout_rate': 0.4716707082983828, 'lr': 1.4245400623252361e-05, 'lstm_units': 181, 'num_conv_layers': 3, 'num_fc_layers': 1, 'num_fc_units_1': 169, 'num_filters_1': 4, 'optimizer': 'SGD', 'num_filters_2': 6, 'num_filters_3': 148, 'sgd_momentum': 0.25205706455916066}, 'budget': 66.66666666666666, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: done with job (0, 0, 1), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: registered result for job (0, 0, 1) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 1) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 1) on hpbandster.run_None.worker.74c293875977.63436140593734223680 finished
# DEBUG:hpbandster:job_id: (0, 0, 1)
# kwargs: {'config': {'dropout_rate': 0.4716707082983828, 'lr': 1.4245400623252361e-05, 'lstm_units': 181, 'num_conv_layers': 3, 'num_fc_layers': 1, 'num_fc_units_1': 169, 'num_filters_1': 4, 'optimizer': 'SGD', 'num_filters_2': 6, 'num_filters_3': 148, 'sgd_momentum': 0.25205706455916066}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.26330798864364624, 'info': {'test accuracy': 0.75, 'train accuracy': 0.7544360160827637, 'validation accuracy': 0.7366920113563538, 'number of parameters': 272766}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (0, 0, 1) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (0, 0, 1) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:Only 2 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (0, 0, 1) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 0
# DEBUG:hpbandster:HBMASTER: trying submitting job (0, 0, 2) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (0, 0, 2) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (0, 0, 2)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (0, 0, 2) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (0, 0, 2) on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 2) dispatched on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: start processing job (0, 0, 2)
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: kwargs: {'config': {'dropout_rate': 0.09064850471519058, 'lr': 0.002344424440426849, 'lstm_units': 23, 'num_conv_layers': 1, 'num_fc_layers': 2, 'num_fc_units_1': 28, 'num_filters_1': 16, 'optimizer': 'SGD', 'num_fc_units_2': 35, 'sgd_momentum': 0.9064329460771788}, 'budget': 66.66666666666666, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: done with job (0, 0, 2), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: registered result for job (0, 0, 2) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 2) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 2) on hpbandster.run_None.worker.74c293875977.63436140593734223680 finished
# DEBUG:hpbandster:job_id: (0, 0, 2)
# kwargs: {'config': {'dropout_rate': 0.09064850471519058, 'lr': 0.002344424440426849, 'lstm_units': 23, 'num_conv_layers': 1, 'num_fc_layers': 2, 'num_fc_units_1': 28, 'num_filters_1': 16, 'optimizer': 'SGD', 'num_fc_units_2': 35, 'sgd_momentum': 0.9064329460771788}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.25760453939437866, 'info': {'test accuracy': 0.6872037649154663, 'train accuracy': 0.7652091383934021, 'validation accuracy': 0.7423954606056213, 'number of parameters': 5515}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (0, 0, 2) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (0, 0, 2) got condition
# DEBUG:hpbandster:Only 3 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (0, 0, 2) finished
# DEBUG:hpbandster:ITERATION: Advancing config (0, 0, 0) to next budget 200.000000
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 0
# DEBUG:hpbandster:HBMASTER: trying submitting job (0, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (0, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (0, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (0, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (0, 0, 0) on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: start processing job (0, 0, 0)
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: kwargs: {'config': {'dropout_rate': 0.6512486686936398, 'lr': 0.015162501202588777, 'lstm_units': 71, 'num_conv_layers': 2, 'num_fc_layers': 3, 'num_fc_units_1': 30, 'num_filters_1': 215, 'optimizer': 'SGD', 'num_fc_units_2': 16, 'num_fc_units_3': 26, 'num_filters_2': 14, 'sgd_momentum': 0.3875715660828014}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: done with job (0, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: registered result for job (0, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (0, 0, 0) on hpbandster.run_None.worker.74c293875977.63436140593734223680 finished
# DEBUG:hpbandster:job_id: (0, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.6512486686936398, 'lr': 0.015162501202588777, 'lstm_units': 71, 'num_conv_layers': 2, 'num_fc_layers': 3, 'num_fc_units_1': 30, 'num_filters_1': 215, 'optimizer': 'SGD', 'num_fc_units_2': 16, 'num_fc_units_3': 26, 'num_filters_2': 14, 'sgd_momentum': 0.3875715660828014}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.22528517246246338, 'info': {'test accuracy': 0.7748815417289734, 'train accuracy': 0.7908745408058167, 'validation accuracy': 0.7747148275375366, 'number of parameters': 38098}}
# exception: None
# DEBUG:hpbandster:job_callback for (0, 0, 0) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (0, 0, 0) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:Only 1 run(s) for budget 200.000000 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (0, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 1
# DEBUG:hpbandster:HBMASTER: trying submitting job (1, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (1, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (1, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (1, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (1, 0, 0) on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: start processing job (1, 0, 0)
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: kwargs: {'config': {'dropout_rate': 0.06330305434316162, 'lr': 0.09294871404957533, 'lstm_units': 173, 'num_conv_layers': 3, 'num_fc_layers': 3, 'num_fc_units_1': 47, 'num_filters_1': 12, 'optimizer': 'SGD', 'num_fc_units_2': 140, 'num_fc_units_3': 13, 'num_filters_2': 12, 'num_filters_3': 126, 'sgd_momentum': 0.6768319568120289}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: done with job (1, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: registered result for job (1, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 0) on hpbandster.run_None.worker.74c293875977.63436140593734223680 finished
# DEBUG:hpbandster:job_id: (1, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.06330305434316162, 'lr': 0.09294871404957533, 'lstm_units': 173, 'num_conv_layers': 3, 'num_fc_layers': 3, 'num_fc_units_1': 47, 'num_filters_1': 12, 'optimizer': 'SGD', 'num_fc_units_2': 140, 'num_fc_units_3': 13, 'num_filters_2': 12, 'num_filters_3': 126, 'sgd_momentum': 0.6768319568120289}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.11692017316818237, 'info': {'test accuracy': 0.8364928960800171, 'train accuracy': 1.0, 'validation accuracy': 0.8830798268318176, 'number of parameters': 229535}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (1, 0, 0) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (1, 0, 0) got condition
# DEBUG:hpbandster:Only 2 run(s) for budget 200.000000 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (1, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 1
# DEBUG:hpbandster:HBMASTER: trying submitting job (1, 0, 1) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (1, 0, 1) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (1, 0, 1)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (1, 0, 1) submitted to dispatcher
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (1, 0, 1) on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 1) dispatched on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: start processing job (1, 0, 1)
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: kwargs: {'config': {'dropout_rate': 0.1910180600083343, 'lr': 1.5694393011123773e-05, 'lstm_units': 75, 'num_conv_layers': 5, 'num_fc_layers': 3, 'num_fc_units_1': 30, 'num_filters_1': 10, 'optimizer': 'SGD', 'num_fc_units_2': 213, 'num_fc_units_3': 14, 'num_filters_2': 5, 'num_filters_3': 31, 'num_filters_4': 29, 'num_filters_5': 65, 'sgd_momentum': 0.025083904219880715}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: done with job (1, 0, 1), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: registered result for job (1, 0, 1) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 1) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (1, 0, 1) on hpbandster.run_None.worker.74c293875977.63436140593734223680 finished
# DEBUG:hpbandster:job_id: (1, 0, 1)
# kwargs: {'config': {'dropout_rate': 0.1910180600083343, 'lr': 1.5694393011123773e-05, 'lstm_units': 75, 'num_conv_layers': 5, 'num_fc_layers': 3, 'num_fc_units_1': 30, 'num_filters_1': 10, 'optimizer': 'SGD', 'num_fc_units_2': 213, 'num_fc_units_3': 14, 'num_filters_2': 5, 'num_filters_3': 31, 'num_filters_4': 29, 'num_filters_5': 65, 'sgd_momentum': 0.025083904219880715}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.26330798864364624, 'info': {'test accuracy': 0.75, 'train accuracy': 0.7544360160827637, 'validation accuracy': 0.7366920113563538, 'number of parameters': 63361}}
# exception: None
# DEBUG:hpbandster:job_callback for (1, 0, 1) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (1, 0, 1) got condition
# DEBUG:hpbandster:Only 3 run(s) for budget 200.000000 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (1, 0, 1) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 2
# DEBUG:hpbandster:HBMASTER: trying submitting job (2, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (2, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (2, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (2, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (2, 0, 0) on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63436140593734223680
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: start processing job (2, 0, 0)
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: kwargs: {'config': {'dropout_rate': 0.22357652277712536, 'lr': 8.577342816633363e-06, 'lstm_units': 86, 'num_conv_layers': 3, 'num_fc_layers': 2, 'num_fc_units_1': 80, 'num_filters_1': 65, 'optimizer': 'SGD', 'num_fc_units_2': 21, 'num_filters_2': 7, 'num_filters_3': 14, 'sgd_momentum': 0.8902238120247522}, 'budget': 66.66666666666666, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: done with job (2, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: registered result for job (2, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 0) on hpbandster.run_None.worker.74c293875977.63436140593734223680 finished
# DEBUG:hpbandster:job_id: (2, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.22357652277712536, 'lr': 8.577342816633363e-06, 'lstm_units': 86, 'num_conv_layers': 3, 'num_fc_layers': 2, 'num_fc_units_1': 80, 'num_filters_1': 65, 'optimizer': 'SGD', 'num_fc_units_2': 21, 'num_filters_2': 7, 'num_filters_3': 14, 'sgd_momentum': 0.8902238120247522}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.26330798864364624, 'info': {'test accuracy': 0.75, 'train accuracy': 0.7544360160827637, 'validation accuracy': 0.7366920113563538, 'number of parameters': 45562}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (2, 0, 0) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (2, 0, 0) got condition
# DEBUG:hpbandster:Only 4 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (2, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 2
# DEBUG:hpbandster:HBMASTER: trying submitting job (2, 0, 1) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (2, 0, 1) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (2, 0, 1)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (2, 0, 1) submitted to dispatcher
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (2, 0, 1) on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 1) dispatched on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: start processing job (2, 0, 1)
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: kwargs: {'config': {'dropout_rate': 0.5609493419940856, 'lr': 1.790160502814853e-05, 'lstm_units': 215, 'num_conv_layers': 2, 'num_fc_layers': 3, 'num_fc_units_1': 54, 'num_filters_1': 204, 'optimizer': 'SGD', 'num_fc_units_2': 126, 'num_fc_units_3': 77, 'num_filters_2': 14, 'sgd_momentum': 0.14264417899467347}, 'budget': 66.66666666666666, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: done with job (2, 0, 1), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: registered result for job (2, 0, 1) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 1) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 1) on hpbandster.run_None.worker.74c293875977.63436140593734223680 finished
# DEBUG:hpbandster:job_id: (2, 0, 1)
# kwargs: {'config': {'dropout_rate': 0.5609493419940856, 'lr': 1.790160502814853e-05, 'lstm_units': 215, 'num_conv_layers': 2, 'num_fc_layers': 3, 'num_fc_units_1': 54, 'num_filters_1': 204, 'optimizer': 'SGD', 'num_fc_units_2': 126, 'num_fc_units_3': 77, 'num_filters_2': 14, 'sgd_momentum': 0.14264417899467347}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.2652091383934021, 'info': {'test accuracy': 0.75, 'train accuracy': 0.7515842914581299, 'validation accuracy': 0.7347908616065979, 'number of parameters': 236261}}
# exception: None
# DEBUG:hpbandster:job_callback for (2, 0, 1) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (2, 0, 1) got condition
# DEBUG:hpbandster:Only 5 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (2, 0, 1) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 2
# DEBUG:hpbandster:HBMASTER: trying submitting job (2, 0, 2) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (2, 0, 2) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (2, 0, 2)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (2, 0, 2) submitted to dispatcher
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: starting job (2, 0, 2) on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 2) dispatched on hpbandster.run_None.worker.74c293875977.63436140593734223680
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: start processing job (2, 0, 2)
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: kwargs: {'config': {'dropout_rate': 0.5534323283038798, 'lr': 0.06527097431990794, 'lstm_units': 162, 'num_conv_layers': 5, 'num_fc_layers': 2, 'num_fc_units_1': 12, 'num_filters_1': 90, 'optimizer': 'Adam', 'num_fc_units_2': 154, 'num_filters_2': 11, 'num_filters_3': 14, 'num_filters_4': 13, 'num_filters_5': 50}, 'budget': 66.66666666666666, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: done with job (2, 0, 2), trying to register it.
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 2) finished
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: registered result for job (2, 0, 2) with dispatcher
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 2) on hpbandster.run_None.worker.74c293875977.63436140593734223680 finished
# DEBUG:hpbandster:job_id: (2, 0, 2)
# kwargs: {'config': {'dropout_rate': 0.5534323283038798, 'lr': 0.06527097431990794, 'lstm_units': 162, 'num_conv_layers': 5, 'num_fc_layers': 2, 'num_fc_units_1': 12, 'num_filters_1': 90, 'optimizer': 'Adam', 'num_fc_units_2': 154, 'num_filters_2': 11, 'num_filters_3': 14, 'num_filters_4': 13, 'num_filters_5': 50}, 'budget': 66.66666666666666, 'working_directory': '.'}
# result: {'loss': 0.26330798864364624, 'info': {'test accuracy': 0.75, 'train accuracy': 0.7544360160827637, 'validation accuracy': 0.7366920113563538, 'number of parameters': 148783}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (2, 0, 2) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (2, 0, 2) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:Only 6 run(s) for budget 66.666667 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (2, 0, 2) finished
# DEBUG:hpbandster:ITERATION: Advancing config (2, 0, 0) to next budget 200.000000
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 2
# DEBUG:hpbandster:HBMASTER: trying submitting job (2, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (2, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (2, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (2, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (2, 0, 0) on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: start processing job (2, 0, 0)
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: kwargs: {'config': {'dropout_rate': 0.22357652277712536, 'lr': 8.577342816633363e-06, 'lstm_units': 86, 'num_conv_layers': 3, 'num_fc_layers': 2, 'num_fc_units_1': 80, 'num_filters_1': 65, 'optimizer': 'SGD', 'num_fc_units_2': 21, 'num_filters_2': 7, 'num_filters_3': 14, 'sgd_momentum': 0.8902238120247522}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: done with job (2, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: registered result for job (2, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (2, 0, 0) on hpbandster.run_None.worker.74c293875977.63436140593734223680 finished
# DEBUG:hpbandster:job_id: (2, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.22357652277712536, 'lr': 8.577342816633363e-06, 'lstm_units': 86, 'num_conv_layers': 3, 'num_fc_layers': 2, 'num_fc_units_1': 80, 'num_filters_1': 65, 'optimizer': 'SGD', 'num_fc_units_2': 21, 'num_filters_2': 7, 'num_filters_3': 14, 'sgd_momentum': 0.8902238120247522}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.26330798864364624, 'info': {'test accuracy': 0.75, 'train accuracy': 0.7544360160827637, 'validation accuracy': 0.7366920113563538, 'number of parameters': 45562}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (2, 0, 0) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (2, 0, 0) got condition
# DEBUG:hpbandster:Only 4 run(s) for budget 200.000000 available, need more than 17 -> can't build model!
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (2, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 3
# DEBUG:hpbandster:HBMASTER: trying submitting job (3, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (3, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (3, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (3, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (3, 0, 0) on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: job (3, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: start processing job (3, 0, 0)
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: kwargs: {'config': {'dropout_rate': 0.8339506271894708, 'lr': 0.00032164320246459157, 'lstm_units': 63, 'num_conv_layers': 3, 'num_fc_layers': 2, 'num_fc_units_1': 77, 'num_filters_1': 6, 'optimizer': 'Adam', 'num_fc_units_2': 13, 'num_filters_2': 6, 'num_filters_3': 5}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# ...
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: done with job (98, 0, 1), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: registered result for job (98, 0, 1) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (98, 0, 1) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (98, 0, 1) on hpbandster.run_None.worker.74c293875977.63436140593734223680 finished
# DEBUG:hpbandster:job_id: (98, 0, 1)
# kwargs: {'config': {'dropout_rate': 0.7697153872792809, 'lr': 0.03619308830912289, 'lstm_units': 169, 'num_conv_layers': 2, 'num_fc_layers': 3, 'num_fc_units_1': 12, 'num_filters_1': 65, 'optimizer': 'SGD', 'num_fc_units_2': 115, 'num_fc_units_3': 81, 'num_filters_2': 5, 'sgd_momentum': 0.3639432785280402}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.16920149326324463, 'info': {'test accuracy': 0.741706132888794, 'train accuracy': 0.8456907272338867, 'validation accuracy': 0.8307985067367554, 'number of parameters': 132748}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (98, 0, 1) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:job_callback for (98, 0, 1) got condition
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:done building a new model for budget 200.000000 based on 22/125 split
# Best loss for this budget:0.089354
#
#
#
#
#
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (98, 0, 1) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:best_vector: [0.9371522049382461, 0.6737195990702579, 0.39335365668705463, 0.5629294686280926, 0.3270140792676712, 0.7977996172670666, 0.8827552161955677, 1, 0.2793133399924185, 0.049004042265547665, 0.9266938004765276, 0.10852023704718017, 0.18997896011477142, 0.6459799681439067, 0.7233620761466393], 0.0240472144457353, 0.40760013107400045, 0.009801647760046306
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 99
# DEBUG:hpbandster:HBMASTER: trying submitting job (99, 0, 0) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (99, 0, 0) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (99, 0, 0)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (99, 0, 0) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (99, 0, 0) on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 0) dispatched on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: start processing job (99, 0, 0)
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: kwargs: {'config': {'dropout_rate': 0.8434369844444215, 'lr': 0.002336673295857773, 'lstm_units': 105, 'num_conv_layers': 3, 'num_fc_layers': 1, 'num_fc_units_1': 126, 'num_filters_1': 155, 'optimizer': 'SGD', 'num_filters_2': 187, 'num_filters_3': 6, 'sgd_momentum': 0.7161284553851729}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: done with job (99, 0, 0), trying to register it.
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: registered result for job (99, 0, 0) with dispatcher
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 0) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 0) on hpbandster.run_None.worker.74c293875977.63436140593734223680 finished
# DEBUG:hpbandster:job_id: (99, 0, 0)
# kwargs: {'config': {'dropout_rate': 0.8434369844444215, 'lr': 0.002336673295857773, 'lstm_units': 105, 'num_conv_layers': 3, 'num_fc_layers': 1, 'num_fc_units_1': 126, 'num_filters_1': 155, 'optimizer': 'SGD', 'num_filters_2': 187, 'num_filters_3': 6, 'sgd_momentum': 0.7161284553851729}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.17585551738739014, 'info': {'test accuracy': 0.7677724957466125, 'train accuracy': 0.8409379124641418, 'validation accuracy': 0.8241444826126099, 'number of parameters': 152122}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (99, 0, 0) started
# DEBUG:hpbandster:job_callback for (99, 0, 0) got condition
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:done building a new model for budget 200.000000 based on 22/126 split
# Best loss for this budget:0.089354
#
#
#
#
#
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (99, 0, 0) finished
# DEBUG:hpbandster:start sampling a new configuration.
# DEBUG:hpbandster:best_vector: [0.06466942017201094, 0.8462564821570371, 0.23169347706354482, 0.1963167999951273, 0.03768079940059571, 0.04366436950339958, 0.5823939138601644, 1, 0.026863671675870747, 0.44946498671973273, 0.4466992356738475, 0.6171736624397215, 0.02140027238664624, 0.7851287908657363, 0.07897710712797018], 0.0034478285791869298, 0.04459434166386775, 0.00015375364565870965
# DEBUG:hpbandster:done sampling a new configuration.
# DEBUG:hpbandster:HBMASTER: schedule new run for iteration 99
# DEBUG:hpbandster:HBMASTER: trying submitting job (99, 0, 1) to dispatcher
# DEBUG:hpbandster:HBMASTER: submitting job (99, 0, 1) to dispatcher
# DEBUG:hpbandster:DISPATCHER: trying to submit job (99, 0, 1)
# DEBUG:hpbandster:DISPATCHER: trying to notify the job_runner thread.
# DEBUG:hpbandster:HBMASTER: job (99, 0, 1) submitted to dispatcher
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# DEBUG:hpbandster:DISPATCHER: starting job (99, 0, 1) on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 1) dispatched on hpbandster.run_None.worker.74c293875977.63436140593734223680
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: start processing job (99, 0, 1)
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: args: ()
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: kwargs: {'config': {'dropout_rate': 0.05820247815480985, 'lr': 0.017032657392508022, 'lstm_units': 65, 'num_conv_layers': 1, 'num_fc_layers': 1, 'num_fc_units_1': 9, 'num_filters_1': 43, 'optimizer': 'SGD', 'sgd_momentum': 0.07818733605669048}, 'budget': 200.0, 'working_directory': '.'}
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster:DISPATCHER: Starting worker discovery
# DEBUG:hpbandster:DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# DEBUG:hpbandster:DISPATCHER: Finished worker discovery
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: done with job (99, 0, 1), trying to register it.
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 1) finished
# DEBUG:hpbandster:DISPATCHER: register_result: lock acquired
# DEBUG:hpbandster:DISPATCHER: job (99, 0, 1) on hpbandster.run_None.worker.74c293875977.63436140593734223680 finished
# INFO:hpbandster.run_None.worker.74c293875977.63436:WORKER: registered result for job (99, 0, 1) with dispatcher
# DEBUG:hpbandster:job_id: (99, 0, 1)
# kwargs: {'config': {'dropout_rate': 0.05820247815480985, 'lr': 0.017032657392508022, 'lstm_units': 65, 'num_conv_layers': 1, 'num_fc_layers': 1, 'num_fc_units_1': 9, 'num_filters_1': 43, 'optimizer': 'SGD', 'sgd_momentum': 0.07818733605669048}, 'budget': 200.0, 'working_directory': '.'}
# result: {'loss': 0.25, 'info': {'test accuracy': 0.6919431090354919, 'train accuracy': 0.7686945796012878, 'validation accuracy': 0.75, 'number of parameters': 29245}}
# exception: None
#
# DEBUG:hpbandster:job_callback for (99, 0, 1) started
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# DEBUG:hpbandster:job_callback for (99, 0, 1) got condition
# DEBUG:hpbandster:done building a new model for budget 200.000000 based on 22/127 split
# Best loss for this budget:0.089354
#
#
#
#
#
# DEBUG:hpbandster:HBMASTER: Trying to run another job!
# DEBUG:hpbandster:job_callback for (99, 0, 1) finished
# DEBUG:hpbandster:HBMASTER: shutdown initiated, shutdown_workers = True
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: shutting down now!
# INFO:hpbandster:DISPATCHER: Dispatcher shutting down
# DEBUG:hpbandster:DISPATCHER: Trying to submit another job.
# DEBUG:hpbandster:DISPATCHER: job_runner shutting down
# DEBUG:hpbandster:DISPATCHER: discover_workers shutting down
# DEBUG:hpbandster:DISPATCHER: 'discover_worker' thread exited
# DEBUG:hpbandster:DISPATCHER: 'job_runner' thread exited
# INFO:hpbandster:DISPATCHER: shut down complete
# DEBUG:hpbandster.run_None.worker.74c293875977.63436:WORKER: shutting down now!

# %%
# Step 5: Analysis
# Each optimizer returns a hpbandster.core.result.Result object.
# It holds informations about the optimization run like the incumbent (=best) configuration.
# For further details about the Result object, see its documentation.
# Here we simply print out the best config and some statistics about the performed runs.
id2config = res.get_id2config_mapping()
incumbent = res.get_incumbent_id()

print('Best found configuration:', id2config[incumbent]['config'])
print('A total of %i unique configurations where sampled.' % len(id2config.keys()))
print('A total of %i runs where executed.' % len(res.get_all_runs()))
print('Total budget corresponds to %.1f full function evaluations.'%(sum([r.budget for r in res.get_all_runs()])/args.max_budget))
# Out:
# Best found configuration: {'dropout_rate': 0.7947857692503151, 'lr': 0.0007448505160641001, 'lstm_units': 128, 'num_conv_layers': 3, 'num_fc_layers': 2, 'num_fc_units_1': 136, 'num_filters_1': 153, 'optimizer': 'Adam', 'num_fc_units_2': 8, 'num_filters_2': 101, 'num_filters_3': 49}
# A total of 250 unique configurations where sampled.
# A total of 300 runs where executed.
# Total budget corresponds to 200.0 full function evaluations.
