# %%
# -*- coding: utf-8 -*-

import scipy.io
import numpy as np
import tensorflow as tf
import sklearn as sk
import matplotlib.pyplot as plt
import itertools
import random

from numba import cuda
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

from tensorflow.keras.callbacks import  EarlyStopping

# %%
# tensorflow = 2.
# python = 3.6


seed = np.random.seed(777)

gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
    
  try:
      
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
      
  except RuntimeError as e:
      
    print(e)


val_loss_all = []

test_loss_all = []
test_acc_all = []
test_pre_all = []
frr_all = []
far_all = []

conf_matrix_sco = []
test_pre_sco = []
test_rec_sco = []
test_spedi_sco = []
test_sensi_sco = []

class MyModelCheckpoint(tf.keras.callbacks.ModelCheckpoint):

    def __init__(self, *args, **kwargs):
        super(MyModelCheckpoint, self).__init__(*args, **kwargs)

    # redefine the save so it only activates after 100 epochs
    def on_epoch_end(self, epoch, logs=None):
        if epoch >= 1: super(MyModelCheckpoint, self).on_epoch_end(epoch, logs)

# %%
train_data = scipy.io.loadmat('../../datas/160hz/train_5day_160hz.mat', squeeze_me=True)['data']
test_data = scipy.io.loadmat('../../datas/160hz/test_6day_160hz(2).mat', squeeze_me=True)['data']

# sub 수
sub_cnt = train_data.shape[0]

# 3sec 데이터 크기
data_size = 480

# 1명당 3초 데이터 개수
train_data_cnt = 1052
test_data_cnt = 211

# 3sec 480(= 160*3) 크기로 데이터 길이 설정
train_cut_size = 504960 # 480*1052 = 504960
test_cut_size = 101280 # 480*211 = 101280

# 3sec 데이터 길이 자르기
# train: 504,960 / test: 101,280
train_data = train_data[:,0:train_cut_size,:]
test_data = test_data[:,0:test_cut_size,:]

# flatten(): 3D -> 1D / reshape(-1,1): -1 마지막 인덱스
train_flatten = train_data.flatten().reshape(-1,1)
test_flatten = test_data.flatten().reshape(-1,1)

# StandardScaler(): train에 맞춰 표준화
data_scaler = StandardScaler()
    
data_scaler.fit(train_flatten)
train_scaler = data_scaler.transform(train_flatten)
test_scaler = data_scaler.transform(test_flatten)
    
# train, test 데이터 reshape
train_data = train_scaler.reshape(train_data_cnt * sub_cnt, data_size, 2) 
test_data = test_scaler.reshape(test_data_cnt * sub_cnt, data_size, 2)

#train data를 sub:other=1:1로 만들기 위해서 각 sub 추출
train_data_each = []
for i in range(sub_cnt):
    train_data_each.insert(i, train_data[i*train_data_cnt:(i+1)*train_data_cnt, :, :])
print(np.shape(train_data_each))

#test data를 sub:other=1:3로 만들기 위해서 각 sub 추출
test_data_each = []
for i in range(sub_cnt):
    test_data_each.insert(i, test_data[i*test_data_cnt:(i+1)*test_data_cnt, :, :])
print(np.shape(test_data_each))
# Out:
# (11, 1052, 480, 2)
# (11, 211, 480, 2)

# %%
# sub number
sub_num = 0

#1 to 3 비율로 설정
ratio = 3

train_data_n = train_data_each[sub_num]
test_data_n = test_data_each[sub_num]

# train data를 sub:other = 1:3으로 만들기
# 3초 덩어리 개수 1052 : 3156
# => 315 * 4 + 316 * 6 = 1260 + 1896 = 3156

# test data를 sub:other = 1:3로 만들기
# 3초 덩어리 개수 211 : 633
# 63 * 7 + 64 * 3 = 633

cnt = 0
for j in range(sub_cnt):
    if j != sub_num and cnt < 4:
        cnt = cnt + 1
        train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 315)), axis = 0)
    elif j != sub_num and cnt >= 4:
        train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 316)), axis = 0)
#     print("train_data_n.shape")
#     print(train_data_n.shape)
#     print("train_data_n")
#     print(train_data_n)
        
cnt = 0
for j in range(sub_cnt):
    if j != sub_num and cnt < 7:
        cnt = cnt + 1
        test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 63)), axis = 0)
    elif j != sub_num and cnt >= 7:
        test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 64)), axis = 0)
        
        
        
train_label = np.zeros(train_data_cnt*(ratio+1))
test_label = np.zeros(test_data_cnt*(ratio+1))

for j in range(len(train_label)):
    if (j < train_data_cnt):
        train_label[j] = 1

for j in range(len(test_label)):
    if (j < test_data_cnt):
        test_label[j] = 1
        
train_data_shuffled, train_label_shuffled = sk.utils.shuffle(train_data_n, train_label, random_state = 0)

val_data_set = train_data_shuffled[:train_data_cnt]
train_data_set = train_data_shuffled[train_data_cnt:]

val_label_set = train_label_shuffled[:train_data_cnt]
train_label_set = train_label_shuffled[train_data_cnt:]

# %%
# model CNN-LSTM    
inputs = tf.keras.Input(shape = (480, 2))
conv_1 = tf.keras.layers.Conv1D(filters = 16, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(inputs)
max_1 = tf.keras.layers.MaxPool1D(3)(conv_1)
    
conv_2 = tf.keras.layers.Conv1D(filters = 57, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(max_1)
max_2 = tf.keras.layers.MaxPool1D(3)(conv_2)
    
conv_3 = tf.keras.layers.Conv1D(filters = 43, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(max_2)
max_3 = tf.keras.layers.MaxPool1D(3)(conv_3)
    

D_out_1 = tf.keras.layers.Dropout(0.6270639984295334)(max_3)
    
    
lstm_1 = tf.keras.layers.LSTM(252)(D_out_1)
    
dense_1 = tf.keras.layers.Dense(16, activation = 'relu')(lstm_1)
dense_2 = tf.keras.layers.Dense(13, activation = 'relu')(dense_1)
dense_3 = tf.keras.layers.Dense(1, activation = 'sigmoid')(dense_2)
    
model = tf.keras.models.Model(inputs = inputs, outputs = dense_3)

# Adam
# model.compile(loss = 'binary_crossentropy', optimizer = tf.keras.optimizers.Adam(0.4411297369087802), metrics = ['accuracy'])
# SGD
model.compile(loss= 'binary_crossentropy', optimizer= tf.keras.optimizers.SGD(learning_rate=0.0461300729767683, momentum=0.4411297369087802), metrics=['accuracy'])
    
# EarlyStopping 조기종료 및 모델 학습
early_stopping = tf.keras.callbacks.EarlyStopping(patience = 20)
check_point = MyModelCheckpoint('best_model_' + str(sub_num + 1) + '.h5', monitor = 'val_loss', mode = 'min', save_best_only = True, verbose = 1)

# EarlyStopping 사용
hist = model.fit(train_data_set, train_label_set, epochs = 200, batch_size = 32, validation_data = (val_data_set, val_label_set), callbacks = [early_stopping, check_point])
# EarlyStopping 미사용
# hist = model.fit(train_data_set, train_label_set, epochs = 200, batch_size = 32, validation_data = (val_data_set, val_label_set), callbacks = [check_point])

# model save .h5형식
model = tf.keras.models.load_model('best_model_' + str(sub_num + 1) + '.h5')
model.save('Binary_BOHB_' + str(sub_num + 1) + '.h5')
model.summary() 
        
val_loss, val_acc = model.evaluate(val_data_set, val_label_set, verbose = 2)

test_loss, test_acc = model.evaluate(test_data_n, test_label, verbose = 2)
test_pred = model.predict(test_data_n)
        
    
# 각 행은 1sec, 0.5 <= 자신, 0.5 > 타인
for i in range(len(test_pred)):
    if(test_pred[i] >= 0.5):
        test_pred[i] = 1
    
    else: 
        test_pred[i] = 0
    
    
val_loss_all.append(val_loss)
    
test_loss_all.append(test_loss)
test_acc_all.append(test_acc)
test_pre_all.append(test_pred)
    

conf_matrix = confusion_matrix(test_label, test_pred) 
conf_matrix_sco.append(conf_matrix)
    
conf_row = conf_matrix.sum(axis = 1)
conf_col = conf_matrix.sum(axis = 0)

precision = conf_matrix[1][1] / conf_col[1]
recall = conf_matrix[1][1] / conf_row[1]
specificity = conf_matrix[0][0] / conf_row[0]
sensitivity = conf_matrix[1][1] / conf_row[1]
frr = conf_matrix[1][0] / (conf_matrix[1][1]+conf_matrix[1][0])
far = conf_matrix[0][1] / (conf_matrix[0][1]+conf_matrix[0][0])
    
frr_all.append(frr)
far_all.append(far)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111)

cax = ax.matshow(conf_matrix)

fig.colorbar(cax)

for i, j in itertools.product(range(conf_matrix.shape[0]), range(conf_matrix.shape[1])):
    plt.text(j, i, conf_matrix[i, j], color="white")

plt.title('CNN+LSTM model')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.show()
 
    
test_pre_sco.append(precision)
test_rec_sco.append(recall)
test_spedi_sco.append(specificity)
test_sensi_sco.append(sensitivity)
    
print('val_loss:', val_loss)
print('test_loss:', test_loss)
print('test_acc:', test_acc)
    
print('precision:', precision)
print('recall:', recall)
print('specificity', specificity)
print('sensitivity : ', sensitivity)
print('far', far)
print('frr', frr)
# Out:
# Epoch 1/200
# 99/99 [==============================] - 2s 22ms/step - loss: 0.5681 - accuracy: 0.7544 - val_loss: 0.5558 - val_accuracy: 0.7367
# Epoch 2/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.5007 - accuracy: 0.7568
# Epoch 00002: val_loss improved from inf to 0.42632, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 21ms/step - loss: 0.4997 - accuracy: 0.7573 - val_loss: 0.4263 - val_accuracy: 0.7814
# Epoch 3/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.4154 - accuracy: 0.7887
# Epoch 00003: val_loss improved from 0.42632 to 0.38474, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.4140 - accuracy: 0.7890 - val_loss: 0.3847 - val_accuracy: 0.8051
# Epoch 4/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3888 - accuracy: 0.8051
# Epoch 00004: val_loss improved from 0.38474 to 0.34638, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.3905 - accuracy: 0.8048 - val_loss: 0.3464 - val_accuracy: 0.8470
# Epoch 5/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3672 - accuracy: 0.8363
# Epoch 00005: val_loss did not improve from 0.34638
# 99/99 [==============================] - 2s 20ms/step - loss: 0.3654 - accuracy: 0.8368 - val_loss: 0.4027 - val_accuracy: 0.8346
# Epoch 6/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3583 - accuracy: 0.8402
# Epoch 00006: val_loss improved from 0.34638 to 0.31568, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.3578 - accuracy: 0.8403 - val_loss: 0.3157 - val_accuracy: 0.8660
# Epoch 7/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3413 - accuracy: 0.8524
# Epoch 00007: val_loss did not improve from 0.31568
# 99/99 [==============================] - 2s 20ms/step - loss: 0.3459 - accuracy: 0.8504 - val_loss: 0.3184 - val_accuracy: 0.8793
# Epoch 8/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3305 - accuracy: 0.8631
# Epoch 00008: val_loss did not improve from 0.31568
# 99/99 [==============================] - 2s 20ms/step - loss: 0.3313 - accuracy: 0.8622 - val_loss: 0.3448 - val_accuracy: 0.8840
# Epoch 9/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3114 - accuracy: 0.8744
# Epoch 00009: val_loss did not improve from 0.31568
# 99/99 [==============================] - 2s 20ms/step - loss: 0.3103 - accuracy: 0.8748 - val_loss: 0.3173 - val_accuracy: 0.8764
# Epoch 10/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3252 - accuracy: 0.8628
# Epoch 00010: val_loss did not improve from 0.31568
# 99/99 [==============================] - 2s 20ms/step - loss: 0.3238 - accuracy: 0.8628 - val_loss: 0.3365 - val_accuracy: 0.8726
# Epoch 11/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3052 - accuracy: 0.8744
# Epoch 00011: val_loss did not improve from 0.31568
# 99/99 [==============================] - 2s 20ms/step - loss: 0.3099 - accuracy: 0.8704 - val_loss: 0.3205 - val_accuracy: 0.8536
# Epoch 12/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2877 - accuracy: 0.8908
# Epoch 00012: val_loss improved from 0.31568 to 0.25447, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2872 - accuracy: 0.8907 - val_loss: 0.2545 - val_accuracy: 0.9059
# Epoch 13/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2822 - accuracy: 0.8869
# Epoch 00013: val_loss did not improve from 0.25447
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2844 - accuracy: 0.8862 - val_loss: 0.3496 - val_accuracy: 0.8365
# Epoch 14/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2823 - accuracy: 0.8918
# Epoch 00014: val_loss improved from 0.25447 to 0.25351, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2814 - accuracy: 0.8916 - val_loss: 0.2535 - val_accuracy: 0.9097
# Epoch 15/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2782 - accuracy: 0.8895
# Epoch 00015: val_loss did not improve from 0.25351
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2767 - accuracy: 0.8904 - val_loss: 0.3073 - val_accuracy: 0.8859
# Epoch 16/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2631 - accuracy: 0.8972
# Epoch 00016: val_loss did not improve from 0.25351
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2629 - accuracy: 0.8970 - val_loss: 0.2571 - val_accuracy: 0.9021
# Epoch 17/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2536 - accuracy: 0.8985
# Epoch 00017: val_loss did not improve from 0.25351
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2529 - accuracy: 0.8992 - val_loss: 0.2565 - val_accuracy: 0.8983
# Epoch 18/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2587 - accuracy: 0.8985
# Epoch 00018: val_loss did not improve from 0.25351
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2594 - accuracy: 0.8973 - val_loss: 0.2636 - val_accuracy: 0.8916
# Epoch 19/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2444 - accuracy: 0.9079
# Epoch 00019: val_loss did not improve from 0.25351
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2441 - accuracy: 0.9078 - val_loss: 0.3010 - val_accuracy: 0.8916
# Epoch 20/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2411 - accuracy: 0.9114
# Epoch 00020: val_loss did not improve from 0.25351
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2407 - accuracy: 0.9119 - val_loss: 0.2963 - val_accuracy: 0.8878
# Epoch 21/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2416 - accuracy: 0.9088
# Epoch 00021: val_loss did not improve from 0.25351
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2401 - accuracy: 0.9094 - val_loss: 0.2640 - val_accuracy: 0.8954
# Epoch 22/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2325 - accuracy: 0.9117
# Epoch 00022: val_loss improved from 0.25351 to 0.24554, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2335 - accuracy: 0.9116 - val_loss: 0.2455 - val_accuracy: 0.9135
# Epoch 23/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2392 - accuracy: 0.9037
# Epoch 00023: val_loss did not improve from 0.24554
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2400 - accuracy: 0.9034 - val_loss: 0.2878 - val_accuracy: 0.8907
# Epoch 24/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2256 - accuracy: 0.9098
# Epoch 00024: val_loss did not improve from 0.24554
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2370 - accuracy: 0.9065 - val_loss: 0.2865 - val_accuracy: 0.8935
# Epoch 25/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2310 - accuracy: 0.9098
# Epoch 00025: val_loss improved from 0.24554 to 0.21278, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2304 - accuracy: 0.9097 - val_loss: 0.2128 - val_accuracy: 0.9173
# Epoch 26/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2173 - accuracy: 0.9146
# Epoch 00026: val_loss improved from 0.21278 to 0.20590, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2167 - accuracy: 0.9148 - val_loss: 0.2059 - val_accuracy: 0.9259
# Epoch 27/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2140 - accuracy: 0.9185
# Epoch 00027: val_loss did not improve from 0.20590
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2180 - accuracy: 0.9167 - val_loss: 0.2690 - val_accuracy: 0.8840
# Epoch 28/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2090 - accuracy: 0.9204
# Epoch 00028: val_loss improved from 0.20590 to 0.19600, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2087 - accuracy: 0.9208 - val_loss: 0.1960 - val_accuracy: 0.9325
# Epoch 29/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2124 - accuracy: 0.9162
# Epoch 00029: val_loss did not improve from 0.19600
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2125 - accuracy: 0.9160 - val_loss: 0.1988 - val_accuracy: 0.9325
# Epoch 30/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2101 - accuracy: 0.9214
# Epoch 00030: val_loss did not improve from 0.19600
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2104 - accuracy: 0.9205 - val_loss: 0.2578 - val_accuracy: 0.8793
# Epoch 31/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2092 - accuracy: 0.9175
# Epoch 00031: val_loss did not improve from 0.19600
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2094 - accuracy: 0.9176 - val_loss: 0.2134 - val_accuracy: 0.9202
# Epoch 32/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1945 - accuracy: 0.9214
# Epoch 00032: val_loss did not improve from 0.19600
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1947 - accuracy: 0.9208 - val_loss: 0.4041 - val_accuracy: 0.8479
# Epoch 33/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1940 - accuracy: 0.9272
# Epoch 00033: val_loss did not improve from 0.19600
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1935 - accuracy: 0.9274 - val_loss: 0.2342 - val_accuracy: 0.9087
# Epoch 34/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1961 - accuracy: 0.9191
# Epoch 00034: val_loss did not improve from 0.19600
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1947 - accuracy: 0.9202 - val_loss: 0.2176 - val_accuracy: 0.9240
# Epoch 35/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1873 - accuracy: 0.9285
# Epoch 00035: val_loss did not improve from 0.19600
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1868 - accuracy: 0.9284 - val_loss: 0.2303 - val_accuracy: 0.9183
# Epoch 36/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1959 - accuracy: 0.9253
# Epoch 00036: val_loss did not improve from 0.19600
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1989 - accuracy: 0.9236 - val_loss: 0.2257 - val_accuracy: 0.9125
# Epoch 37/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2017 - accuracy: 0.9227
# Epoch 00037: val_loss did not improve from 0.19600
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1994 - accuracy: 0.9240 - val_loss: 0.2240 - val_accuracy: 0.9211
# Epoch 38/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1763 - accuracy: 0.9298
# Epoch 00038: val_loss did not improve from 0.19600
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1767 - accuracy: 0.9297 - val_loss: 0.2100 - val_accuracy: 0.9268
# Epoch 39/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1844 - accuracy: 0.9259
# Epoch 00039: val_loss improved from 0.19600 to 0.18312, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 21ms/step - loss: 0.1849 - accuracy: 0.9259 - val_loss: 0.1831 - val_accuracy: 0.9411
# Epoch 40/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1832 - accuracy: 0.9269
# Epoch 00040: val_loss did not improve from 0.18312
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1867 - accuracy: 0.9255 - val_loss: 0.2889 - val_accuracy: 0.8869
# Epoch 41/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1784 - accuracy: 0.9327
# Epoch 00041: val_loss did not improve from 0.18312
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1782 - accuracy: 0.9325 - val_loss: 0.2646 - val_accuracy: 0.8897
# Epoch 42/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1747 - accuracy: 0.9333
# Epoch 00042: val_loss did not improve from 0.18312
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1748 - accuracy: 0.9328 - val_loss: 0.1831 - val_accuracy: 0.9392
# Epoch 43/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1786 - accuracy: 0.9285
# Epoch 00043: val_loss did not improve from 0.18312
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1788 - accuracy: 0.9281 - val_loss: 0.1989 - val_accuracy: 0.9316
# Epoch 44/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1704 - accuracy: 0.9362
# Epoch 00044: val_loss improved from 0.18312 to 0.17800, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1684 - accuracy: 0.9373 - val_loss: 0.1780 - val_accuracy: 0.9354
# Epoch 45/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1747 - accuracy: 0.9314
# Epoch 00045: val_loss did not improve from 0.17800
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1743 - accuracy: 0.9312 - val_loss: 0.1866 - val_accuracy: 0.9401
# Epoch 46/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1724 - accuracy: 0.9346
# Epoch 00046: val_loss did not improve from 0.17800
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1715 - accuracy: 0.9347 - val_loss: 0.1892 - val_accuracy: 0.9382
# Epoch 47/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1628 - accuracy: 0.9375
# Epoch 00047: val_loss did not improve from 0.17800
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1617 - accuracy: 0.9379 - val_loss: 0.1865 - val_accuracy: 0.9354
# Epoch 48/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1723 - accuracy: 0.9323
# Epoch 00048: val_loss did not improve from 0.17800
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1713 - accuracy: 0.9322 - val_loss: 0.2395 - val_accuracy: 0.9144
# Epoch 49/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1632 - accuracy: 0.9401
# Epoch 00049: val_loss did not improve from 0.17800
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1639 - accuracy: 0.9398 - val_loss: 0.1874 - val_accuracy: 0.9344
# Epoch 50/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1616 - accuracy: 0.9346
# Epoch 00050: val_loss improved from 0.17800 to 0.17686, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1604 - accuracy: 0.9350 - val_loss: 0.1769 - val_accuracy: 0.9373
# Epoch 51/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1572 - accuracy: 0.9369
# Epoch 00051: val_loss improved from 0.17686 to 0.17046, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1556 - accuracy: 0.9379 - val_loss: 0.1705 - val_accuracy: 0.9420
# Epoch 52/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1596 - accuracy: 0.9378
# Epoch 00052: val_loss did not improve from 0.17046
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1594 - accuracy: 0.9379 - val_loss: 0.1972 - val_accuracy: 0.9278
# Epoch 53/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1568 - accuracy: 0.9430
# Epoch 00053: val_loss did not improve from 0.17046
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1572 - accuracy: 0.9420 - val_loss: 0.2193 - val_accuracy: 0.9249
# Epoch 54/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1546 - accuracy: 0.9381
# Epoch 00054: val_loss did not improve from 0.17046
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1544 - accuracy: 0.9382 - val_loss: 0.1762 - val_accuracy: 0.9439
# Epoch 55/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1467 - accuracy: 0.9433
# Epoch 00055: val_loss did not improve from 0.17046
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1450 - accuracy: 0.9442 - val_loss: 0.2035 - val_accuracy: 0.9335
# Epoch 56/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1603 - accuracy: 0.9381
# Epoch 00056: val_loss did not improve from 0.17046
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1585 - accuracy: 0.9388 - val_loss: 0.1807 - val_accuracy: 0.9420
# Epoch 57/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1485 - accuracy: 0.9433
# Epoch 00057: val_loss did not improve from 0.17046
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1501 - accuracy: 0.9433 - val_loss: 0.1770 - val_accuracy: 0.9420
# Epoch 58/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1530 - accuracy: 0.9420
# Epoch 00058: val_loss did not improve from 0.17046
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1514 - accuracy: 0.9426 - val_loss: 0.1955 - val_accuracy: 0.9411
# Epoch 59/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1638 - accuracy: 0.9372
# Epoch 00059: val_loss did not improve from 0.17046
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1647 - accuracy: 0.9373 - val_loss: 0.1963 - val_accuracy: 0.9297
# Epoch 60/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1389 - accuracy: 0.9462
# Epoch 00060: val_loss did not improve from 0.17046
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1394 - accuracy: 0.9458 - val_loss: 0.1762 - val_accuracy: 0.9382
# Epoch 61/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1419 - accuracy: 0.9430
# Epoch 00061: val_loss did not improve from 0.17046
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1421 - accuracy: 0.9433 - val_loss: 0.1976 - val_accuracy: 0.9344
# Epoch 62/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1297 - accuracy: 0.9517
# Epoch 00062: val_loss improved from 0.17046 to 0.17041, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1317 - accuracy: 0.9509 - val_loss: 0.1704 - val_accuracy: 0.9468
# Epoch 63/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1428 - accuracy: 0.9472
# Epoch 00063: val_loss improved from 0.17041 to 0.16579, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 21ms/step - loss: 0.1413 - accuracy: 0.9477 - val_loss: 0.1658 - val_accuracy: 0.9468
# Epoch 64/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1373 - accuracy: 0.9485
# Epoch 00064: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1376 - accuracy: 0.9480 - val_loss: 0.2041 - val_accuracy: 0.9382
# Epoch 65/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1337 - accuracy: 0.9494
# Epoch 00065: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1340 - accuracy: 0.9493 - val_loss: 0.1989 - val_accuracy: 0.9354
# Epoch 66/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1382 - accuracy: 0.9433
# Epoch 00066: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1367 - accuracy: 0.9442 - val_loss: 0.2028 - val_accuracy: 0.9335
# Epoch 67/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1273 - accuracy: 0.9507
# Epoch 00067: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1279 - accuracy: 0.9499 - val_loss: 0.1785 - val_accuracy: 0.9411
# Epoch 68/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1279 - accuracy: 0.9472
# Epoch 00068: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1266 - accuracy: 0.9477 - val_loss: 0.1675 - val_accuracy: 0.9487
# Epoch 69/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1369 - accuracy: 0.9465
# Epoch 00069: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1364 - accuracy: 0.9465 - val_loss: 0.1758 - val_accuracy: 0.9468
# Epoch 70/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1213 - accuracy: 0.9517
# Epoch 00070: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1210 - accuracy: 0.9518 - val_loss: 0.1832 - val_accuracy: 0.9382
# Epoch 71/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1421 - accuracy: 0.9462
# Epoch 00071: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1426 - accuracy: 0.9461 - val_loss: 0.1852 - val_accuracy: 0.9392
# Epoch 72/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1241 - accuracy: 0.9565
# Epoch 00072: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1231 - accuracy: 0.9569 - val_loss: 0.1668 - val_accuracy: 0.9449
# Epoch 73/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1170 - accuracy: 0.9552
# Epoch 00073: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1205 - accuracy: 0.9537 - val_loss: 0.3860 - val_accuracy: 0.8745
# Epoch 74/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1363 - accuracy: 0.9485
# Epoch 00074: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1363 - accuracy: 0.9487 - val_loss: 0.1881 - val_accuracy: 0.9392
# Epoch 75/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1143 - accuracy: 0.9578
# Epoch 00075: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1147 - accuracy: 0.9572 - val_loss: 0.2413 - val_accuracy: 0.9173
# Epoch 76/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1225 - accuracy: 0.9546
# Epoch 00076: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1208 - accuracy: 0.9553 - val_loss: 0.1669 - val_accuracy: 0.9430
# Epoch 77/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1179 - accuracy: 0.9581
# Epoch 00077: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1165 - accuracy: 0.9588 - val_loss: 0.1761 - val_accuracy: 0.9411
# Epoch 78/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1167 - accuracy: 0.9533
# Epoch 00078: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1165 - accuracy: 0.9528 - val_loss: 0.1768 - val_accuracy: 0.9439
# Epoch 79/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0999 - accuracy: 0.9633
# Epoch 00079: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.0993 - accuracy: 0.9632 - val_loss: 0.2043 - val_accuracy: 0.9458
# Epoch 80/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1240 - accuracy: 0.9536
# Epoch 00080: val_loss did not improve from 0.16579
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1249 - accuracy: 0.9528 - val_loss: 0.1883 - val_accuracy: 0.9439
# Epoch 81/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1115 - accuracy: 0.9581
# Epoch 00081: val_loss improved from 0.16579 to 0.16264, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1111 - accuracy: 0.9585 - val_loss: 0.1626 - val_accuracy: 0.9515
# Epoch 82/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1167 - accuracy: 0.9588
# Epoch 00082: val_loss improved from 0.16264 to 0.16209, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1159 - accuracy: 0.9591 - val_loss: 0.1621 - val_accuracy: 0.9477
# Epoch 83/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1061 - accuracy: 0.9601
# Epoch 00083: val_loss improved from 0.16209 to 0.15912, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1062 - accuracy: 0.9601 - val_loss: 0.1591 - val_accuracy: 0.9439
# Epoch 84/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1056 - accuracy: 0.9604
# Epoch 00084: val_loss did not improve from 0.15912
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1056 - accuracy: 0.9598 - val_loss: 0.1785 - val_accuracy: 0.9458
# Epoch 85/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1115 - accuracy: 0.9581
# Epoch 00085: val_loss did not improve from 0.15912
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1103 - accuracy: 0.9588 - val_loss: 0.1861 - val_accuracy: 0.9468
# Epoch 86/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1147 - accuracy: 0.9562
# Epoch 00086: val_loss did not improve from 0.15912
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1155 - accuracy: 0.9556 - val_loss: 0.2088 - val_accuracy: 0.9297
# Epoch 87/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1044 - accuracy: 0.9626
# Epoch 00087: val_loss did not improve from 0.15912
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1043 - accuracy: 0.9626 - val_loss: 0.2136 - val_accuracy: 0.9325
# Epoch 88/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1078 - accuracy: 0.9597
# Epoch 00088: val_loss did not improve from 0.15912
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1068 - accuracy: 0.9604 - val_loss: 0.1929 - val_accuracy: 0.9392
# Epoch 89/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0971 - accuracy: 0.9610
# Epoch 00089: val_loss improved from 0.15912 to 0.15551, saving model to best_model_1.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.0967 - accuracy: 0.9610 - val_loss: 0.1555 - val_accuracy: 0.9506
# Epoch 90/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0996 - accuracy: 0.9646
# Epoch 00090: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.0994 - accuracy: 0.9642 - val_loss: 0.2236 - val_accuracy: 0.9363
# Epoch 91/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1085 - accuracy: 0.9617
# Epoch 00091: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1128 - accuracy: 0.9604 - val_loss: 0.1624 - val_accuracy: 0.9420
# Epoch 92/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1116 - accuracy: 0.9562
# Epoch 00092: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1114 - accuracy: 0.9563 - val_loss: 0.2051 - val_accuracy: 0.9458
# Epoch 93/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1103 - accuracy: 0.9591
# Epoch 00093: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1092 - accuracy: 0.9598 - val_loss: 0.1646 - val_accuracy: 0.9449
# Epoch 94/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0985 - accuracy: 0.9633
# Epoch 00094: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 21ms/step - loss: 0.0987 - accuracy: 0.9629 - val_loss: 0.1885 - val_accuracy: 0.9335
# Epoch 95/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1006 - accuracy: 0.9626
# Epoch 00095: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1002 - accuracy: 0.9629 - val_loss: 0.2467 - val_accuracy: 0.9183
# Epoch 96/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0925 - accuracy: 0.9671
# Epoch 00096: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.0931 - accuracy: 0.9667 - val_loss: 0.3107 - val_accuracy: 0.9078
# Epoch 97/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1019 - accuracy: 0.9613
# Epoch 00097: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1015 - accuracy: 0.9613 - val_loss: 0.2508 - val_accuracy: 0.9173
# Epoch 98/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0902 - accuracy: 0.9678
# Epoch 00098: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.0903 - accuracy: 0.9674 - val_loss: 0.1669 - val_accuracy: 0.9487
# Epoch 99/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0886 - accuracy: 0.9671
# Epoch 00099: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.0896 - accuracy: 0.9667 - val_loss: 0.1829 - val_accuracy: 0.9449
# Epoch 100/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0976 - accuracy: 0.9620
# Epoch 00100: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.0971 - accuracy: 0.9623 - val_loss: 0.1584 - val_accuracy: 0.9496
# Epoch 101/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1098 - accuracy: 0.9591
# Epoch 00101: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.1093 - accuracy: 0.9591 - val_loss: 0.1932 - val_accuracy: 0.9401
# Epoch 102/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0781 - accuracy: 0.9720
# Epoch 00102: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.0776 - accuracy: 0.9721 - val_loss: 0.2245 - val_accuracy: 0.9316
# Epoch 103/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0833 - accuracy: 0.9694
# Epoch 00103: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.0855 - accuracy: 0.9693 - val_loss: 0.2126 - val_accuracy: 0.9363
# Epoch 104/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0820 - accuracy: 0.9694
# Epoch 00104: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.0821 - accuracy: 0.9689 - val_loss: 0.1864 - val_accuracy: 0.9439
# Epoch 105/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0906 - accuracy: 0.9671
# Epoch 00105: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.0905 - accuracy: 0.9670 - val_loss: 0.1605 - val_accuracy: 0.9544
# Epoch 106/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0908 - accuracy: 0.9691
# Epoch 00106: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.0937 - accuracy: 0.9686 - val_loss: 0.2126 - val_accuracy: 0.9344
# Epoch 107/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0835 - accuracy: 0.9668
# Epoch 00107: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.0829 - accuracy: 0.9670 - val_loss: 0.1651 - val_accuracy: 0.9534
# Epoch 108/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0837 - accuracy: 0.9678
# Epoch 00108: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.0833 - accuracy: 0.9680 - val_loss: 0.2283 - val_accuracy: 0.9316
# Epoch 109/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0845 - accuracy: 0.9639
# Epoch 00109: val_loss did not improve from 0.15551
# 99/99 [==============================] - 2s 20ms/step - loss: 0.0834 - accuracy: 0.9645 - val_loss: 0.2525 - val_accuracy: 0.9344
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 480, 16)           112
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 160, 16)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 160, 57)           2793
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 53, 57)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 53, 43)            7396
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 17, 43)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 17, 43)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 252)               298368
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                4048
# _________________________________________________________________
# dense_4 (Dense)              (None, 13)                221
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 14
# =================================================================
# Total params: 312,952
# Trainable params: 312,952
# Non-trainable params: 0
# _________________________________________________________________
# 33/33 - 0s - loss: 0.1555 - accuracy: 0.9506
# 27/27 - 0s - loss: 0.1946 - accuracy: 0.9218
# val_loss: 0.15551118552684784
# test_loss: 0.19458900392055511
# test_acc: 0.921800971031189
# precision: 0.8877005347593583
# recall: 0.7867298578199052
# specificity 0.966824644549763
# sensitivity :  0.7867298578199052
# far 0.03317535545023697
# frr 0.2132701421800948
