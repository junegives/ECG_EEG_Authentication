# %%
# -*- coding: utf-8 -*-

import scipy.io
import numpy as np
import tensorflow as tf
import sklearn as sk
import matplotlib.pyplot as plt
import itertools
import random

from numba import cuda
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

from tensorflow.keras.callbacks import  EarlyStopping

# %%
# tensorflow = 2.
# python = 3.6


seed = np.random.seed(777)

gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
    
  try:
      
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
      
  except RuntimeError as e:
      
    print(e)


val_loss_all = []

test_loss_all = []
test_acc_all = []
test_pre_all = []
frr_all = []
far_all = []

conf_matrix_sco = []
test_pre_sco = []
test_rec_sco = []
test_spedi_sco = []
test_sensi_sco = []

class MyModelCheckpoint(tf.keras.callbacks.ModelCheckpoint):

    def __init__(self, *args, **kwargs):
        super(MyModelCheckpoint, self).__init__(*args, **kwargs)

    # redefine the save so it only activates after 100 epochs
    def on_epoch_end(self, epoch, logs=None):
        if epoch >= 1: super(MyModelCheckpoint, self).on_epoch_end(epoch, logs)

# %%
train_data = scipy.io.loadmat('../../datas/160hz/train_5day_160hz.mat', squeeze_me=True)['data']
test_data = scipy.io.loadmat('../../datas/160hz/test_6day_160hz(2).mat', squeeze_me=True)['data']

# sub 수
sub_cnt = train_data.shape[0]

# 3sec 데이터 크기
data_size = 480

# 1명당 3초 데이터 개수
train_data_cnt = 1052
test_data_cnt = 211

# 3sec 480(= 160*3) 크기로 데이터 길이 설정
train_cut_size = 504960 # 480*1052 = 504960
test_cut_size = 101280 # 480*211 = 101280

# 3sec 데이터 길이 자르기
# train: 504,960 / test: 101,280
train_data = train_data[:,0:train_cut_size,:]
test_data = test_data[:,0:test_cut_size,:]

# flatten(): 3D -> 1D / reshape(-1,1): -1 마지막 인덱스
train_flatten = train_data.flatten().reshape(-1,1)
test_flatten = test_data.flatten().reshape(-1,1)

# StandardScaler(): train에 맞춰 표준화
data_scaler = StandardScaler()
    
data_scaler.fit(train_flatten)
train_scaler = data_scaler.transform(train_flatten)
test_scaler = data_scaler.transform(test_flatten)
    
# train, test 데이터 reshape
train_data = train_scaler.reshape(train_data_cnt * sub_cnt, data_size, 2) 
test_data = test_scaler.reshape(test_data_cnt * sub_cnt, data_size, 2)

#train data를 sub:other=1:1로 만들기 위해서 각 sub 추출
train_data_each = []
for i in range(sub_cnt):
    train_data_each.insert(i, train_data[i*train_data_cnt:(i+1)*train_data_cnt, :, :])
print(np.shape(train_data_each))

#test data를 sub:other=1:3로 만들기 위해서 각 sub 추출
test_data_each = []
for i in range(sub_cnt):
    test_data_each.insert(i, test_data[i*test_data_cnt:(i+1)*test_data_cnt, :, :])
print(np.shape(test_data_each))
# Out:
# (11, 1052, 480, 2)
# (11, 211, 480, 2)

# %%
# sub number
sub_num = 5

#1 to 3 비율로 설정
ratio = 3

train_data_n = train_data_each[sub_num]
test_data_n = test_data_each[sub_num]

# train data를 sub:other = 1:3으로 만들기
# 3초 덩어리 개수 1052 : 3156
# => 315 * 4 + 316 * 6 = 1260 + 1896 = 3156

# test data를 sub:other = 1:3로 만들기
# 3초 덩어리 개수 211 : 633
# 63 * 7 + 64 * 3 = 633

cnt = 0
for j in range(sub_cnt):
    if j != sub_num and cnt < 4:
        cnt = cnt + 1
        train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 315)), axis = 0)
    elif j != sub_num and cnt >= 4:
        train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 316)), axis = 0)
#     print("train_data_n.shape")
#     print(train_data_n.shape)
#     print("train_data_n")
#     print(train_data_n)
        
cnt = 0
for j in range(sub_cnt):
    if j != sub_num and cnt < 7:
        cnt = cnt + 1
        test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 63)), axis = 0)
    elif j != sub_num and cnt >= 7:
        test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 64)), axis = 0)
        
        
        
train_label = np.zeros(train_data_cnt*(ratio+1))
test_label = np.zeros(test_data_cnt*(ratio+1))

for j in range(len(train_label)):
    if (j < train_data_cnt):
        train_label[j] = 1

for j in range(len(test_label)):
    if (j < test_data_cnt):
        test_label[j] = 1
        
train_data_shuffled, train_label_shuffled = sk.utils.shuffle(train_data_n, train_label, random_state = 0)

val_data_set = train_data_shuffled[:train_data_cnt]
train_data_set = train_data_shuffled[train_data_cnt:]

val_label_set = train_label_shuffled[:train_data_cnt]
train_label_set = train_label_shuffled[train_data_cnt:]

# %%
# model CNN-LSTM    
inputs = tf.keras.Input(shape = (480, 2))
conv_1 = tf.keras.layers.Conv1D(filters = 86, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(inputs)
max_1 = tf.keras.layers.MaxPool1D(3)(conv_1)
    
# conv_2 = tf.keras.layers.Conv1D(filters = 41, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(max_1)
# max_2 = tf.keras.layers.MaxPool1D(3)(conv_2)
    
# conv_3 = tf.keras.layers.Conv1D(filters = 27, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(max_2)
# max_3 = tf.keras.layers.MaxPool1D(3)(conv_3)
    

D_out_1 = tf.keras.layers.Dropout(0.5463367255390843)(max_1)
    
    
lstm_1 = tf.keras.layers.LSTM(154)(D_out_1)
    
dense_1 = tf.keras.layers.Dense(33, activation = 'relu')(lstm_1)
dense_2 = tf.keras.layers.Dense(59, activation = 'relu')(dense_1)
dense_3 = tf.keras.layers.Dense(1, activation = 'sigmoid')(dense_2)
    
model = tf.keras.models.Model(inputs = inputs, outputs = dense_3)

# Adam
model.compile(loss = 'binary_crossentropy', optimizer = tf.keras.optimizers.Adam(0.00025897385811766787), metrics = ['accuracy'])
# SGD
# model.compile(loss= 'binary_crossentropy', optimizer= tf.keras.optimizers.SGD(learning_rate=0.0461300729767683, momentum=0.4411297369087802), metrics=['accuracy'])
    
# EarlyStopping 조기종료 및 모델 학습
early_stopping = tf.keras.callbacks.EarlyStopping(patience = 20)
check_point = MyModelCheckpoint('best_model_' + str(sub_num + 1) + '.h5', monitor = 'val_loss', mode = 'min', save_best_only = True, verbose = 1)

# EarlyStopping 사용
hist = model.fit(train_data_set, train_label_set, epochs = 200, batch_size = 32, validation_data = (val_data_set, val_label_set), callbacks = [early_stopping, check_point])
# EarlyStopping 미사용
# hist = model.fit(train_data_set, train_label_set, epochs = 200, batch_size = 32, validation_data = (val_data_set, val_label_set), callbacks = [check_point])
        
# model save .h5형식
model = tf.keras.models.load_model('best_model_' + str(sub_num + 1) + '.h5')
model.save('Binary_BOHB_' + str(sub_num + 1) + '.h5')
model.summary() 
        
val_loss, val_acc = model.evaluate(val_data_set, val_label_set, verbose = 2)

test_loss, test_acc = model.evaluate(test_data_n, test_label, verbose = 2)
test_pred = model.predict(test_data_n)
        
    
# 각 행은 1sec, 0.5 <= 자신, 0.5 > 타인
for i in range(len(test_pred)):
    if(test_pred[i] >= 0.5):
        test_pred[i] = 1
    
    else: 
        test_pred[i] = 0
    
    
val_loss_all.append(val_loss)
    
test_loss_all.append(test_loss)
test_acc_all.append(test_acc)
test_pre_all.append(test_pred)
    

conf_matrix = confusion_matrix(test_label, test_pred) 
conf_matrix_sco.append(conf_matrix)
    
conf_row = conf_matrix.sum(axis = 1)
conf_col = conf_matrix.sum(axis = 0)

precision = conf_matrix[1][1] / conf_col[1]
recall = conf_matrix[1][1] / conf_row[1]
specificity = conf_matrix[0][0] / conf_row[0]
sensitivity = conf_matrix[1][1] / conf_row[1]
frr = conf_matrix[1][0] / (conf_matrix[1][1]+conf_matrix[1][0])
far = conf_matrix[0][1] / (conf_matrix[0][1]+conf_matrix[0][0])
    
frr_all.append(frr)
far_all.append(far)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111)

cax = ax.matshow(conf_matrix)

fig.colorbar(cax)

for i, j in itertools.product(range(conf_matrix.shape[0]), range(conf_matrix.shape[1])):
    plt.text(j, i, conf_matrix[i, j], color="white")

plt.title('CNN+LSTM model')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.show()
 
    
test_pre_sco.append(precision)
test_rec_sco.append(recall)
test_spedi_sco.append(specificity)
test_sensi_sco.append(sensitivity)
    
print('val_loss:', val_loss)
print('test_loss:', test_loss)
print('test_acc:', test_acc)
    
print('precision:', precision)
print('recall:', recall)
print('specificity', specificity)
print('sensitivity : ', sensitivity)
print('far', far)
print('frr', frr)
# Out:
# Epoch 1/200
# 99/99 [==============================] - 30s 304ms/step - loss: 0.4929 - accuracy: 0.7795 - val_loss: 0.5368 - val_accuracy: 0.8470
# Epoch 2/200
# 99/99 [==============================] - ETA: 0s - loss: 0.4470 - accuracy: 0.7925
# Epoch 00002: val_loss improved from inf to 0.35338, saving model to best_model_6.h5
# 99/99 [==============================] - 31s 311ms/step - loss: 0.4470 - accuracy: 0.7925 - val_loss: 0.3534 - val_accuracy: 0.8821
# Epoch 3/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3903 - accuracy: 0.8555
# Epoch 00003: val_loss improved from 0.35338 to 0.30197, saving model to best_model_6.h5
# 99/99 [==============================] - 30s 308ms/step - loss: 0.3903 - accuracy: 0.8555 - val_loss: 0.3020 - val_accuracy: 0.8641
# Epoch 4/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2939 - accuracy: 0.8587
# Epoch 00004: val_loss improved from 0.30197 to 0.26397, saving model to best_model_6.h5
# 99/99 [==============================] - 30s 306ms/step - loss: 0.2939 - accuracy: 0.8587 - val_loss: 0.2640 - val_accuracy: 0.8650
# Epoch 5/200
# 99/99 [==============================] - ETA: 0s - loss: 0.4424 - accuracy: 0.7677
# Epoch 00005: val_loss did not improve from 0.26397
# 99/99 [==============================] - 31s 313ms/step - loss: 0.4424 - accuracy: 0.7677 - val_loss: 0.6365 - val_accuracy: 0.7367
# Epoch 6/200
# 99/99 [==============================] - ETA: 0s - loss: 0.5112 - accuracy: 0.7776
# Epoch 00006: val_loss did not improve from 0.26397
# 99/99 [==============================] - 32s 323ms/step - loss: 0.5112 - accuracy: 0.7776 - val_loss: 0.4219 - val_accuracy: 0.8584
# Epoch 7/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2894 - accuracy: 0.8568
# Epoch 00007: val_loss improved from 0.26397 to 0.24315, saving model to best_model_6.h5
# 99/99 [==============================] - 32s 324ms/step - loss: 0.2894 - accuracy: 0.8568 - val_loss: 0.2431 - val_accuracy: 0.8945
# Epoch 8/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2466 - accuracy: 0.8777
# Epoch 00008: val_loss improved from 0.24315 to 0.21261, saving model to best_model_6.h5
# 99/99 [==============================] - 31s 316ms/step - loss: 0.2466 - accuracy: 0.8777 - val_loss: 0.2126 - val_accuracy: 0.9021
# Epoch 9/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.8954
# Epoch 00009: val_loss did not improve from 0.21261
# 99/99 [==============================] - 29s 292ms/step - loss: 0.2399 - accuracy: 0.8954 - val_loss: 0.2139 - val_accuracy: 0.9011
# Epoch 10/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.8913
# Epoch 00010: val_loss did not improve from 0.21261
# 99/99 [==============================] - 30s 300ms/step - loss: 0.2428 - accuracy: 0.8913 - val_loss: 0.2189 - val_accuracy: 0.9030
# Epoch 11/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2330 - accuracy: 0.8881
# Epoch 00011: val_loss did not improve from 0.21261
# 99/99 [==============================] - 31s 312ms/step - loss: 0.2330 - accuracy: 0.8881 - val_loss: 0.2168 - val_accuracy: 0.9116
# Epoch 12/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2189 - accuracy: 0.9024
# Epoch 00012: val_loss improved from 0.21261 to 0.20987, saving model to best_model_6.h5
# 99/99 [==============================] - 32s 319ms/step - loss: 0.2189 - accuracy: 0.9024 - val_loss: 0.2099 - val_accuracy: 0.9154
# Epoch 13/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2171 - accuracy: 0.9053
# Epoch 00013: val_loss improved from 0.20987 to 0.19490, saving model to best_model_6.h5
# 99/99 [==============================] - 28s 285ms/step - loss: 0.2171 - accuracy: 0.9053 - val_loss: 0.1949 - val_accuracy: 0.9116
# Epoch 14/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.8999
# Epoch 00014: val_loss did not improve from 0.19490
# 99/99 [==============================] - 26s 264ms/step - loss: 0.2117 - accuracy: 0.8999 - val_loss: 0.2266 - val_accuracy: 0.9030
# Epoch 15/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2136 - accuracy: 0.9011
# Epoch 00015: val_loss did not improve from 0.19490
# 99/99 [==============================] - 29s 292ms/step - loss: 0.2136 - accuracy: 0.9011 - val_loss: 0.2013 - val_accuracy: 0.9144
# Epoch 16/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2051 - accuracy: 0.9011
# Epoch 00016: val_loss did not improve from 0.19490
# 99/99 [==============================] - 30s 299ms/step - loss: 0.2051 - accuracy: 0.9011 - val_loss: 0.1975 - val_accuracy: 0.9125
# Epoch 17/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 0.9087
# Epoch 00017: val_loss did not improve from 0.19490
# 99/99 [==============================] - 30s 299ms/step - loss: 0.1974 - accuracy: 0.9087 - val_loss: 0.2032 - val_accuracy: 0.9125
# Epoch 18/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.8977
# Epoch 00018: val_loss did not improve from 0.19490
# 99/99 [==============================] - 30s 300ms/step - loss: 0.2208 - accuracy: 0.8977 - val_loss: 0.2074 - val_accuracy: 0.9097
# Epoch 19/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9043
# Epoch 00019: val_loss did not improve from 0.19490
# 99/99 [==============================] - 32s 319ms/step - loss: 0.1980 - accuracy: 0.9043 - val_loss: 0.2099 - val_accuracy: 0.9125
# Epoch 20/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2016 - accuracy: 0.9056
# Epoch 00020: val_loss did not improve from 0.19490
# 99/99 [==============================] - 30s 307ms/step - loss: 0.2016 - accuracy: 0.9056 - val_loss: 0.2180 - val_accuracy: 0.9021
# Epoch 21/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1989 - accuracy: 0.9053
# Epoch 00021: val_loss did not improve from 0.19490
# 99/99 [==============================] - 33s 332ms/step - loss: 0.1989 - accuracy: 0.9053 - val_loss: 0.1954 - val_accuracy: 0.9106
# Epoch 22/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1915 - accuracy: 0.9135
# Epoch 00022: val_loss improved from 0.19490 to 0.19038, saving model to best_model_6.h5
# 99/99 [==============================] - 30s 307ms/step - loss: 0.1915 - accuracy: 0.9135 - val_loss: 0.1904 - val_accuracy: 0.9059
# Epoch 23/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1965 - accuracy: 0.9056
# Epoch 00023: val_loss did not improve from 0.19038
# 99/99 [==============================] - 32s 320ms/step - loss: 0.1965 - accuracy: 0.9056 - val_loss: 0.1940 - val_accuracy: 0.9144
# Epoch 24/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1943 - accuracy: 0.9046
# Epoch 00024: val_loss improved from 0.19038 to 0.18473, saving model to best_model_6.h5
# 99/99 [==============================] - 32s 322ms/step - loss: 0.1943 - accuracy: 0.9046 - val_loss: 0.1847 - val_accuracy: 0.9144
# Epoch 25/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1926 - accuracy: 0.9110
# Epoch 00025: val_loss improved from 0.18473 to 0.18455, saving model to best_model_6.h5
# 99/99 [==============================] - 32s 323ms/step - loss: 0.1926 - accuracy: 0.9110 - val_loss: 0.1845 - val_accuracy: 0.9192
# Epoch 26/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2025 - accuracy: 0.9084
# Epoch 00026: val_loss did not improve from 0.18455
# 99/99 [==============================] - 32s 323ms/step - loss: 0.2025 - accuracy: 0.9084 - val_loss: 0.2302 - val_accuracy: 0.9040
# Epoch 27/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1978 - accuracy: 0.9075
# Epoch 00027: val_loss did not improve from 0.18455
# 99/99 [==============================] - 32s 319ms/step - loss: 0.1978 - accuracy: 0.9075 - val_loss: 0.1927 - val_accuracy: 0.9125
# Epoch 28/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1912 - accuracy: 0.9091
# Epoch 00028: val_loss did not improve from 0.18455
# 99/99 [==============================] - 28s 281ms/step - loss: 0.1912 - accuracy: 0.9091 - val_loss: 0.1915 - val_accuracy: 0.9135
# Epoch 29/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1896 - accuracy: 0.9072
# Epoch 00029: val_loss did not improve from 0.18455
# 99/99 [==============================] - 27s 276ms/step - loss: 0.1896 - accuracy: 0.9072 - val_loss: 0.2028 - val_accuracy: 0.9163
# Epoch 30/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2050 - accuracy: 0.9018
# Epoch 00030: val_loss did not improve from 0.18455
# 99/99 [==============================] - 28s 287ms/step - loss: 0.2050 - accuracy: 0.9018 - val_loss: 0.2155 - val_accuracy: 0.9068
# Epoch 31/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1885 - accuracy: 0.9100
# Epoch 00031: val_loss did not improve from 0.18455
# 99/99 [==============================] - 28s 278ms/step - loss: 0.1885 - accuracy: 0.9100 - val_loss: 0.1875 - val_accuracy: 0.9163
# Epoch 32/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1888 - accuracy: 0.9154
# Epoch 00032: val_loss improved from 0.18455 to 0.17718, saving model to best_model_6.h5
# 99/99 [==============================] - 27s 270ms/step - loss: 0.1888 - accuracy: 0.9154 - val_loss: 0.1772 - val_accuracy: 0.9144
# Epoch 33/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9056
# Epoch 00033: val_loss did not improve from 0.17718
# 99/99 [==============================] - 25s 256ms/step - loss: 0.1889 - accuracy: 0.9056 - val_loss: 0.1891 - val_accuracy: 0.9116
# Epoch 34/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1917 - accuracy: 0.9091
# Epoch 00034: val_loss did not improve from 0.17718
# 99/99 [==============================] - 27s 271ms/step - loss: 0.1917 - accuracy: 0.9091 - val_loss: 0.2118 - val_accuracy: 0.9116
# Epoch 35/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1928 - accuracy: 0.9094
# Epoch 00035: val_loss did not improve from 0.17718
# 99/99 [==============================] - 27s 272ms/step - loss: 0.1928 - accuracy: 0.9094 - val_loss: 0.2006 - val_accuracy: 0.9087
# Epoch 36/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.9110
# Epoch 00036: val_loss did not improve from 0.17718
# 99/99 [==============================] - 27s 273ms/step - loss: 0.1892 - accuracy: 0.9110 - val_loss: 0.2256 - val_accuracy: 0.9087
# Epoch 37/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1808 - accuracy: 0.9154
# Epoch 00037: val_loss did not improve from 0.17718
# 99/99 [==============================] - 26s 265ms/step - loss: 0.1808 - accuracy: 0.9154 - val_loss: 0.1816 - val_accuracy: 0.9106
# Epoch 38/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1869 - accuracy: 0.9125
# Epoch 00038: val_loss did not improve from 0.17718
# 99/99 [==============================] - 25s 251ms/step - loss: 0.1869 - accuracy: 0.9125 - val_loss: 0.1913 - val_accuracy: 0.9173
# Epoch 39/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1904 - accuracy: 0.9068
# Epoch 00039: val_loss did not improve from 0.17718
# 99/99 [==============================] - 25s 250ms/step - loss: 0.1904 - accuracy: 0.9068 - val_loss: 0.1950 - val_accuracy: 0.9144
# Epoch 40/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1772 - accuracy: 0.9116
# Epoch 00040: val_loss did not improve from 0.17718
# 99/99 [==============================] - 24s 242ms/step - loss: 0.1772 - accuracy: 0.9116 - val_loss: 0.1900 - val_accuracy: 0.9135
# Epoch 41/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1705 - accuracy: 0.9202
# Epoch 00041: val_loss did not improve from 0.17718
# 99/99 [==============================] - 24s 242ms/step - loss: 0.1705 - accuracy: 0.9202 - val_loss: 0.1786 - val_accuracy: 0.9116
# Epoch 42/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1813 - accuracy: 0.9144
# Epoch 00042: val_loss did not improve from 0.17718
# 99/99 [==============================] - 25s 255ms/step - loss: 0.1813 - accuracy: 0.9144 - val_loss: 0.2074 - val_accuracy: 0.8983
# Epoch 43/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1734 - accuracy: 0.9154
# Epoch 00043: val_loss improved from 0.17718 to 0.17320, saving model to best_model_6.h5
# 99/99 [==============================] - 25s 256ms/step - loss: 0.1734 - accuracy: 0.9154 - val_loss: 0.1732 - val_accuracy: 0.9144
# Epoch 44/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1759 - accuracy: 0.9170
# Epoch 00044: val_loss did not improve from 0.17320
# 99/99 [==============================] - 26s 260ms/step - loss: 0.1759 - accuracy: 0.9170 - val_loss: 0.1746 - val_accuracy: 0.9163
# Epoch 45/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1753 - accuracy: 0.9173
# Epoch 00045: val_loss did not improve from 0.17320
# 99/99 [==============================] - 24s 246ms/step - loss: 0.1753 - accuracy: 0.9173 - val_loss: 0.1903 - val_accuracy: 0.9183
# Epoch 46/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1791 - accuracy: 0.9186
# Epoch 00046: val_loss improved from 0.17320 to 0.17126, saving model to best_model_6.h5
# 99/99 [==============================] - 25s 252ms/step - loss: 0.1791 - accuracy: 0.9186 - val_loss: 0.1713 - val_accuracy: 0.9287
# Epoch 47/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2248 - accuracy: 0.8862
# Epoch 00047: val_loss did not improve from 0.17126
# 99/99 [==============================] - 27s 277ms/step - loss: 0.2248 - accuracy: 0.8862 - val_loss: 0.2302 - val_accuracy: 0.9097
# Epoch 48/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1969 - accuracy: 0.9075
# Epoch 00048: val_loss did not improve from 0.17126
# 99/99 [==============================] - 28s 285ms/step - loss: 0.1969 - accuracy: 0.9075 - val_loss: 0.2027 - val_accuracy: 0.9125
# Epoch 49/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1914 - accuracy: 0.9122
# Epoch 00049: val_loss did not improve from 0.17126
# 99/99 [==============================] - 29s 291ms/step - loss: 0.1914 - accuracy: 0.9122 - val_loss: 0.2036 - val_accuracy: 0.9144
# Epoch 50/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1774 - accuracy: 0.9151
# Epoch 00050: val_loss did not improve from 0.17126
# 99/99 [==============================] - 27s 271ms/step - loss: 0.1774 - accuracy: 0.9151 - val_loss: 0.1926 - val_accuracy: 0.9144
# Epoch 51/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1885 - accuracy: 0.9192
# Epoch 00051: val_loss did not improve from 0.17126
# 99/99 [==============================] - 26s 265ms/step - loss: 0.1885 - accuracy: 0.9192 - val_loss: 0.1741 - val_accuracy: 0.9202
# Epoch 52/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1737 - accuracy: 0.9192
# Epoch 00052: val_loss did not improve from 0.17126
# 99/99 [==============================] - 26s 260ms/step - loss: 0.1737 - accuracy: 0.9192 - val_loss: 0.1876 - val_accuracy: 0.9125
# Epoch 53/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1812 - accuracy: 0.9214
# Epoch 00053: val_loss did not improve from 0.17126
# 99/99 [==============================] - 26s 265ms/step - loss: 0.1812 - accuracy: 0.9214 - val_loss: 0.1759 - val_accuracy: 0.9211
# Epoch 54/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1584 - accuracy: 0.9176
# Epoch 00054: val_loss improved from 0.17126 to 0.16401, saving model to best_model_6.h5
# 99/99 [==============================] - 26s 262ms/step - loss: 0.1584 - accuracy: 0.9176 - val_loss: 0.1640 - val_accuracy: 0.9230
# Epoch 55/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1559 - accuracy: 0.9214
# Epoch 00055: val_loss did not improve from 0.16401
# 99/99 [==============================] - 26s 259ms/step - loss: 0.1559 - accuracy: 0.9214 - val_loss: 0.1695 - val_accuracy: 0.9230
# Epoch 56/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1604 - accuracy: 0.9224
# Epoch 00056: val_loss did not improve from 0.16401
# 99/99 [==============================] - 25s 250ms/step - loss: 0.1604 - accuracy: 0.9224 - val_loss: 0.1677 - val_accuracy: 0.9116
# Epoch 57/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1612 - accuracy: 0.9179
# Epoch 00057: val_loss did not improve from 0.16401
# 99/99 [==============================] - 29s 292ms/step - loss: 0.1612 - accuracy: 0.9179 - val_loss: 0.1649 - val_accuracy: 0.9221
# Epoch 58/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1604 - accuracy: 0.9224
# Epoch 00058: val_loss did not improve from 0.16401
# 99/99 [==============================] - 28s 283ms/step - loss: 0.1604 - accuracy: 0.9224 - val_loss: 0.1751 - val_accuracy: 0.9135
# Epoch 59/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1538 - accuracy: 0.9255
# Epoch 00059: val_loss did not improve from 0.16401
# 99/99 [==============================] - 28s 286ms/step - loss: 0.1538 - accuracy: 0.9255 - val_loss: 0.1668 - val_accuracy: 0.9211
# Epoch 60/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1514 - accuracy: 0.9287
# Epoch 00060: val_loss did not improve from 0.16401
# 99/99 [==============================] - 27s 277ms/step - loss: 0.1514 - accuracy: 0.9287 - val_loss: 0.1694 - val_accuracy: 0.9154
# Epoch 61/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.9255
# Epoch 00061: val_loss did not improve from 0.16401
# 99/99 [==============================] - 28s 283ms/step - loss: 0.1525 - accuracy: 0.9255 - val_loss: 0.1837 - val_accuracy: 0.9106
# Epoch 62/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1466 - accuracy: 0.9312
# Epoch 00062: val_loss improved from 0.16401 to 0.14470, saving model to best_model_6.h5
# 99/99 [==============================] - 29s 296ms/step - loss: 0.1466 - accuracy: 0.9312 - val_loss: 0.1447 - val_accuracy: 0.9335
# Epoch 63/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1372 - accuracy: 0.9357
# Epoch 00063: val_loss did not improve from 0.14470
# 99/99 [==============================] - 28s 285ms/step - loss: 0.1372 - accuracy: 0.9357 - val_loss: 0.1495 - val_accuracy: 0.9316
# Epoch 64/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1507 - accuracy: 0.9325
# Epoch 00064: val_loss did not improve from 0.14470
# 99/99 [==============================] - 29s 292ms/step - loss: 0.1507 - accuracy: 0.9325 - val_loss: 0.1502 - val_accuracy: 0.9316
# Epoch 65/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1451 - accuracy: 0.9344
# Epoch 00065: val_loss improved from 0.14470 to 0.13906, saving model to best_model_6.h5
# 99/99 [==============================] - 28s 288ms/step - loss: 0.1451 - accuracy: 0.9344 - val_loss: 0.1391 - val_accuracy: 0.9363
# Epoch 66/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9388
# Epoch 00066: val_loss improved from 0.13906 to 0.13077, saving model to best_model_6.h5
# 99/99 [==============================] - 28s 287ms/step - loss: 0.1356 - accuracy: 0.9388 - val_loss: 0.1308 - val_accuracy: 0.9392
# Epoch 67/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1484 - accuracy: 0.9274
# Epoch 00067: val_loss did not improve from 0.13077
# 99/99 [==============================] - 29s 295ms/step - loss: 0.1484 - accuracy: 0.9274 - val_loss: 0.1863 - val_accuracy: 0.9287
# Epoch 68/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9335
# Epoch 00068: val_loss did not improve from 0.13077
# 99/99 [==============================] - 29s 296ms/step - loss: 0.1426 - accuracy: 0.9335 - val_loss: 0.1474 - val_accuracy: 0.9382
# Epoch 69/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1491 - accuracy: 0.9297
# Epoch 00069: val_loss did not improve from 0.13077
# 99/99 [==============================] - 28s 285ms/step - loss: 0.1491 - accuracy: 0.9297 - val_loss: 0.1793 - val_accuracy: 0.9297
# Epoch 70/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 0.9360
# Epoch 00070: val_loss improved from 0.13077 to 0.12974, saving model to best_model_6.h5
# 99/99 [==============================] - 29s 290ms/step - loss: 0.1358 - accuracy: 0.9360 - val_loss: 0.1297 - val_accuracy: 0.9477
# Epoch 71/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1335 - accuracy: 0.9382
# Epoch 00071: val_loss did not improve from 0.12974
# 99/99 [==============================] - 28s 282ms/step - loss: 0.1335 - accuracy: 0.9382 - val_loss: 0.1300 - val_accuracy: 0.9420
# Epoch 72/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9246
# Epoch 00072: val_loss did not improve from 0.12974
# 99/99 [==============================] - 29s 289ms/step - loss: 0.1483 - accuracy: 0.9246 - val_loss: 0.2180 - val_accuracy: 0.8945
# Epoch 73/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1401 - accuracy: 0.9379
# Epoch 00073: val_loss did not improve from 0.12974
# 99/99 [==============================] - 29s 297ms/step - loss: 0.1401 - accuracy: 0.9379 - val_loss: 0.1540 - val_accuracy: 0.9382
# Epoch 74/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.9468
# Epoch 00074: val_loss improved from 0.12974 to 0.11705, saving model to best_model_6.h5
# 99/99 [==============================] - 29s 288ms/step - loss: 0.1216 - accuracy: 0.9468 - val_loss: 0.1171 - val_accuracy: 0.9458
# Epoch 75/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1154 - accuracy: 0.9487
# Epoch 00075: val_loss did not improve from 0.11705
# 99/99 [==============================] - 29s 288ms/step - loss: 0.1154 - accuracy: 0.9487 - val_loss: 0.1336 - val_accuracy: 0.9354
# Epoch 76/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1285 - accuracy: 0.9490
# Epoch 00076: val_loss did not improve from 0.11705
# 99/99 [==============================] - 28s 286ms/step - loss: 0.1285 - accuracy: 0.9490 - val_loss: 0.1314 - val_accuracy: 0.9506
# Epoch 77/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1259 - accuracy: 0.9490
# Epoch 00077: val_loss did not improve from 0.11705
# 99/99 [==============================] - 29s 293ms/step - loss: 0.1259 - accuracy: 0.9490 - val_loss: 0.1285 - val_accuracy: 0.9411
# Epoch 78/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1191 - accuracy: 0.9522
# Epoch 00078: val_loss improved from 0.11705 to 0.11188, saving model to best_model_6.h5
# 99/99 [==============================] - 30s 301ms/step - loss: 0.1191 - accuracy: 0.9522 - val_loss: 0.1119 - val_accuracy: 0.9572
# Epoch 79/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1159 - accuracy: 0.9484
# Epoch 00079: val_loss improved from 0.11188 to 0.11186, saving model to best_model_6.h5
# 99/99 [==============================] - 30s 304ms/step - loss: 0.1159 - accuracy: 0.9484 - val_loss: 0.1119 - val_accuracy: 0.9572
# Epoch 80/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1129 - accuracy: 0.9522
# Epoch 00080: val_loss did not improve from 0.11186
# 99/99 [==============================] - 32s 319ms/step - loss: 0.1129 - accuracy: 0.9522 - val_loss: 0.1250 - val_accuracy: 0.9563
# Epoch 81/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1181 - accuracy: 0.9484
# Epoch 00081: val_loss improved from 0.11186 to 0.08430, saving model to best_model_6.h5
# 99/99 [==============================] - 31s 316ms/step - loss: 0.1181 - accuracy: 0.9484 - val_loss: 0.0843 - val_accuracy: 0.9705
# Epoch 82/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1195 - accuracy: 0.9458
# Epoch 00082: val_loss did not improve from 0.08430
# 99/99 [==============================] - 29s 296ms/step - loss: 0.1195 - accuracy: 0.9458 - val_loss: 0.1162 - val_accuracy: 0.9591
# Epoch 83/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1162 - accuracy: 0.9503
# Epoch 00083: val_loss did not improve from 0.08430
# 99/99 [==============================] - 28s 284ms/step - loss: 0.1162 - accuracy: 0.9503 - val_loss: 0.1005 - val_accuracy: 0.9620
# Epoch 84/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1180 - accuracy: 0.9525
# Epoch 00084: val_loss did not improve from 0.08430
# 99/99 [==============================] - 28s 284ms/step - loss: 0.1180 - accuracy: 0.9525 - val_loss: 0.1587 - val_accuracy: 0.9382
# Epoch 85/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1309 - accuracy: 0.9461
# Epoch 00085: val_loss did not improve from 0.08430
# 99/99 [==============================] - 28s 283ms/step - loss: 0.1309 - accuracy: 0.9461 - val_loss: 0.1046 - val_accuracy: 0.9610
# Epoch 86/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1148 - accuracy: 0.9531
# Epoch 00086: val_loss did not improve from 0.08430
# 99/99 [==============================] - 29s 291ms/step - loss: 0.1148 - accuracy: 0.9531 - val_loss: 0.0905 - val_accuracy: 0.9667
# Epoch 87/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1050 - accuracy: 0.9572
# Epoch 00087: val_loss did not improve from 0.08430
# 99/99 [==============================] - 29s 293ms/step - loss: 0.1050 - accuracy: 0.9572 - val_loss: 0.1056 - val_accuracy: 0.9553
# Epoch 88/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1121 - accuracy: 0.9518
# Epoch 00088: val_loss did not improve from 0.08430
# 99/99 [==============================] - 27s 278ms/step - loss: 0.1121 - accuracy: 0.9518 - val_loss: 0.1011 - val_accuracy: 0.9639
# Epoch 89/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1041 - accuracy: 0.9531
# Epoch 00089: val_loss did not improve from 0.08430
# 99/99 [==============================] - 26s 267ms/step - loss: 0.1041 - accuracy: 0.9531 - val_loss: 0.0883 - val_accuracy: 0.9667
# Epoch 90/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.9617
# Epoch 00090: val_loss did not improve from 0.08430
# 99/99 [==============================] - 26s 260ms/step - loss: 0.0946 - accuracy: 0.9617 - val_loss: 0.0955 - val_accuracy: 0.9610
# Epoch 91/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0975 - accuracy: 0.9594
# Epoch 00091: val_loss did not improve from 0.08430
# 99/99 [==============================] - 26s 262ms/step - loss: 0.0975 - accuracy: 0.9594 - val_loss: 0.0892 - val_accuracy: 0.9648
# Epoch 92/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0952 - accuracy: 0.9591
# Epoch 00092: val_loss did not improve from 0.08430
# 99/99 [==============================] - 27s 276ms/step - loss: 0.0952 - accuracy: 0.9591 - val_loss: 0.0998 - val_accuracy: 0.9610
# Epoch 93/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1073 - accuracy: 0.9541
# Epoch 00093: val_loss did not improve from 0.08430
# 99/99 [==============================] - 28s 286ms/step - loss: 0.1073 - accuracy: 0.9541 - val_loss: 0.0934 - val_accuracy: 0.9648
# Epoch 94/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0923 - accuracy: 0.9617
# Epoch 00094: val_loss did not improve from 0.08430
# 99/99 [==============================] - 28s 282ms/step - loss: 0.0923 - accuracy: 0.9617 - val_loss: 0.0978 - val_accuracy: 0.9639
# Epoch 95/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0976 - accuracy: 0.9591
# Epoch 00095: val_loss did not improve from 0.08430
# 99/99 [==============================] - 27s 268ms/step - loss: 0.0976 - accuracy: 0.9591 - val_loss: 0.0939 - val_accuracy: 0.9648
# Epoch 96/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0966 - accuracy: 0.9588
# Epoch 00096: val_loss improved from 0.08430 to 0.08264, saving model to best_model_6.h5
# 99/99 [==============================] - 27s 275ms/step - loss: 0.0966 - accuracy: 0.9588 - val_loss: 0.0826 - val_accuracy: 0.9696
# Epoch 97/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0856 - accuracy: 0.9680
# Epoch 00097: val_loss improved from 0.08264 to 0.07276, saving model to best_model_6.h5
# 99/99 [==============================] - 25s 256ms/step - loss: 0.0856 - accuracy: 0.9680 - val_loss: 0.0728 - val_accuracy: 0.9715
# Epoch 98/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0807 - accuracy: 0.9683
# Epoch 00098: val_loss did not improve from 0.07276
# 99/99 [==============================] - 25s 253ms/step - loss: 0.0807 - accuracy: 0.9683 - val_loss: 0.0878 - val_accuracy: 0.9696
# Epoch 99/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0957 - accuracy: 0.9594
# Epoch 00099: val_loss did not improve from 0.07276
# 99/99 [==============================] - 26s 259ms/step - loss: 0.0957 - accuracy: 0.9594 - val_loss: 0.0897 - val_accuracy: 0.9667
# Epoch 100/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0905 - accuracy: 0.9651
# Epoch 00100: val_loss did not improve from 0.07276
# 99/99 [==============================] - 25s 254ms/step - loss: 0.0905 - accuracy: 0.9651 - val_loss: 0.1240 - val_accuracy: 0.9487
# Epoch 101/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0894 - accuracy: 0.9620
# Epoch 00101: val_loss did not improve from 0.07276
# 99/99 [==============================] - 26s 259ms/step - loss: 0.0894 - accuracy: 0.9620 - val_loss: 0.0935 - val_accuracy: 0.9610
# Epoch 102/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0887 - accuracy: 0.9604
# Epoch 00102: val_loss did not improve from 0.07276
# 99/99 [==============================] - 27s 268ms/step - loss: 0.0887 - accuracy: 0.9604 - val_loss: 0.0978 - val_accuracy: 0.9620
# Epoch 103/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0887 - accuracy: 0.9661
# Epoch 00103: val_loss did not improve from 0.07276
# 99/99 [==============================] - 26s 266ms/step - loss: 0.0887 - accuracy: 0.9661 - val_loss: 0.1804 - val_accuracy: 0.9278
# Epoch 104/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0919 - accuracy: 0.9636
# Epoch 00104: val_loss did not improve from 0.07276
# 99/99 [==============================] - 26s 268ms/step - loss: 0.0919 - accuracy: 0.9636 - val_loss: 0.0899 - val_accuracy: 0.9639
# Epoch 105/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9683
# Epoch 00105: val_loss did not improve from 0.07276
# 99/99 [==============================] - 26s 262ms/step - loss: 0.0779 - accuracy: 0.9683 - val_loss: 0.0728 - val_accuracy: 0.9686
# Epoch 106/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0841 - accuracy: 0.9658
# Epoch 00106: val_loss did not improve from 0.07276
# 99/99 [==============================] - 26s 258ms/step - loss: 0.0841 - accuracy: 0.9658 - val_loss: 0.0794 - val_accuracy: 0.9734
# Epoch 107/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9724
# Epoch 00107: val_loss did not improve from 0.07276
# 99/99 [==============================] - 26s 261ms/step - loss: 0.0752 - accuracy: 0.9724 - val_loss: 0.0807 - val_accuracy: 0.9724
# Epoch 108/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1035 - accuracy: 0.9594
# Epoch 00108: val_loss did not improve from 0.07276
# 99/99 [==============================] - 25s 253ms/step - loss: 0.1035 - accuracy: 0.9594 - val_loss: 0.1960 - val_accuracy: 0.9278
# Epoch 109/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1143 - accuracy: 0.9506
# Epoch 00109: val_loss did not improve from 0.07276
# 99/99 [==============================] - 26s 262ms/step - loss: 0.1143 - accuracy: 0.9506 - val_loss: 0.1191 - val_accuracy: 0.9572
# Epoch 110/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0843 - accuracy: 0.9664
# Epoch 00110: val_loss did not improve from 0.07276
# 99/99 [==============================] - 26s 262ms/step - loss: 0.0843 - accuracy: 0.9664 - val_loss: 0.0813 - val_accuracy: 0.9658
# Epoch 111/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9655
# Epoch 00111: val_loss improved from 0.07276 to 0.06716, saving model to best_model_6.h5
# 99/99 [==============================] - 26s 264ms/step - loss: 0.0851 - accuracy: 0.9655 - val_loss: 0.0672 - val_accuracy: 0.9734
# Epoch 112/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0856 - accuracy: 0.9661
# Epoch 00112: val_loss did not improve from 0.06716
# 99/99 [==============================] - 25s 256ms/step - loss: 0.0856 - accuracy: 0.9661 - val_loss: 0.0849 - val_accuracy: 0.9601
# Epoch 113/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9661
# Epoch 00113: val_loss did not improve from 0.06716
# 99/99 [==============================] - 26s 259ms/step - loss: 0.0862 - accuracy: 0.9661 - val_loss: 0.0775 - val_accuracy: 0.9753
# Epoch 114/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1000 - accuracy: 0.9617
# Epoch 00114: val_loss did not improve from 0.06716
# 99/99 [==============================] - 25s 249ms/step - loss: 0.1000 - accuracy: 0.9617 - val_loss: 0.0962 - val_accuracy: 0.9610
# Epoch 115/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0773 - accuracy: 0.9693
# Epoch 00115: val_loss did not improve from 0.06716
# 99/99 [==============================] - 26s 264ms/step - loss: 0.0773 - accuracy: 0.9693 - val_loss: 0.0881 - val_accuracy: 0.9667
# Epoch 116/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0865 - accuracy: 0.9642
# Epoch 00116: val_loss did not improve from 0.06716
# 99/99 [==============================] - 26s 258ms/step - loss: 0.0865 - accuracy: 0.9642 - val_loss: 0.0940 - val_accuracy: 0.9648
# Epoch 117/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9718
# Epoch 00117: val_loss did not improve from 0.06716
# 99/99 [==============================] - 26s 266ms/step - loss: 0.0744 - accuracy: 0.9718 - val_loss: 0.1039 - val_accuracy: 0.9572
# Epoch 118/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0740 - accuracy: 0.9731
# Epoch 00118: val_loss did not improve from 0.06716
# 99/99 [==============================] - 26s 259ms/step - loss: 0.0740 - accuracy: 0.9731 - val_loss: 0.0766 - val_accuracy: 0.9753
# Epoch 119/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9699
# Epoch 00119: val_loss did not improve from 0.06716
# 99/99 [==============================] - 25s 256ms/step - loss: 0.0776 - accuracy: 0.9699 - val_loss: 0.0701 - val_accuracy: 0.9724
# Epoch 120/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0787 - accuracy: 0.9696
# Epoch 00120: val_loss did not improve from 0.06716
# 99/99 [==============================] - 26s 260ms/step - loss: 0.0787 - accuracy: 0.9696 - val_loss: 0.1090 - val_accuracy: 0.9591
# Epoch 121/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.9699
# Epoch 00121: val_loss did not improve from 0.06716
# 99/99 [==============================] - 26s 260ms/step - loss: 0.0828 - accuracy: 0.9699 - val_loss: 0.1147 - val_accuracy: 0.9534
# Epoch 122/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0777 - accuracy: 0.9724
# Epoch 00122: val_loss did not improve from 0.06716
# 99/99 [==============================] - 25s 258ms/step - loss: 0.0777 - accuracy: 0.9724 - val_loss: 0.1315 - val_accuracy: 0.9610
# Epoch 123/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0794 - accuracy: 0.9693
# Epoch 00123: val_loss did not improve from 0.06716
# 99/99 [==============================] - 25s 251ms/step - loss: 0.0794 - accuracy: 0.9693 - val_loss: 0.0838 - val_accuracy: 0.9677
# Epoch 124/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9708
# Epoch 00124: val_loss did not improve from 0.06716
# 99/99 [==============================] - 25s 253ms/step - loss: 0.0677 - accuracy: 0.9708 - val_loss: 0.0785 - val_accuracy: 0.9705
# Epoch 125/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9667
# Epoch 00125: val_loss did not improve from 0.06716
# 99/99 [==============================] - 26s 260ms/step - loss: 0.0801 - accuracy: 0.9667 - val_loss: 0.1029 - val_accuracy: 0.9620
# Epoch 126/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0699 - accuracy: 0.9715
# Epoch 00126: val_loss did not improve from 0.06716
# 99/99 [==============================] - 24s 243ms/step - loss: 0.0699 - accuracy: 0.9715 - val_loss: 0.0728 - val_accuracy: 0.9724
# Epoch 127/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0901 - accuracy: 0.9613
# Epoch 00127: val_loss did not improve from 0.06716
# 99/99 [==============================] - 25s 256ms/step - loss: 0.0901 - accuracy: 0.9613 - val_loss: 0.1057 - val_accuracy: 0.9572
# Epoch 128/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0818 - accuracy: 0.9708
# Epoch 00128: val_loss did not improve from 0.06716
# 99/99 [==============================] - 26s 258ms/step - loss: 0.0818 - accuracy: 0.9708 - val_loss: 0.0885 - val_accuracy: 0.9677
# Epoch 129/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0740 - accuracy: 0.9702
# Epoch 00129: val_loss did not improve from 0.06716
# 99/99 [==============================] - 25s 251ms/step - loss: 0.0740 - accuracy: 0.9702 - val_loss: 0.0736 - val_accuracy: 0.9715
# Epoch 130/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.9718
# Epoch 00130: val_loss did not improve from 0.06716
# 99/99 [==============================] - 25s 254ms/step - loss: 0.0733 - accuracy: 0.9718 - val_loss: 0.0895 - val_accuracy: 0.9667
# Epoch 131/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0715 - accuracy: 0.9753
# Epoch 00131: val_loss did not improve from 0.06716
# 99/99 [==============================] - 24s 245ms/step - loss: 0.0715 - accuracy: 0.9753 - val_loss: 0.0937 - val_accuracy: 0.9629
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 480, 86)           602
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 160, 86)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 160, 86)           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 154)               148456
# _________________________________________________________________
# dense (Dense)                (None, 33)                5115
# _________________________________________________________________
# dense_1 (Dense)              (None, 59)                2006
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 60
# =================================================================
# Total params: 156,239
# Trainable params: 156,239
# Non-trainable params: 0
# _________________________________________________________________
# 33/33 - 2s - loss: 0.0672 - accuracy: 0.9734
# 27/27 - 2s - loss: 0.1033 - accuracy: 0.9573
# val_loss: 0.06716185063123703
# test_loss: 0.10327155888080597
# test_acc: 0.9573459625244141
# precision: 0.8630705394190872
# recall: 0.985781990521327
# specificity 0.9478672985781991
# sensitivity :  0.985781990521327
# far 0.052132701421800945
# frr 0.014218009478672985
