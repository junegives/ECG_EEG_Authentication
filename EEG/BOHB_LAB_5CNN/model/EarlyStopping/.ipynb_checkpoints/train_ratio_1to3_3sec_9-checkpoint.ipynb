# %%
# -*- coding: utf-8 -*-

import scipy.io
import numpy as np
import tensorflow as tf
import sklearn as sk
import matplotlib.pyplot as plt
import itertools
import random

from numba import cuda
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

from tensorflow.keras.callbacks import  EarlyStopping

# %%
# tensorflow = 2.
# python = 3.6


seed = np.random.seed(777)

gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
    
  try:
      
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
      
  except RuntimeError as e:
      
    print(e)


val_loss_all = []

test_loss_all = []
test_acc_all = []
test_pre_all = []
frr_all = []
far_all = []

conf_matrix_sco = []
test_pre_sco = []
test_rec_sco = []
test_spedi_sco = []
test_sensi_sco = []

class MyModelCheckpoint(tf.keras.callbacks.ModelCheckpoint):

    def __init__(self, *args, **kwargs):
        super(MyModelCheckpoint, self).__init__(*args, **kwargs)

    # redefine the save so it only activates after 100 epochs
    def on_epoch_end(self, epoch, logs=None):
        if epoch >= 1: super(MyModelCheckpoint, self).on_epoch_end(epoch, logs)

# %%
train_data = scipy.io.loadmat('../../datas/160hz/train_5day_160hz.mat', squeeze_me=True)['data']
test_data = scipy.io.loadmat('../../datas/160hz/test_6day_160hz(2).mat', squeeze_me=True)['data']

# sub 수
sub_cnt = train_data.shape[0]

# 3sec 데이터 크기
data_size = 480

# 1명당 3초 데이터 개수
train_data_cnt = 1052
test_data_cnt = 211

# 3sec 480(= 160*3) 크기로 데이터 길이 설정
train_cut_size = 504960 # 480*1052 = 504960
test_cut_size = 101280 # 480*211 = 101280

# 3sec 데이터 길이 자르기
# train: 504,960 / test: 101,280
train_data = train_data[:,0:train_cut_size,:]
test_data = test_data[:,0:test_cut_size,:]

# flatten(): 3D -> 1D / reshape(-1,1): -1 마지막 인덱스
train_flatten = train_data.flatten().reshape(-1,1)
test_flatten = test_data.flatten().reshape(-1,1)

# StandardScaler(): train에 맞춰 표준화
data_scaler = StandardScaler()
    
data_scaler.fit(train_flatten)
train_scaler = data_scaler.transform(train_flatten)
test_scaler = data_scaler.transform(test_flatten)
    
# train, test 데이터 reshape
train_data = train_scaler.reshape(train_data_cnt * sub_cnt, data_size, 2) 
test_data = test_scaler.reshape(test_data_cnt * sub_cnt, data_size, 2)

#train data를 sub:other=1:1로 만들기 위해서 각 sub 추출
train_data_each = []
for i in range(sub_cnt):
    train_data_each.insert(i, train_data[i*train_data_cnt:(i+1)*train_data_cnt, :, :])
print(np.shape(train_data_each))

#test data를 sub:other=1:3로 만들기 위해서 각 sub 추출
test_data_each = []
for i in range(sub_cnt):
    test_data_each.insert(i, test_data[i*test_data_cnt:(i+1)*test_data_cnt, :, :])
print(np.shape(test_data_each))
# Out:
# (11, 1052, 480, 2)
# (11, 211, 480, 2)

# %%
# sub number
sub_num = 8

#1 to 3 비율로 설정
ratio = 3

train_data_n = train_data_each[sub_num]
test_data_n = test_data_each[sub_num]

# train data를 sub:other = 1:3으로 만들기
# 3초 덩어리 개수 1052 : 3156
# => 315 * 4 + 316 * 6 = 1260 + 1896 = 3156

# test data를 sub:other = 1:3로 만들기
# 3초 덩어리 개수 211 : 633
# 63 * 7 + 64 * 3 = 633

cnt = 0
for j in range(sub_cnt):
    if j != sub_num and cnt < 4:
        cnt = cnt + 1
        train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 315)), axis = 0)
    elif j != sub_num and cnt >= 4:
        train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 316)), axis = 0)
#     print("train_data_n.shape")
#     print(train_data_n.shape)
#     print("train_data_n")
#     print(train_data_n)
        
cnt = 0
for j in range(sub_cnt):
    if j != sub_num and cnt < 7:
        cnt = cnt + 1
        test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 63)), axis = 0)
    elif j != sub_num and cnt >= 7:
        test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 64)), axis = 0)
        
        
        
train_label = np.zeros(train_data_cnt*(ratio+1))
test_label = np.zeros(test_data_cnt*(ratio+1))

for j in range(len(train_label)):
    if (j < train_data_cnt):
        train_label[j] = 1

for j in range(len(test_label)):
    if (j < test_data_cnt):
        test_label[j] = 1
        
train_data_shuffled, train_label_shuffled = sk.utils.shuffle(train_data_n, train_label, random_state = 0)

val_data_set = train_data_shuffled[:train_data_cnt]
train_data_set = train_data_shuffled[train_data_cnt:]

val_label_set = train_label_shuffled[:train_data_cnt]
train_label_set = train_label_shuffled[train_data_cnt:]

# %%
# model CNN-LSTM    
inputs = tf.keras.Input(shape = (480, 2))
conv_1 = tf.keras.layers.Conv1D(filters = 240, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(inputs)
max_1 = tf.keras.layers.MaxPool1D(3)(conv_1)
    
conv_2 = tf.keras.layers.Conv1D(filters = 44, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(max_1)
max_2 = tf.keras.layers.MaxPool1D(3)(conv_2)
    
# conv_3 = tf.keras.layers.Conv1D(filters = 47, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(max_2)
# max_3 = tf.keras.layers.MaxPool1D(3)(conv_3)
    

D_out_1 = tf.keras.layers.Dropout(0.6273313485219749)(max_2)
    
    
lstm_1 = tf.keras.layers.LSTM(156)(D_out_1)
    
dense_1 = tf.keras.layers.Dense(253, activation = 'relu')(lstm_1)
dense_2 = tf.keras.layers.Dense(34, activation = 'relu')(dense_1)
dense_3 = tf.keras.layers.Dense(55, activation = 'relu')(dense_2)
dense_4 = tf.keras.layers.Dense(1, activation = 'sigmoid')(dense_3)
    
model = tf.keras.models.Model(inputs = inputs, outputs = dense_4)

# Adam
model.compile(loss = 'binary_crossentropy', optimizer = tf.keras.optimizers.Adam(0.00024850487236764685), metrics = ['accuracy'])
# SGD
# model.compile(loss= 'binary_crossentropy', optimizer= tf.keras.optimizers.SGD(learning_rate=0.06347691327304918, momentum=0.027904272142875237), metrics=['accuracy'])
    
# EarlyStopping 조기종료 및 모델 학습
early_stopping = tf.keras.callbacks.EarlyStopping(patience = 20)
check_point = MyModelCheckpoint('best_model_' + str(sub_num + 1) + '.h5', monitor = 'val_loss', mode = 'min', save_best_only = True, verbose = 1)

# EarlyStopping 사용
hist = model.fit(train_data_set, train_label_set, epochs = 200, batch_size = 32, validation_data = (val_data_set, val_label_set), callbacks = [early_stopping, check_point])
# EarlyStopping 미사용
# hist = model.fit(train_data_set, train_label_set, epochs = 200, batch_size = 32, validation_data = (val_data_set, val_label_set), callbacks = [check_point])
        
# model save .h5형식
model = tf.keras.models.load_model('best_model_' + str(sub_num + 1) + '.h5')
model.save('Binary_BOHB_' + str(sub_num + 1) + '.h5')
model.summary() 
        
val_loss, val_acc = model.evaluate(val_data_set, val_label_set, verbose = 2)

test_loss, test_acc = model.evaluate(test_data_n, test_label, verbose = 2)
test_pred = model.predict(test_data_n)
        
    
# 각 행은 1sec, 0.5 <= 자신, 0.5 > 타인
for i in range(len(test_pred)):
    if(test_pred[i] >= 0.5):
        test_pred[i] = 1
    
    else: 
        test_pred[i] = 0
    
    
val_loss_all.append(val_loss)
    
test_loss_all.append(test_loss)
test_acc_all.append(test_acc)
test_pre_all.append(test_pred)
    

conf_matrix = confusion_matrix(test_label, test_pred) 
conf_matrix_sco.append(conf_matrix)
    
conf_row = conf_matrix.sum(axis = 1)
conf_col = conf_matrix.sum(axis = 0)

precision = conf_matrix[1][1] / conf_col[1]
recall = conf_matrix[1][1] / conf_row[1]
specificity = conf_matrix[0][0] / conf_row[0]
sensitivity = conf_matrix[1][1] / conf_row[1]
frr = conf_matrix[1][0] / (conf_matrix[1][1]+conf_matrix[1][0])
far = conf_matrix[0][1] / (conf_matrix[0][1]+conf_matrix[0][0])
    
frr_all.append(frr)
far_all.append(far)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111)

cax = ax.matshow(conf_matrix)

fig.colorbar(cax)

for i, j in itertools.product(range(conf_matrix.shape[0]), range(conf_matrix.shape[1])):
    plt.text(j, i, conf_matrix[i, j], color="white")

plt.title('CNN+LSTM model')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.show()
 
    
test_pre_sco.append(precision)
test_rec_sco.append(recall)
test_spedi_sco.append(specificity)
test_sensi_sco.append(sensitivity)
    
print('val_loss:', val_loss)
print('test_loss:', test_loss)
print('test_acc:', test_acc)
    
print('precision:', precision)
print('recall:', recall)
print('specificity', specificity)
print('sensitivity : ', sensitivity)
print('far', far)
print('frr', frr)
# Out:
# Epoch 1/200
# 99/99 [==============================] - 5s 52ms/step - loss: 0.5665 - accuracy: 0.7500 - val_loss: 0.5356 - val_accuracy: 0.7367
# Epoch 2/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.4904 - accuracy: 0.7777
# Epoch 00002: val_loss improved from inf to 0.46378, saving model to best_model_9.h5
# 99/99 [==============================] - 5s 49ms/step - loss: 0.4902 - accuracy: 0.7779 - val_loss: 0.4638 - val_accuracy: 0.7842
# Epoch 3/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.4625 - accuracy: 0.7997
# Epoch 00003: val_loss improved from 0.46378 to 0.43158, saving model to best_model_9.h5
# 99/99 [==============================] - 5s 49ms/step - loss: 0.4647 - accuracy: 0.7978 - val_loss: 0.4316 - val_accuracy: 0.8137
# Epoch 4/200
# 99/99 [==============================] - ETA: 0s - loss: 0.4298 - accuracy: 0.8131
# Epoch 00004: val_loss improved from 0.43158 to 0.38368, saving model to best_model_9.h5
# 99/99 [==============================] - 5s 50ms/step - loss: 0.4298 - accuracy: 0.8131 - val_loss: 0.3837 - val_accuracy: 0.8384
# Epoch 5/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.4005 - accuracy: 0.8307
# Epoch 00005: val_loss improved from 0.38368 to 0.37232, saving model to best_model_9.h5
# 99/99 [==============================] - 5s 48ms/step - loss: 0.3996 - accuracy: 0.8311 - val_loss: 0.3723 - val_accuracy: 0.8384
# Epoch 6/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.3586 - accuracy: 0.8504
# Epoch 00006: val_loss improved from 0.37232 to 0.33019, saving model to best_model_9.h5
# 99/99 [==============================] - 5s 49ms/step - loss: 0.3611 - accuracy: 0.8492 - val_loss: 0.3302 - val_accuracy: 0.8622
# Epoch 7/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3559 - accuracy: 0.8466
# Epoch 00007: val_loss did not improve from 0.33019
# 99/99 [==============================] - 5s 49ms/step - loss: 0.3559 - accuracy: 0.8466 - val_loss: 0.3361 - val_accuracy: 0.8593
# Epoch 8/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3584 - accuracy: 0.8523
# Epoch 00008: val_loss did not improve from 0.33019
# 99/99 [==============================] - 5s 47ms/step - loss: 0.3584 - accuracy: 0.8523 - val_loss: 0.3310 - val_accuracy: 0.8688
# Epoch 9/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3378 - accuracy: 0.8584
# Epoch 00009: val_loss improved from 0.33019 to 0.30904, saving model to best_model_9.h5
# 99/99 [==============================] - 4s 44ms/step - loss: 0.3378 - accuracy: 0.8584 - val_loss: 0.3090 - val_accuracy: 0.8641
# Epoch 10/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3310 - accuracy: 0.8638
# Epoch 00010: val_loss did not improve from 0.30904
# 99/99 [==============================] - 4s 44ms/step - loss: 0.3310 - accuracy: 0.8638 - val_loss: 0.3263 - val_accuracy: 0.8650
# Epoch 11/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3411 - accuracy: 0.8549
# Epoch 00011: val_loss improved from 0.30904 to 0.30034, saving model to best_model_9.h5
# 99/99 [==============================] - 4s 44ms/step - loss: 0.3411 - accuracy: 0.8549 - val_loss: 0.3003 - val_accuracy: 0.8745
# Epoch 12/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3203 - accuracy: 0.8682
# Epoch 00012: val_loss did not improve from 0.30034
# 99/99 [==============================] - 4s 43ms/step - loss: 0.3203 - accuracy: 0.8682 - val_loss: 0.3067 - val_accuracy: 0.8698
# Epoch 13/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3262 - accuracy: 0.8619
# Epoch 00013: val_loss did not improve from 0.30034
# 99/99 [==============================] - 4s 44ms/step - loss: 0.3262 - accuracy: 0.8619 - val_loss: 0.3584 - val_accuracy: 0.8375
# Epoch 14/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3175 - accuracy: 0.8641
# Epoch 00014: val_loss improved from 0.30034 to 0.29283, saving model to best_model_9.h5
# 99/99 [==============================] - 4s 44ms/step - loss: 0.3175 - accuracy: 0.8641 - val_loss: 0.2928 - val_accuracy: 0.8717
# Epoch 15/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3108 - accuracy: 0.8714
# Epoch 00015: val_loss did not improve from 0.29283
# 99/99 [==============================] - 4s 45ms/step - loss: 0.3108 - accuracy: 0.8714 - val_loss: 0.3018 - val_accuracy: 0.8669
# Epoch 16/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2987 - accuracy: 0.8717
# Epoch 00016: val_loss improved from 0.29283 to 0.27711, saving model to best_model_9.h5
# 99/99 [==============================] - 4s 45ms/step - loss: 0.2987 - accuracy: 0.8717 - val_loss: 0.2771 - val_accuracy: 0.8802
# Epoch 17/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3016 - accuracy: 0.8714
# Epoch 00017: val_loss improved from 0.27711 to 0.26835, saving model to best_model_9.h5
# 99/99 [==============================] - 5s 46ms/step - loss: 0.3016 - accuracy: 0.8714 - val_loss: 0.2683 - val_accuracy: 0.8859
# Epoch 18/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2921 - accuracy: 0.8761
# Epoch 00018: val_loss did not improve from 0.26835
# 99/99 [==============================] - 4s 45ms/step - loss: 0.2921 - accuracy: 0.8761 - val_loss: 0.2686 - val_accuracy: 0.8840
# Epoch 19/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2990 - accuracy: 0.8707
# Epoch 00019: val_loss did not improve from 0.26835
# 99/99 [==============================] - 4s 45ms/step - loss: 0.2990 - accuracy: 0.8707 - val_loss: 0.2825 - val_accuracy: 0.8717
# Epoch 20/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2809 - accuracy: 0.8847
# Epoch 00020: val_loss did not improve from 0.26835
# 99/99 [==============================] - 4s 45ms/step - loss: 0.2809 - accuracy: 0.8847 - val_loss: 0.3337 - val_accuracy: 0.8317
# Epoch 21/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2801 - accuracy: 0.8837
# Epoch 00021: val_loss improved from 0.26835 to 0.25624, saving model to best_model_9.h5
# 99/99 [==============================] - 4s 44ms/step - loss: 0.2801 - accuracy: 0.8837 - val_loss: 0.2562 - val_accuracy: 0.8926
# Epoch 22/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2670 - accuracy: 0.8840
# Epoch 00022: val_loss improved from 0.25624 to 0.25063, saving model to best_model_9.h5
# 99/99 [==============================] - 5s 46ms/step - loss: 0.2670 - accuracy: 0.8840 - val_loss: 0.2506 - val_accuracy: 0.8935
# Epoch 23/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2702 - accuracy: 0.8837
# Epoch 00023: val_loss did not improve from 0.25063
# 99/99 [==============================] - 4s 45ms/step - loss: 0.2702 - accuracy: 0.8837 - val_loss: 0.2875 - val_accuracy: 0.8726
# Epoch 24/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2581 - accuracy: 0.8878
# Epoch 00024: val_loss improved from 0.25063 to 0.24178, saving model to best_model_9.h5
# 99/99 [==============================] - 5s 46ms/step - loss: 0.2581 - accuracy: 0.8878 - val_loss: 0.2418 - val_accuracy: 0.9068
# Epoch 25/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2610 - accuracy: 0.8831
# Epoch 00025: val_loss did not improve from 0.24178
# 99/99 [==============================] - 4s 45ms/step - loss: 0.2610 - accuracy: 0.8831 - val_loss: 0.3360 - val_accuracy: 0.8460
# Epoch 26/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2523 - accuracy: 0.8961
# Epoch 00026: val_loss did not improve from 0.24178
# 99/99 [==============================] - 4s 45ms/step - loss: 0.2523 - accuracy: 0.8961 - val_loss: 0.2476 - val_accuracy: 0.8964
# Epoch 27/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2776 - accuracy: 0.8771
# Epoch 00027: val_loss did not improve from 0.24178
# 99/99 [==============================] - 4s 45ms/step - loss: 0.2776 - accuracy: 0.8771 - val_loss: 0.2778 - val_accuracy: 0.8774
# Epoch 28/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2475 - accuracy: 0.8970
# Epoch 00028: val_loss improved from 0.24178 to 0.22663, saving model to best_model_9.h5
# 99/99 [==============================] - 5s 46ms/step - loss: 0.2475 - accuracy: 0.8970 - val_loss: 0.2266 - val_accuracy: 0.9163
# Epoch 29/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2434 - accuracy: 0.8980
# Epoch 00029: val_loss improved from 0.22663 to 0.22139, saving model to best_model_9.h5
# 99/99 [==============================] - 5s 46ms/step - loss: 0.2434 - accuracy: 0.8980 - val_loss: 0.2214 - val_accuracy: 0.9116
# Epoch 30/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2517 - accuracy: 0.8932
# Epoch 00030: val_loss did not improve from 0.22139
# 99/99 [==============================] - 5s 51ms/step - loss: 0.2517 - accuracy: 0.8932 - val_loss: 0.2502 - val_accuracy: 0.9049
# Epoch 31/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2466 - accuracy: 0.8996
# Epoch 00031: val_loss did not improve from 0.22139
# 99/99 [==============================] - 5s 50ms/step - loss: 0.2461 - accuracy: 0.8999 - val_loss: 0.2244 - val_accuracy: 0.9087
# Epoch 32/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2432 - accuracy: 0.8964
# Epoch 00032: val_loss did not improve from 0.22139
# 99/99 [==============================] - 5s 52ms/step - loss: 0.2436 - accuracy: 0.8964 - val_loss: 0.2216 - val_accuracy: 0.9135
# Epoch 33/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2203 - accuracy: 0.9113
# Epoch 00033: val_loss did not improve from 0.22139
# 99/99 [==============================] - 5s 52ms/step - loss: 0.2203 - accuracy: 0.9113 - val_loss: 0.2235 - val_accuracy: 0.9144
# Epoch 34/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2226 - accuracy: 0.9091
# Epoch 00034: val_loss did not improve from 0.22139
# 99/99 [==============================] - 5s 52ms/step - loss: 0.2226 - accuracy: 0.9091 - val_loss: 0.2265 - val_accuracy: 0.8945
# Epoch 35/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2381 - accuracy: 0.9030
# Epoch 00035: val_loss did not improve from 0.22139
# 99/99 [==============================] - 5s 51ms/step - loss: 0.2381 - accuracy: 0.9030 - val_loss: 0.2259 - val_accuracy: 0.9030
# Epoch 36/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2426 - accuracy: 0.8967
# Epoch 00036: val_loss did not improve from 0.22139
# 99/99 [==============================] - 5s 51ms/step - loss: 0.2421 - accuracy: 0.8967 - val_loss: 0.2257 - val_accuracy: 0.9078
# Epoch 37/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2389 - accuracy: 0.8970
# Epoch 00037: val_loss improved from 0.22139 to 0.21893, saving model to best_model_9.h5
# 99/99 [==============================] - 5s 52ms/step - loss: 0.2385 - accuracy: 0.8967 - val_loss: 0.2189 - val_accuracy: 0.9106
# Epoch 38/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.9062
# Epoch 00038: val_loss did not improve from 0.21893
# 99/99 [==============================] - 5s 52ms/step - loss: 0.2217 - accuracy: 0.9062 - val_loss: 0.2211 - val_accuracy: 0.9068
# Epoch 39/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2169 - accuracy: 0.9097
# Epoch 00039: val_loss did not improve from 0.21893
# 99/99 [==============================] - 5s 51ms/step - loss: 0.2169 - accuracy: 0.9097 - val_loss: 0.2545 - val_accuracy: 0.8878
# Epoch 40/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2131 - accuracy: 0.9110
# Epoch 00040: val_loss did not improve from 0.21893
# 99/99 [==============================] - 5s 51ms/step - loss: 0.2128 - accuracy: 0.9113 - val_loss: 0.2228 - val_accuracy: 0.9068
# Epoch 41/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2180 - accuracy: 0.9072
# Epoch 00041: val_loss improved from 0.21893 to 0.20807, saving model to best_model_9.h5
# 99/99 [==============================] - 5s 51ms/step - loss: 0.2176 - accuracy: 0.9075 - val_loss: 0.2081 - val_accuracy: 0.9202
# Epoch 42/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2183 - accuracy: 0.9098
# Epoch 00042: val_loss did not improve from 0.20807
# 99/99 [==============================] - 5s 51ms/step - loss: 0.2177 - accuracy: 0.9100 - val_loss: 0.2455 - val_accuracy: 0.8954
# Epoch 43/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2276 - accuracy: 0.9068
# Epoch 00043: val_loss did not improve from 0.20807
# 99/99 [==============================] - 5s 53ms/step - loss: 0.2276 - accuracy: 0.9068 - val_loss: 0.2189 - val_accuracy: 0.9154
# Epoch 44/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2138 - accuracy: 0.9125
# Epoch 00044: val_loss did not improve from 0.20807
# 99/99 [==============================] - 5s 51ms/step - loss: 0.2138 - accuracy: 0.9125 - val_loss: 0.2168 - val_accuracy: 0.9192
# Epoch 45/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2048 - accuracy: 0.9155
# Epoch 00045: val_loss improved from 0.20807 to 0.20434, saving model to best_model_9.h5
# 99/99 [==============================] - 5s 52ms/step - loss: 0.2056 - accuracy: 0.9151 - val_loss: 0.2043 - val_accuracy: 0.9163
# Epoch 46/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2210 - accuracy: 0.9084
# Epoch 00046: val_loss did not improve from 0.20434
# 99/99 [==============================] - 5s 52ms/step - loss: 0.2210 - accuracy: 0.9084 - val_loss: 0.2215 - val_accuracy: 0.9097
# Epoch 47/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2052 - accuracy: 0.9129
# Epoch 00047: val_loss did not improve from 0.20434
# 99/99 [==============================] - 5s 51ms/step - loss: 0.2052 - accuracy: 0.9129 - val_loss: 0.2053 - val_accuracy: 0.9202
# Epoch 48/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2011 - accuracy: 0.9133
# Epoch 00048: val_loss did not improve from 0.20434
# 99/99 [==============================] - 5s 51ms/step - loss: 0.2004 - accuracy: 0.9138 - val_loss: 0.2109 - val_accuracy: 0.9125
# Epoch 49/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2108 - accuracy: 0.9148
# Epoch 00049: val_loss did not improve from 0.20434
# 99/99 [==============================] - 5s 52ms/step - loss: 0.2108 - accuracy: 0.9148 - val_loss: 0.2166 - val_accuracy: 0.9163
# Epoch 50/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2056 - accuracy: 0.9161
# Epoch 00050: val_loss did not improve from 0.20434
# 99/99 [==============================] - 5s 51ms/step - loss: 0.2052 - accuracy: 0.9160 - val_loss: 0.2608 - val_accuracy: 0.8821
# Epoch 51/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2110 - accuracy: 0.9110
# Epoch 00051: val_loss did not improve from 0.20434
# 99/99 [==============================] - 5s 51ms/step - loss: 0.2110 - accuracy: 0.9110 - val_loss: 0.2193 - val_accuracy: 0.9087
# Epoch 52/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1950 - accuracy: 0.9244
# Epoch 00052: val_loss did not improve from 0.20434
# 99/99 [==============================] - 5s 51ms/step - loss: 0.1957 - accuracy: 0.9236 - val_loss: 0.2476 - val_accuracy: 0.8945
# Epoch 53/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1900 - accuracy: 0.9236
# Epoch 00053: val_loss did not improve from 0.20434
# 99/99 [==============================] - 5s 51ms/step - loss: 0.1900 - accuracy: 0.9236 - val_loss: 0.2187 - val_accuracy: 0.9021
# Epoch 54/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1966 - accuracy: 0.9173
# Epoch 00054: val_loss did not improve from 0.20434
# 99/99 [==============================] - 5s 51ms/step - loss: 0.1966 - accuracy: 0.9173 - val_loss: 0.2242 - val_accuracy: 0.9040
# Epoch 55/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2038 - accuracy: 0.9180
# Epoch 00055: val_loss did not improve from 0.20434
# 99/99 [==============================] - 5s 53ms/step - loss: 0.2032 - accuracy: 0.9183 - val_loss: 0.2067 - val_accuracy: 0.9173
# Epoch 56/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1962 - accuracy: 0.9235
# Epoch 00056: val_loss did not improve from 0.20434
# 99/99 [==============================] - 5s 51ms/step - loss: 0.1954 - accuracy: 0.9240 - val_loss: 0.2133 - val_accuracy: 0.9106
# Epoch 57/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1999 - accuracy: 0.9190
# Epoch 00057: val_loss improved from 0.20434 to 0.19879, saving model to best_model_9.h5
# 99/99 [==============================] - 5s 53ms/step - loss: 0.1993 - accuracy: 0.9192 - val_loss: 0.1988 - val_accuracy: 0.9249
# Epoch 58/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1835 - accuracy: 0.9233
# Epoch 00058: val_loss did not improve from 0.19879
# 99/99 [==============================] - 5s 51ms/step - loss: 0.1835 - accuracy: 0.9233 - val_loss: 0.2652 - val_accuracy: 0.8831
# Epoch 59/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1978 - accuracy: 0.9168
# Epoch 00059: val_loss did not improve from 0.19879
# 99/99 [==============================] - 5s 51ms/step - loss: 0.1977 - accuracy: 0.9170 - val_loss: 0.2179 - val_accuracy: 0.9078
# Epoch 60/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1884 - accuracy: 0.9241
# Epoch 00060: val_loss did not improve from 0.19879
# 99/99 [==============================] - 5s 51ms/step - loss: 0.1881 - accuracy: 0.9243 - val_loss: 0.2919 - val_accuracy: 0.8869
# Epoch 61/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1941 - accuracy: 0.9202
# Epoch 00061: val_loss did not improve from 0.19879
# 99/99 [==============================] - 5s 51ms/step - loss: 0.1941 - accuracy: 0.9202 - val_loss: 0.2501 - val_accuracy: 0.8964
# Epoch 62/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1961 - accuracy: 0.9158
# Epoch 00062: val_loss improved from 0.19879 to 0.19287, saving model to best_model_9.h5
# 99/99 [==============================] - 5s 49ms/step - loss: 0.1957 - accuracy: 0.9160 - val_loss: 0.1929 - val_accuracy: 0.9211
# Epoch 63/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1909 - accuracy: 0.9227
# Epoch 00063: val_loss did not improve from 0.19287
# 99/99 [==============================] - 5s 50ms/step - loss: 0.1909 - accuracy: 0.9227 - val_loss: 0.2596 - val_accuracy: 0.8945
# Epoch 64/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1846 - accuracy: 0.9255
# Epoch 00064: val_loss did not improve from 0.19287
# 99/99 [==============================] - 5s 49ms/step - loss: 0.1846 - accuracy: 0.9255 - val_loss: 0.2452 - val_accuracy: 0.8983
# Epoch 65/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1931 - accuracy: 0.9202
# Epoch 00065: val_loss did not improve from 0.19287
# 99/99 [==============================] - 5s 48ms/step - loss: 0.1931 - accuracy: 0.9202 - val_loss: 0.2201 - val_accuracy: 0.9049
# Epoch 66/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1720 - accuracy: 0.9286
# Epoch 00066: val_loss did not improve from 0.19287
# 99/99 [==============================] - 5s 51ms/step - loss: 0.1728 - accuracy: 0.9284 - val_loss: 0.2443 - val_accuracy: 0.8945
# Epoch 67/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1932 - accuracy: 0.9281
# Epoch 00067: val_loss did not improve from 0.19287
# 99/99 [==============================] - 4s 44ms/step - loss: 0.1932 - accuracy: 0.9281 - val_loss: 0.1937 - val_accuracy: 0.9183
# Epoch 68/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1684 - accuracy: 0.9300
# Epoch 00068: val_loss did not improve from 0.19287
# 99/99 [==============================] - 4s 44ms/step - loss: 0.1684 - accuracy: 0.9300 - val_loss: 0.2260 - val_accuracy: 0.9068
# Epoch 69/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1772 - accuracy: 0.9221
# Epoch 00069: val_loss did not improve from 0.19287
# 99/99 [==============================] - 4s 44ms/step - loss: 0.1772 - accuracy: 0.9221 - val_loss: 0.1948 - val_accuracy: 0.9192
# Epoch 70/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1902 - accuracy: 0.9186
# Epoch 00070: val_loss did not improve from 0.19287
# 99/99 [==============================] - 4s 44ms/step - loss: 0.1902 - accuracy: 0.9186 - val_loss: 0.2234 - val_accuracy: 0.9116
# Epoch 71/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1775 - accuracy: 0.9249
# Epoch 00071: val_loss did not improve from 0.19287
# 99/99 [==============================] - 4s 44ms/step - loss: 0.1775 - accuracy: 0.9249 - val_loss: 0.2006 - val_accuracy: 0.9154
# Epoch 72/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1698 - accuracy: 0.9293
# Epoch 00072: val_loss improved from 0.19287 to 0.19250, saving model to best_model_9.h5
# 99/99 [==============================] - 4s 44ms/step - loss: 0.1698 - accuracy: 0.9293 - val_loss: 0.1925 - val_accuracy: 0.9202
# Epoch 73/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1591 - accuracy: 0.9420
# Epoch 00073: val_loss did not improve from 0.19250
# 99/99 [==============================] - 4s 44ms/step - loss: 0.1591 - accuracy: 0.9420 - val_loss: 0.2256 - val_accuracy: 0.9135
# Epoch 74/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1847 - accuracy: 0.9211
# Epoch 00074: val_loss did not improve from 0.19250
# 99/99 [==============================] - 4s 44ms/step - loss: 0.1847 - accuracy: 0.9211 - val_loss: 0.2556 - val_accuracy: 0.8992
# Epoch 75/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1721 - accuracy: 0.9322
# Epoch 00075: val_loss improved from 0.19250 to 0.18480, saving model to best_model_9.h5
# 99/99 [==============================] - 5s 46ms/step - loss: 0.1721 - accuracy: 0.9322 - val_loss: 0.1848 - val_accuracy: 0.9268
# Epoch 76/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1574 - accuracy: 0.9319
# Epoch 00076: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 46ms/step - loss: 0.1574 - accuracy: 0.9319 - val_loss: 0.1871 - val_accuracy: 0.9249
# Epoch 77/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1742 - accuracy: 0.9300
# Epoch 00077: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 46ms/step - loss: 0.1742 - accuracy: 0.9300 - val_loss: 0.1982 - val_accuracy: 0.9183
# Epoch 78/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1758 - accuracy: 0.9293
# Epoch 00078: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 46ms/step - loss: 0.1758 - accuracy: 0.9293 - val_loss: 0.2190 - val_accuracy: 0.9135
# Epoch 79/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1692 - accuracy: 0.9303
# Epoch 00079: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 46ms/step - loss: 0.1692 - accuracy: 0.9303 - val_loss: 0.1959 - val_accuracy: 0.9259
# Epoch 80/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1821 - accuracy: 0.9243
# Epoch 00080: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 46ms/step - loss: 0.1821 - accuracy: 0.9243 - val_loss: 0.1887 - val_accuracy: 0.9211
# Epoch 81/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1905 - accuracy: 0.9211
# Epoch 00081: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 46ms/step - loss: 0.1905 - accuracy: 0.9211 - val_loss: 0.2490 - val_accuracy: 0.8973
# Epoch 82/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1653 - accuracy: 0.9359
# Epoch 00082: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 48ms/step - loss: 0.1658 - accuracy: 0.9354 - val_loss: 0.2072 - val_accuracy: 0.9173
# Epoch 83/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1681 - accuracy: 0.9303
# Epoch 00083: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 48ms/step - loss: 0.1681 - accuracy: 0.9303 - val_loss: 0.1880 - val_accuracy: 0.9287
# Epoch 84/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1711 - accuracy: 0.9270
# Epoch 00084: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 48ms/step - loss: 0.1714 - accuracy: 0.9268 - val_loss: 0.2599 - val_accuracy: 0.8973
# Epoch 85/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1791 - accuracy: 0.9246
# Epoch 00085: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 47ms/step - loss: 0.1791 - accuracy: 0.9246 - val_loss: 0.2450 - val_accuracy: 0.8935
# Epoch 86/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1751 - accuracy: 0.9257
# Epoch 00086: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 49ms/step - loss: 0.1752 - accuracy: 0.9255 - val_loss: 0.1962 - val_accuracy: 0.9202
# Epoch 87/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1797 - accuracy: 0.9260
# Epoch 00087: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 48ms/step - loss: 0.1790 - accuracy: 0.9262 - val_loss: 0.2045 - val_accuracy: 0.9163
# Epoch 88/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1639 - accuracy: 0.9340
# Epoch 00088: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 48ms/step - loss: 0.1632 - accuracy: 0.9344 - val_loss: 0.1903 - val_accuracy: 0.9259
# Epoch 89/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1603 - accuracy: 0.9360
# Epoch 00089: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 47ms/step - loss: 0.1603 - accuracy: 0.9360 - val_loss: 0.2026 - val_accuracy: 0.9230
# Epoch 90/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1576 - accuracy: 0.9381
# Epoch 00090: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 48ms/step - loss: 0.1571 - accuracy: 0.9382 - val_loss: 0.2120 - val_accuracy: 0.9144
# Epoch 91/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1514 - accuracy: 0.9353
# Epoch 00091: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 53ms/step - loss: 0.1526 - accuracy: 0.9347 - val_loss: 0.2355 - val_accuracy: 0.8973
# Epoch 92/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1593 - accuracy: 0.9381
# Epoch 00092: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 52ms/step - loss: 0.1601 - accuracy: 0.9382 - val_loss: 0.2125 - val_accuracy: 0.9144
# Epoch 93/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1631 - accuracy: 0.9343
# Epoch 00093: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 52ms/step - loss: 0.1625 - accuracy: 0.9347 - val_loss: 0.1911 - val_accuracy: 0.9240
# Epoch 94/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1518 - accuracy: 0.9369
# Epoch 00094: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 54ms/step - loss: 0.1510 - accuracy: 0.9373 - val_loss: 0.2175 - val_accuracy: 0.9183
# Epoch 95/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1522 - accuracy: 0.9349
# Epoch 00095: val_loss did not improve from 0.18480
# 99/99 [==============================] - 5s 55ms/step - loss: 0.1542 - accuracy: 0.9344 - val_loss: 0.2156 - val_accuracy: 0.9221
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 480, 240)          1680
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 160, 240)          0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 160, 44)           31724
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 53, 44)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 53, 44)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 156)               125424
# _________________________________________________________________
# dense_2 (Dense)              (None, 253)               39721
# _________________________________________________________________
# dense_3 (Dense)              (None, 34)                8636
# _________________________________________________________________
# dense_4 (Dense)              (None, 55)                1925
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 56
# =================================================================
# Total params: 209,166
# Trainable params: 209,166
# Non-trainable params: 0
# _________________________________________________________________
# 33/33 - 1s - loss: 0.1848 - accuracy: 0.9268
# 27/27 - 0s - loss: 0.1405 - accuracy: 0.9455
# val_loss: 0.18480144441127777
# test_loss: 0.14045511186122894
# test_acc: 0.9454976320266724
# precision: 0.8666666666666667
# recall: 0.9241706161137441
# specificity 0.95260663507109
# sensitivity :  0.9241706161137441
# far 0.04739336492890995
# frr 0.07582938388625593
