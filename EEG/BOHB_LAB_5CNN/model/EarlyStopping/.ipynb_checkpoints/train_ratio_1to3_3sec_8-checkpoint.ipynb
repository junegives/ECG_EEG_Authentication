# %%
# -*- coding: utf-8 -*-

import scipy.io
import numpy as np
import tensorflow as tf
import sklearn as sk
import matplotlib.pyplot as plt
import itertools
import random

from numba import cuda
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

from tensorflow.keras.callbacks import  EarlyStopping

# %%
# tensorflow = 2.
# python = 3.6


seed = np.random.seed(777)

gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
    
  try:
      
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
      
  except RuntimeError as e:
      
    print(e)


val_loss_all = []

test_loss_all = []
test_acc_all = []
test_pre_all = []
frr_all = []
far_all = []

conf_matrix_sco = []
test_pre_sco = []
test_rec_sco = []
test_spedi_sco = []
test_sensi_sco = []

class MyModelCheckpoint(tf.keras.callbacks.ModelCheckpoint):

    def __init__(self, *args, **kwargs):
        super(MyModelCheckpoint, self).__init__(*args, **kwargs)

    # redefine the save so it only activates after 100 epochs
    def on_epoch_end(self, epoch, logs=None):
        if epoch >= 1: super(MyModelCheckpoint, self).on_epoch_end(epoch, logs)

# %%
train_data = scipy.io.loadmat('../../../datas/160hz/train_5day_160hz.mat', squeeze_me=True)['data']
test_data = scipy.io.loadmat('../../../datas/160hz/test_6day_160hz(2).mat', squeeze_me=True)['data']

# sub 수
sub_cnt = train_data.shape[0]

# 3sec 데이터 크기
data_size = 480

# 1명당 3초 데이터 개수
train_data_cnt = 1052
test_data_cnt = 211

# 3sec 480(= 160*3) 크기로 데이터 길이 설정
train_cut_size = 504960 # 480*1052 = 504960
test_cut_size = 101280 # 480*211 = 101280

# 3sec 데이터 길이 자르기
# train: 504,960 / test: 101,280
train_data = train_data[:,0:train_cut_size,:]
test_data = test_data[:,0:test_cut_size,:]

# flatten(): 3D -> 1D / reshape(-1,1): -1 마지막 인덱스
train_flatten = train_data.flatten().reshape(-1,1)
test_flatten = test_data.flatten().reshape(-1,1)

# StandardScaler(): train에 맞춰 표준화
data_scaler = StandardScaler()
    
data_scaler.fit(train_flatten)
train_scaler = data_scaler.transform(train_flatten)
test_scaler = data_scaler.transform(test_flatten)
    
# train, test 데이터 reshape
train_data = train_scaler.reshape(train_data_cnt * sub_cnt, data_size, 2) 
test_data = test_scaler.reshape(test_data_cnt * sub_cnt, data_size, 2)

#train data를 sub:other=1:1로 만들기 위해서 각 sub 추출
train_data_each = []
for i in range(sub_cnt):
    train_data_each.insert(i, train_data[i*train_data_cnt:(i+1)*train_data_cnt, :, :])
print(np.shape(train_data_each))

#test data를 sub:other=1:3로 만들기 위해서 각 sub 추출
test_data_each = []
for i in range(sub_cnt):
    test_data_each.insert(i, test_data[i*test_data_cnt:(i+1)*test_data_cnt, :, :])
print(np.shape(test_data_each))
# Out:
# (11, 1052, 480, 2)
# (11, 211, 480, 2)

# %%
# sub number
sub_num = 7

#1 to 3 비율로 설정
ratio = 3

train_data_n = train_data_each[sub_num]
test_data_n = test_data_each[sub_num]

# train data를 sub:other = 1:3으로 만들기
# 3초 덩어리 개수 1052 : 3156
# => 315 * 4 + 316 * 6 = 1260 + 1896 = 3156

# test data를 sub:other = 1:3로 만들기
# 3초 덩어리 개수 211 : 633
# 63 * 7 + 64 * 3 = 633

cnt = 0
for j in range(sub_cnt):
    if j != sub_num and cnt < 4:
        cnt = cnt + 1
        train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 315)), axis = 0)
    elif j != sub_num and cnt >= 4:
        train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 316)), axis = 0)
#     print("train_data_n.shape")
#     print(train_data_n.shape)
#     print("train_data_n")
#     print(train_data_n)
        
cnt = 0
for j in range(sub_cnt):
    if j != sub_num and cnt < 7:
        cnt = cnt + 1
        test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 63)), axis = 0)
    elif j != sub_num and cnt >= 7:
        test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 64)), axis = 0)
        
        
        
train_label = np.zeros(train_data_cnt*(ratio+1))
test_label = np.zeros(test_data_cnt*(ratio+1))

for j in range(len(train_label)):
    if (j < train_data_cnt):
        train_label[j] = 1

for j in range(len(test_label)):
    if (j < test_data_cnt):
        test_label[j] = 1
        
train_data_shuffled, train_label_shuffled = sk.utils.shuffle(train_data_n, train_label, random_state = 0)

val_data_set = train_data_shuffled[:train_data_cnt]
train_data_set = train_data_shuffled[train_data_cnt:]

val_label_set = train_label_shuffled[:train_data_cnt]
train_label_set = train_label_shuffled[train_data_cnt:]

# %%
# model CNN-LSTM    
inputs = tf.keras.Input(shape = (480, 2))
conv_1 = tf.keras.layers.Conv1D(filters = 33, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(inputs)
max_1 = tf.keras.layers.MaxPool1D(3)(conv_1)
    
conv_2 = tf.keras.layers.Conv1D(filters = 63, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(max_1)
max_2 = tf.keras.layers.MaxPool1D(3)(conv_2)
    
conv_3 = tf.keras.layers.Conv1D(filters = 55, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(max_2)
max_3 = tf.keras.layers.MaxPool1D(3)(conv_3)
    

D_out_1 = tf.keras.layers.Dropout(0.8132530633218736)(max_3)
    
    
lstm_1 = tf.keras.layers.LSTM(99)(D_out_1)
    
dense_1 = tf.keras.layers.Dense(14, activation = 'relu')(lstm_1)
dense_2 = tf.keras.layers.Dense(42, activation = 'relu')(dense_1)
dense_3 = tf.keras.layers.Dense(1, activation = 'sigmoid')(dense_2)
    
model = tf.keras.models.Model(inputs = inputs, outputs = dense_3)

# Adam
model.compile(loss = 'binary_crossentropy', optimizer = tf.keras.optimizers.Adam(0.00018169721600388663), metrics = ['accuracy'])
# SGD
# model.compile(loss= 'binary_crossentropy', optimizer= tf.keras.optimizers.SGD(learning_rate=0.0461300729767683, momentum=0.4411297369087802), metrics=['accuracy'])
    
# EarlyStopping 조기종료 및 모델 학습
early_stopping = tf.keras.callbacks.EarlyStopping(patience = 20)
check_point = MyModelCheckpoint('best_model_' + str(sub_num + 1) + '.h5', monitor = 'val_loss', mode = 'min', save_best_only = True, verbose = 1)

# EarlyStopping 사용
hist = model.fit(train_data_set, train_label_set, epochs = 200, batch_size = 32, validation_data = (val_data_set, val_label_set), callbacks = [early_stopping, check_point])
# EarlyStopping 미사용
# hist = model.fit(train_data_set, train_label_set, epochs = 200, batch_size = 32, validation_data = (val_data_set, val_label_set), callbacks = [check_point])
        
# model save .h5형식
model = tf.keras.models.load_model('best_model_' + str(sub_num + 1) + '.h5')
model.save('Binary_BOHB_' + str(sub_num + 1) + '.h5')
model.summary() 
        
val_loss, val_acc = model.evaluate(val_data_set, val_label_set, verbose = 2)

test_loss, test_acc = model.evaluate(test_data_n, test_label, verbose = 2)
test_pred = model.predict(test_data_n)
        
    
# 각 행은 1sec, 0.5 <= 자신, 0.5 > 타인
for i in range(len(test_pred)):
    if(test_pred[i] >= 0.5):
        test_pred[i] = 1
    
    else: 
        test_pred[i] = 0
    
    
val_loss_all.append(val_loss)
    
test_loss_all.append(test_loss)
test_acc_all.append(test_acc)
test_pre_all.append(test_pred)
    

conf_matrix = confusion_matrix(test_label, test_pred) 
conf_matrix_sco.append(conf_matrix)
    
conf_row = conf_matrix.sum(axis = 1)
conf_col = conf_matrix.sum(axis = 0)

precision = conf_matrix[1][1] / conf_col[1]
recall = conf_matrix[1][1] / conf_row[1]
specificity = conf_matrix[0][0] / conf_row[0]
sensitivity = conf_matrix[1][1] / conf_row[1]
frr = conf_matrix[1][0] / (conf_matrix[1][1]+conf_matrix[1][0])
far = conf_matrix[0][1] / (conf_matrix[0][1]+conf_matrix[0][0])
    
frr_all.append(frr)
far_all.append(far)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111)

cax = ax.matshow(conf_matrix)

fig.colorbar(cax)

for i, j in itertools.product(range(conf_matrix.shape[0]), range(conf_matrix.shape[1])):
    plt.text(j, i, conf_matrix[i, j], color="white")

plt.title('CNN+LSTM model')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.show()
 
    
test_pre_sco.append(precision)
test_rec_sco.append(recall)
test_spedi_sco.append(specificity)
test_sensi_sco.append(sensitivity)
    
print('val_loss:', val_loss)
print('test_loss:', test_loss)
print('test_acc:', test_acc)
    
print('precision:', precision)
print('recall:', recall)
print('specificity', specificity)
print('sensitivity : ', sensitivity)
print('far', far)
print('frr', frr)
# Out:
# Epoch 1/200
# 99/99 [==============================] - 3s 26ms/step - loss: 0.5678 - accuracy: 0.7411 - val_loss: 0.5205 - val_accuracy: 0.7367
# Epoch 2/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.4645 - accuracy: 0.7557 E
# Epoch 00002: val_loss improved from inf to 0.44725, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 23ms/step - loss: 0.4631 - accuracy: 0.7560 - val_loss: 0.4473 - val_accuracy: 0.7367
# Epoch 3/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.4112 - accuracy: 0.7922
# Epoch 00003: val_loss improved from 0.44725 to 0.41338, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 22ms/step - loss: 0.4108 - accuracy: 0.7925 - val_loss: 0.4134 - val_accuracy: 0.8289
# Epoch 4/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3942 - accuracy: 0.8289
# Epoch 00004: val_loss improved from 0.41338 to 0.40497, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 22ms/step - loss: 0.3951 - accuracy: 0.8270 - val_loss: 0.4050 - val_accuracy: 0.8251
# Epoch 5/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3779 - accuracy: 0.8324
# Epoch 00005: val_loss improved from 0.40497 to 0.40373, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 23ms/step - loss: 0.3779 - accuracy: 0.8324 - val_loss: 0.4037 - val_accuracy: 0.8356
# Epoch 6/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.3720 - accuracy: 0.8374
# Epoch 00006: val_loss improved from 0.40373 to 0.38093, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 22ms/step - loss: 0.3720 - accuracy: 0.8375 - val_loss: 0.3809 - val_accuracy: 0.8270
# Epoch 7/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.3638 - accuracy: 0.8425
# Epoch 00007: val_loss did not improve from 0.38093
# 99/99 [==============================] - 2s 20ms/step - loss: 0.3628 - accuracy: 0.8428 - val_loss: 0.3826 - val_accuracy: 0.8241
# Epoch 8/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.3664 - accuracy: 0.8367
# Epoch 00008: val_loss improved from 0.38093 to 0.37034, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 23ms/step - loss: 0.3660 - accuracy: 0.8368 - val_loss: 0.3703 - val_accuracy: 0.8346
# Epoch 9/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3542 - accuracy: 0.8505
# Epoch 00009: val_loss improved from 0.37034 to 0.36674, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 24ms/step - loss: 0.3549 - accuracy: 0.8495 - val_loss: 0.3667 - val_accuracy: 0.8422
# Epoch 10/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3589 - accuracy: 0.8441
# Epoch 00010: val_loss improved from 0.36674 to 0.35777, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 23ms/step - loss: 0.3575 - accuracy: 0.8447 - val_loss: 0.3578 - val_accuracy: 0.8498
# Epoch 11/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.3431 - accuracy: 0.8549
# Epoch 00011: val_loss did not improve from 0.35777
# 99/99 [==============================] - 2s 21ms/step - loss: 0.3421 - accuracy: 0.8555 - val_loss: 0.3603 - val_accuracy: 0.8546
# Epoch 12/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3362 - accuracy: 0.8599
# Epoch 00012: val_loss did not improve from 0.35777
# 99/99 [==============================] - 2s 22ms/step - loss: 0.3361 - accuracy: 0.8593 - val_loss: 0.3660 - val_accuracy: 0.8346
# Epoch 13/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3295 - accuracy: 0.8618
# Epoch 00013: val_loss improved from 0.35777 to 0.32791, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 22ms/step - loss: 0.3281 - accuracy: 0.8625 - val_loss: 0.3279 - val_accuracy: 0.8650
# Epoch 14/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.3276 - accuracy: 0.8584
# Epoch 00014: val_loss improved from 0.32791 to 0.32189, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 24ms/step - loss: 0.3264 - accuracy: 0.8590 - val_loss: 0.3219 - val_accuracy: 0.8698
# Epoch 15/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3167 - accuracy: 0.8688
# Epoch 00015: val_loss improved from 0.32189 to 0.31532, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 23ms/step - loss: 0.3167 - accuracy: 0.8688 - val_loss: 0.3153 - val_accuracy: 0.8783
# Epoch 16/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3110 - accuracy: 0.8764
# Epoch 00016: val_loss improved from 0.31532 to 0.30466, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 21ms/step - loss: 0.3110 - accuracy: 0.8764 - val_loss: 0.3047 - val_accuracy: 0.8774
# Epoch 17/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2997 - accuracy: 0.8824
# Epoch 00017: val_loss did not improve from 0.30466
# 99/99 [==============================] - 2s 22ms/step - loss: 0.2998 - accuracy: 0.8815 - val_loss: 0.3128 - val_accuracy: 0.8802
# Epoch 18/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.3029 - accuracy: 0.8852
# Epoch 00018: val_loss did not improve from 0.30466
# 99/99 [==============================] - 2s 22ms/step - loss: 0.3017 - accuracy: 0.8859 - val_loss: 0.3238 - val_accuracy: 0.8764
# Epoch 19/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2992 - accuracy: 0.8789
# Epoch 00019: val_loss improved from 0.30466 to 0.28765, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 22ms/step - loss: 0.2995 - accuracy: 0.8790 - val_loss: 0.2876 - val_accuracy: 0.8878
# Epoch 20/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2845 - accuracy: 0.8885
# Epoch 00020: val_loss improved from 0.28765 to 0.27390, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2834 - accuracy: 0.8891 - val_loss: 0.2739 - val_accuracy: 0.8964
# Epoch 21/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.2832 - accuracy: 0.8874
# Epoch 00021: val_loss did not improve from 0.27390
# 99/99 [==============================] - 2s 21ms/step - loss: 0.2817 - accuracy: 0.8885 - val_loss: 0.2789 - val_accuracy: 0.8983
# Epoch 22/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2797 - accuracy: 0.8897
# Epoch 00022: val_loss improved from 0.27390 to 0.26048, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 19ms/step - loss: 0.2797 - accuracy: 0.8897 - val_loss: 0.2605 - val_accuracy: 0.9087
# Epoch 23/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2758 - accuracy: 0.8929
# Epoch 00023: val_loss improved from 0.26048 to 0.25783, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 23ms/step - loss: 0.2758 - accuracy: 0.8929 - val_loss: 0.2578 - val_accuracy: 0.9021
# Epoch 24/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2609 - accuracy: 0.9005
# Epoch 00024: val_loss improved from 0.25783 to 0.25091, saving model to best_model_8.h5
# 99/99 [==============================] - 4s 37ms/step - loss: 0.2606 - accuracy: 0.9005 - val_loss: 0.2509 - val_accuracy: 0.9068
# Epoch 25/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2622 - accuracy: 0.9037
# Epoch 00025: val_loss improved from 0.25091 to 0.24863, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 21ms/step - loss: 0.2614 - accuracy: 0.9046 - val_loss: 0.2486 - val_accuracy: 0.9125
# Epoch 26/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2613 - accuracy: 0.8961
# Epoch 00026: val_loss improved from 0.24863 to 0.24808, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 21ms/step - loss: 0.2613 - accuracy: 0.8961 - val_loss: 0.2481 - val_accuracy: 0.9135
# Epoch 27/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2573 - accuracy: 0.9018
# Epoch 00027: val_loss improved from 0.24808 to 0.23875, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 22ms/step - loss: 0.2574 - accuracy: 0.9011 - val_loss: 0.2388 - val_accuracy: 0.9125
# Epoch 28/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2593 - accuracy: 0.9011
# Epoch 00028: val_loss improved from 0.23875 to 0.23198, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 21ms/step - loss: 0.2593 - accuracy: 0.9011 - val_loss: 0.2320 - val_accuracy: 0.9202
# Epoch 29/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2530 - accuracy: 0.8996
# Epoch 00029: val_loss improved from 0.23198 to 0.22428, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2530 - accuracy: 0.8996 - val_loss: 0.2243 - val_accuracy: 0.9144
# Epoch 30/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.2386 - accuracy: 0.9056
# Epoch 00030: val_loss did not improve from 0.22428
# 99/99 [==============================] - 2s 19ms/step - loss: 0.2376 - accuracy: 0.9062 - val_loss: 0.2552 - val_accuracy: 0.9078
# Epoch 31/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.2429 - accuracy: 0.9036
# Epoch 00031: val_loss did not improve from 0.22428
# 99/99 [==============================] - 2s 20ms/step - loss: 0.2441 - accuracy: 0.9030 - val_loss: 0.2334 - val_accuracy: 0.9097
# Epoch 32/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2349 - accuracy: 0.9125
# Epoch 00032: val_loss did not improve from 0.22428
# 99/99 [==============================] - 2s 19ms/step - loss: 0.2349 - accuracy: 0.9125 - val_loss: 0.2278 - val_accuracy: 0.9125
# Epoch 33/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2326 - accuracy: 0.9104
# Epoch 00033: val_loss improved from 0.22428 to 0.21592, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 19ms/step - loss: 0.2334 - accuracy: 0.9103 - val_loss: 0.2159 - val_accuracy: 0.9192
# Epoch 34/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2259 - accuracy: 0.9101
# Epoch 00034: val_loss did not improve from 0.21592
# 99/99 [==============================] - 2s 18ms/step - loss: 0.2267 - accuracy: 0.9094 - val_loss: 0.2413 - val_accuracy: 0.9144
# Epoch 35/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.2251 - accuracy: 0.9102
# Epoch 00035: val_loss did not improve from 0.21592
# 99/99 [==============================] - 2s 18ms/step - loss: 0.2228 - accuracy: 0.9116 - val_loss: 0.2169 - val_accuracy: 0.9154
# Epoch 36/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2334 - accuracy: 0.9094
# Epoch 00036: val_loss improved from 0.21592 to 0.21519, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 18ms/step - loss: 0.2328 - accuracy: 0.9094 - val_loss: 0.2152 - val_accuracy: 0.9230
# Epoch 37/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2241 - accuracy: 0.9110
# Epoch 00037: val_loss did not improve from 0.21519
# 99/99 [==============================] - 2s 18ms/step - loss: 0.2241 - accuracy: 0.9110 - val_loss: 0.2298 - val_accuracy: 0.9087
# Epoch 38/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2131 - accuracy: 0.9167
# Epoch 00038: val_loss improved from 0.21519 to 0.21246, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 18ms/step - loss: 0.2131 - accuracy: 0.9167 - val_loss: 0.2125 - val_accuracy: 0.9154
# Epoch 39/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2170 - accuracy: 0.9149
# Epoch 00039: val_loss did not improve from 0.21246
# 99/99 [==============================] - 2s 19ms/step - loss: 0.2177 - accuracy: 0.9154 - val_loss: 0.2205 - val_accuracy: 0.9183
# Epoch 40/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2113 - accuracy: 0.9196
# Epoch 00040: val_loss did not improve from 0.21246
# 99/99 [==============================] - 2s 19ms/step - loss: 0.2109 - accuracy: 0.9198 - val_loss: 0.2222 - val_accuracy: 0.9183
# Epoch 41/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2189 - accuracy: 0.9129
# Epoch 00041: val_loss did not improve from 0.21246
# 99/99 [==============================] - 2s 18ms/step - loss: 0.2183 - accuracy: 0.9132 - val_loss: 0.2353 - val_accuracy: 0.9116
# Epoch 42/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2127 - accuracy: 0.9169
# Epoch 00042: val_loss did not improve from 0.21246
# 99/99 [==============================] - 2s 19ms/step - loss: 0.2137 - accuracy: 0.9163 - val_loss: 0.2227 - val_accuracy: 0.9144
# Epoch 43/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2066 - accuracy: 0.9243
# Epoch 00043: val_loss did not improve from 0.21246
# 99/99 [==============================] - 2s 19ms/step - loss: 0.2066 - accuracy: 0.9243 - val_loss: 0.2147 - val_accuracy: 0.9135
# Epoch 44/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.2139 - accuracy: 0.9157
# Epoch 00044: val_loss did not improve from 0.21246
# 99/99 [==============================] - 2s 19ms/step - loss: 0.2131 - accuracy: 0.9167 - val_loss: 0.2303 - val_accuracy: 0.9154
# Epoch 45/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2146 - accuracy: 0.9230
# Epoch 00045: val_loss improved from 0.21246 to 0.20631, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 19ms/step - loss: 0.2146 - accuracy: 0.9230 - val_loss: 0.2063 - val_accuracy: 0.9211
# Epoch 46/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.2036 - accuracy: 0.9238
# Epoch 00046: val_loss did not improve from 0.20631
# 99/99 [==============================] - 2s 18ms/step - loss: 0.2042 - accuracy: 0.9230 - val_loss: 0.2614 - val_accuracy: 0.8945
# Epoch 47/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2043 - accuracy: 0.9209
# Epoch 00047: val_loss improved from 0.20631 to 0.19995, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 19ms/step - loss: 0.2047 - accuracy: 0.9211 - val_loss: 0.2000 - val_accuracy: 0.9268
# Epoch 48/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1960 - accuracy: 0.9238
# Epoch 00048: val_loss did not improve from 0.19995
# 99/99 [==============================] - 2s 19ms/step - loss: 0.1956 - accuracy: 0.9240 - val_loss: 0.2276 - val_accuracy: 0.9144
# Epoch 49/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1974 - accuracy: 0.9227
# Epoch 00049: val_loss did not improve from 0.19995
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1994 - accuracy: 0.9224 - val_loss: 0.2120 - val_accuracy: 0.9183
# Epoch 50/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2040 - accuracy: 0.9244
# Epoch 00050: val_loss did not improve from 0.19995
# 99/99 [==============================] - 2s 18ms/step - loss: 0.2037 - accuracy: 0.9246 - val_loss: 0.2109 - val_accuracy: 0.9278
# Epoch 51/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1963 - accuracy: 0.9274
# Epoch 00051: val_loss did not improve from 0.19995
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1963 - accuracy: 0.9274 - val_loss: 0.2092 - val_accuracy: 0.9125
# Epoch 52/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1951 - accuracy: 0.9255
# Epoch 00052: val_loss improved from 0.19995 to 0.19654, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1937 - accuracy: 0.9259 - val_loss: 0.1965 - val_accuracy: 0.9287
# Epoch 53/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1939 - accuracy: 0.9240
# Epoch 00053: val_loss did not improve from 0.19654
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1939 - accuracy: 0.9240 - val_loss: 0.2275 - val_accuracy: 0.9135
# Epoch 54/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2011 - accuracy: 0.9262
# Epoch 00054: val_loss did not improve from 0.19654
# 99/99 [==============================] - 2s 17ms/step - loss: 0.2008 - accuracy: 0.9265 - val_loss: 0.2139 - val_accuracy: 0.9183
# Epoch 55/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2010 - accuracy: 0.9211
# Epoch 00055: val_loss improved from 0.19654 to 0.19164, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 18ms/step - loss: 0.2031 - accuracy: 0.9205 - val_loss: 0.1916 - val_accuracy: 0.9173
# Epoch 56/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9199
# Epoch 00056: val_loss did not improve from 0.19164
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1993 - accuracy: 0.9195 - val_loss: 0.2190 - val_accuracy: 0.9125
# Epoch 57/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1939 - accuracy: 0.9277
# Epoch 00057: val_loss did not improve from 0.19164
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1950 - accuracy: 0.9278 - val_loss: 0.1979 - val_accuracy: 0.9249
# Epoch 58/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1896 - accuracy: 0.9279
# Epoch 00058: val_loss improved from 0.19164 to 0.18790, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1901 - accuracy: 0.9278 - val_loss: 0.1879 - val_accuracy: 0.9278
# Epoch 59/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1846 - accuracy: 0.9333
# Epoch 00059: val_loss did not improve from 0.18790
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1836 - accuracy: 0.9338 - val_loss: 0.1886 - val_accuracy: 0.9268
# Epoch 60/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1803 - accuracy: 0.9317
# Epoch 00060: val_loss improved from 0.18790 to 0.18352, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 19ms/step - loss: 0.1794 - accuracy: 0.9322 - val_loss: 0.1835 - val_accuracy: 0.9278
# Epoch 61/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1770 - accuracy: 0.9338
# Epoch 00061: val_loss did not improve from 0.18352
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1770 - accuracy: 0.9338 - val_loss: 0.2382 - val_accuracy: 0.8992
# Epoch 62/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1938 - accuracy: 0.9251
# Epoch 00062: val_loss did not improve from 0.18352
# 99/99 [==============================] - 2s 19ms/step - loss: 0.1924 - accuracy: 0.9249 - val_loss: 0.1884 - val_accuracy: 0.9278
# Epoch 63/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1795 - accuracy: 0.9308
# Epoch 00063: val_loss did not improve from 0.18352
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1805 - accuracy: 0.9306 - val_loss: 0.1935 - val_accuracy: 0.9268
# Epoch 64/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1867 - accuracy: 0.9284
# Epoch 00064: val_loss did not improve from 0.18352
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1867 - accuracy: 0.9284 - val_loss: 0.1907 - val_accuracy: 0.9268
# Epoch 65/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1730 - accuracy: 0.9368
# Epoch 00065: val_loss did not improve from 0.18352
# 99/99 [==============================] - 2s 19ms/step - loss: 0.1733 - accuracy: 0.9373 - val_loss: 0.1965 - val_accuracy: 0.9230
# Epoch 66/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1799 - accuracy: 0.9314
# Epoch 00066: val_loss improved from 0.18352 to 0.18312, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1800 - accuracy: 0.9312 - val_loss: 0.1831 - val_accuracy: 0.9316
# Epoch 67/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1756 - accuracy: 0.9265
# Epoch 00067: val_loss did not improve from 0.18312
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1760 - accuracy: 0.9262 - val_loss: 0.1989 - val_accuracy: 0.9211
# Epoch 68/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1751 - accuracy: 0.9354
# Epoch 00068: val_loss did not improve from 0.18312
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1751 - accuracy: 0.9354 - val_loss: 0.2236 - val_accuracy: 0.9011
# Epoch 69/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1796 - accuracy: 0.9308
# Epoch 00069: val_loss did not improve from 0.18312
# 99/99 [==============================] - 2s 19ms/step - loss: 0.1807 - accuracy: 0.9306 - val_loss: 0.2635 - val_accuracy: 0.8916
# Epoch 70/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1747 - accuracy: 0.9318
# Epoch 00070: val_loss improved from 0.18312 to 0.17995, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1741 - accuracy: 0.9322 - val_loss: 0.1800 - val_accuracy: 0.9278
# Epoch 71/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1675 - accuracy: 0.9320
# Epoch 00071: val_loss improved from 0.17995 to 0.17876, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1675 - accuracy: 0.9319 - val_loss: 0.1788 - val_accuracy: 0.9249
# Epoch 72/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1837 - accuracy: 0.9268
# Epoch 00072: val_loss did not improve from 0.17876
# 99/99 [==============================] - 2s 19ms/step - loss: 0.1837 - accuracy: 0.9268 - val_loss: 0.1831 - val_accuracy: 0.9306
# Epoch 73/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1764 - accuracy: 0.9253
# Epoch 00073: val_loss improved from 0.17876 to 0.17852, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1754 - accuracy: 0.9262 - val_loss: 0.1785 - val_accuracy: 0.9316
# Epoch 74/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1703 - accuracy: 0.9362
# Epoch 00074: val_loss did not improve from 0.17852
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1695 - accuracy: 0.9363 - val_loss: 0.2065 - val_accuracy: 0.9202
# Epoch 75/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1700 - accuracy: 0.9316
# Epoch 00075: val_loss did not improve from 0.17852
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1700 - accuracy: 0.9316 - val_loss: 0.1808 - val_accuracy: 0.9240
# Epoch 76/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1693 - accuracy: 0.9381
# Epoch 00076: val_loss did not improve from 0.17852
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1695 - accuracy: 0.9382 - val_loss: 0.1939 - val_accuracy: 0.9202
# Epoch 77/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1803 - accuracy: 0.9339
# Epoch 00077: val_loss did not improve from 0.17852
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1802 - accuracy: 0.9335 - val_loss: 0.1809 - val_accuracy: 0.9306
# Epoch 78/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1747 - accuracy: 0.9305
# Epoch 00078: val_loss did not improve from 0.17852
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1751 - accuracy: 0.9306 - val_loss: 0.1953 - val_accuracy: 0.9173
# Epoch 79/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1607 - accuracy: 0.9381
# Epoch 00079: val_loss did not improve from 0.17852
# 99/99 [==============================] - 2s 19ms/step - loss: 0.1611 - accuracy: 0.9382 - val_loss: 0.2161 - val_accuracy: 0.9087
# Epoch 80/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1737 - accuracy: 0.9336
# Epoch 00080: val_loss did not improve from 0.17852
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1726 - accuracy: 0.9341 - val_loss: 0.1978 - val_accuracy: 0.9173
# Epoch 81/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1746 - accuracy: 0.9307
# Epoch 00081: val_loss improved from 0.17852 to 0.17513, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1726 - accuracy: 0.9309 - val_loss: 0.1751 - val_accuracy: 0.9344
# Epoch 82/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1553 - accuracy: 0.9398
# Epoch 00082: val_loss did not improve from 0.17513
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1553 - accuracy: 0.9398 - val_loss: 0.1890 - val_accuracy: 0.9278
# Epoch 83/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1659 - accuracy: 0.9327
# Epoch 00083: val_loss did not improve from 0.17513
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1655 - accuracy: 0.9328 - val_loss: 0.1986 - val_accuracy: 0.9202
# Epoch 84/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1577 - accuracy: 0.9365
# Epoch 00084: val_loss improved from 0.17513 to 0.17401, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1600 - accuracy: 0.9354 - val_loss: 0.1740 - val_accuracy: 0.9306
# Epoch 85/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1574 - accuracy: 0.9391
# Epoch 00085: val_loss did not improve from 0.17401
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1571 - accuracy: 0.9388 - val_loss: 0.1831 - val_accuracy: 0.9306
# Epoch 86/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1528 - accuracy: 0.9417
# Epoch 00086: val_loss did not improve from 0.17401
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1528 - accuracy: 0.9417 - val_loss: 0.1865 - val_accuracy: 0.9287
# Epoch 87/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1612 - accuracy: 0.9411
# Epoch 00087: val_loss did not improve from 0.17401
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1612 - accuracy: 0.9411 - val_loss: 0.1789 - val_accuracy: 0.9249
# Epoch 88/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1612 - accuracy: 0.9359
# Epoch 00088: val_loss did not improve from 0.17401
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1613 - accuracy: 0.9357 - val_loss: 0.2394 - val_accuracy: 0.9068
# Epoch 89/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1630 - accuracy: 0.9343
# Epoch 00089: val_loss did not improve from 0.17401
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1642 - accuracy: 0.9338 - val_loss: 0.2076 - val_accuracy: 0.9249
# Epoch 90/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1667 - accuracy: 0.9300
# Epoch 00090: val_loss did not improve from 0.17401
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1667 - accuracy: 0.9290 - val_loss: 0.2221 - val_accuracy: 0.9087
# Epoch 91/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1491 - accuracy: 0.9440
# Epoch 00091: val_loss did not improve from 0.17401
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1520 - accuracy: 0.9420 - val_loss: 0.2148 - val_accuracy: 0.9154
# Epoch 92/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1612 - accuracy: 0.9323
# Epoch 00092: val_loss did not improve from 0.17401
# 99/99 [==============================] - 2s 18ms/step - loss: 0.1612 - accuracy: 0.9319 - val_loss: 0.2080 - val_accuracy: 0.9230
# Epoch 93/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1561 - accuracy: 0.9423
# Epoch 00093: val_loss improved from 0.17401 to 0.17349, saving model to best_model_8.h5
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1556 - accuracy: 0.9426 - val_loss: 0.1735 - val_accuracy: 0.9354
# Epoch 94/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1623 - accuracy: 0.9337
# Epoch 00094: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1630 - accuracy: 0.9335 - val_loss: 0.1852 - val_accuracy: 0.9287
# Epoch 95/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1741 - accuracy: 0.9336
# Epoch 00095: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1726 - accuracy: 0.9344 - val_loss: 0.1913 - val_accuracy: 0.9230
# Epoch 96/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1521 - accuracy: 0.9395
# Epoch 00096: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1521 - accuracy: 0.9395 - val_loss: 0.2001 - val_accuracy: 0.9173
# Epoch 97/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1493 - accuracy: 0.9378
# Epoch 00097: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 16ms/step - loss: 0.1479 - accuracy: 0.9385 - val_loss: 0.1895 - val_accuracy: 0.9278
# Epoch 98/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1501 - accuracy: 0.9385
# Epoch 00098: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1507 - accuracy: 0.9382 - val_loss: 0.1819 - val_accuracy: 0.9268
# Epoch 99/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1559 - accuracy: 0.9385
# Epoch 00099: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 16ms/step - loss: 0.1560 - accuracy: 0.9385 - val_loss: 0.1859 - val_accuracy: 0.9211
# Epoch 100/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1511 - accuracy: 0.9437
# Epoch 00100: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 16ms/step - loss: 0.1503 - accuracy: 0.9439 - val_loss: 0.1904 - val_accuracy: 0.9221
# Epoch 101/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1481 - accuracy: 0.9420
# Epoch 00101: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1481 - accuracy: 0.9420 - val_loss: 0.1738 - val_accuracy: 0.9316
# Epoch 102/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1462 - accuracy: 0.9427
# Epoch 00102: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1464 - accuracy: 0.9433 - val_loss: 0.2132 - val_accuracy: 0.9183
# Epoch 103/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1479 - accuracy: 0.9388
# Epoch 00103: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1479 - accuracy: 0.9388 - val_loss: 0.1948 - val_accuracy: 0.9230
# Epoch 104/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1563 - accuracy: 0.9382
# Epoch 00104: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1548 - accuracy: 0.9388 - val_loss: 0.1773 - val_accuracy: 0.9325
# Epoch 105/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1486 - accuracy: 0.9407
# Epoch 00105: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1476 - accuracy: 0.9407 - val_loss: 0.1841 - val_accuracy: 0.9306
# Epoch 106/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1383 - accuracy: 0.9453
# Epoch 00106: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1387 - accuracy: 0.9452 - val_loss: 0.1809 - val_accuracy: 0.9268
# Epoch 107/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1417 - accuracy: 0.9458
# Epoch 00107: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1412 - accuracy: 0.9461 - val_loss: 0.2019 - val_accuracy: 0.9116
# Epoch 108/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1407 - accuracy: 0.9447
# Epoch 00108: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1407 - accuracy: 0.9446 - val_loss: 0.1752 - val_accuracy: 0.9344
# Epoch 109/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1369 - accuracy: 0.9494
# Epoch 00109: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1403 - accuracy: 0.9480 - val_loss: 0.1818 - val_accuracy: 0.9306
# Epoch 110/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1371 - accuracy: 0.9439
# Epoch 00110: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 16ms/step - loss: 0.1361 - accuracy: 0.9446 - val_loss: 0.1989 - val_accuracy: 0.9240
# Epoch 111/200
# 96/99 [============================>.] - ETA: 0s - loss: 0.1447 - accuracy: 0.9408
# Epoch 00111: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1452 - accuracy: 0.9401 - val_loss: 0.2226 - val_accuracy: 0.9097
# Epoch 112/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1449 - accuracy: 0.9417
# Epoch 00112: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1449 - accuracy: 0.9417 - val_loss: 0.1978 - val_accuracy: 0.9202
# Epoch 113/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.9477
# Epoch 00113: val_loss did not improve from 0.17349
# 99/99 [==============================] - 2s 17ms/step - loss: 0.1384 - accuracy: 0.9477 - val_loss: 0.2195 - val_accuracy: 0.9183
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 480, 33)           231
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 160, 33)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 160, 63)           6300
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 53, 63)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 53, 55)            10450
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 17, 55)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 17, 55)            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 99)                61380
# _________________________________________________________________
# dense (Dense)                (None, 14)                1400
# _________________________________________________________________
# dense_1 (Dense)              (None, 42)                630
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 43
# =================================================================
# Total params: 80,434
# Trainable params: 80,434
# Non-trainable params: 0
# _________________________________________________________________
# 33/33 - 0s - loss: 0.1735 - accuracy: 0.9354
# 27/27 - 0s - loss: 0.3692 - accuracy: 0.8685
# val_loss: 0.17348894476890564
# test_loss: 0.3691841661930084
# test_acc: 0.8684834241867065
# precision: 0.7192982456140351
# recall: 0.7772511848341233
# specificity 0.8988941548183255
# sensitivity :  0.7772511848341233
# far 0.10110584518167456
# frr 0.22274881516587677
