# %%
# -*- coding: utf-8 -*-

import scipy.io
import numpy as np
import tensorflow as tf
import sklearn as sk
import matplotlib.pyplot as plt
import itertools
import random

from numba import cuda
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

from tensorflow.keras.callbacks import  EarlyStopping

# %%
# tensorflow = 2.
# python = 3.6


seed = np.random.seed(777)

gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
    
  try:
      
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
      
  except RuntimeError as e:
      
    print(e)


val_loss_all = []

test_loss_all = []
test_acc_all = []
test_pre_all = []
frr_all = []
far_all = []

conf_matrix_sco = []
test_pre_sco = []
test_rec_sco = []
test_spedi_sco = []
test_sensi_sco = []

class MyModelCheckpoint(tf.keras.callbacks.ModelCheckpoint):

    def __init__(self, *args, **kwargs):
        super(MyModelCheckpoint, self).__init__(*args, **kwargs)

    # redefine the save so it only activates after 100 epochs
    def on_epoch_end(self, epoch, logs=None):
        if epoch >= 1: super(MyModelCheckpoint, self).on_epoch_end(epoch, logs)

# %%
train_data = scipy.io.loadmat('../../../datas/160hz/train_5day_160hz.mat', squeeze_me=True)['data']
test_data = scipy.io.loadmat('../../../datas/160hz/test_6day_160hz(2).mat', squeeze_me=True)['data']

# sub 수
sub_cnt = train_data.shape[0]

# 3sec 데이터 크기
data_size = 480

# 1명당 3초 데이터 개수
train_data_cnt = 1052
test_data_cnt = 211

# 3sec 480(= 160*3) 크기로 데이터 길이 설정
train_cut_size = 504960 # 480*1052 = 504960
test_cut_size = 101280 # 480*211 = 101280

# 3sec 데이터 길이 자르기
# train: 504,960 / test: 101,280
train_data = train_data[:,0:train_cut_size,:]
test_data = test_data[:,0:test_cut_size,:]

# flatten(): 3D -> 1D / reshape(-1,1): -1 마지막 인덱스
train_flatten = train_data.flatten().reshape(-1,1)
test_flatten = test_data.flatten().reshape(-1,1)

# StandardScaler(): train에 맞춰 표준화
data_scaler = StandardScaler()
    
data_scaler.fit(train_flatten)
train_scaler = data_scaler.transform(train_flatten)
test_scaler = data_scaler.transform(test_flatten)
    
# train, test 데이터 reshape
train_data = train_scaler.reshape(train_data_cnt * sub_cnt, data_size, 2) 
test_data = test_scaler.reshape(test_data_cnt * sub_cnt, data_size, 2)

#train data를 sub:other=1:1로 만들기 위해서 각 sub 추출
train_data_each = []
for i in range(sub_cnt):
    train_data_each.insert(i, train_data[i*train_data_cnt:(i+1)*train_data_cnt, :, :])
print(np.shape(train_data_each))

#test data를 sub:other=1:3로 만들기 위해서 각 sub 추출
test_data_each = []
for i in range(sub_cnt):
    test_data_each.insert(i, test_data[i*test_data_cnt:(i+1)*test_data_cnt, :, :])
print(np.shape(test_data_each))
# Out:
# (11, 1052, 480, 2)
# (11, 211, 480, 2)

# %%
# sub number
sub_num = 3

#1 to 3 비율로 설정
ratio = 3

train_data_n = train_data_each[sub_num]
test_data_n = test_data_each[sub_num]

# train data를 sub:other = 1:3으로 만들기
# 3초 덩어리 개수 1052 : 3156
# => 315 * 4 + 316 * 6 = 1260 + 1896 = 3156

# test data를 sub:other = 1:3로 만들기
# 3초 덩어리 개수 211 : 633
# 63 * 7 + 64 * 3 = 633

cnt = 0
for j in range(sub_cnt):
    if j != sub_num and cnt < 4:
        cnt = cnt + 1
        train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 315)), axis = 0)
    elif j != sub_num and cnt >= 4:
        train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 316)), axis = 0)
#     print("train_data_n.shape")
#     print(train_data_n.shape)
#     print("train_data_n")
#     print(train_data_n)
        
cnt = 0
for j in range(sub_cnt):
    if j != sub_num and cnt < 7:
        cnt = cnt + 1
        test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 63)), axis = 0)
    elif j != sub_num and cnt >= 7:
        test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 64)), axis = 0)
        
        
        
train_label = np.zeros(train_data_cnt*(ratio+1))
test_label = np.zeros(test_data_cnt*(ratio+1))

for j in range(len(train_label)):
    if (j < train_data_cnt):
        train_label[j] = 1

for j in range(len(test_label)):
    if (j < test_data_cnt):
        test_label[j] = 1
        
train_data_shuffled, train_label_shuffled = sk.utils.shuffle(train_data_n, train_label, random_state = 0)

val_data_set = train_data_shuffled[:train_data_cnt]
train_data_set = train_data_shuffled[train_data_cnt:]

val_label_set = train_label_shuffled[:train_data_cnt]
train_label_set = train_label_shuffled[train_data_cnt:]

# %%
# model CNN-LSTM    
inputs = tf.keras.Input(shape = (480, 2))
conv_1 = tf.keras.layers.Conv1D(filters = 32, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(inputs)
max_1 = tf.keras.layers.MaxPool1D(3)(conv_1)
    
conv_2 = tf.keras.layers.Conv1D(filters = 32, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(max_1)
max_2 = tf.keras.layers.MaxPool1D(3)(conv_2)
    
conv_3 = tf.keras.layers.Conv1D(filters = 36, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(max_2)
max_3 = tf.keras.layers.MaxPool1D(3)(conv_3)
    

D_out_1 = tf.keras.layers.Dropout(0.5994355970980556)(max_3)
    
    
lstm_1 = tf.keras.layers.LSTM(245)(D_out_1)
    
dense_1 = tf.keras.layers.Dense(220, activation = 'relu')(lstm_1)
dense_2 = tf.keras.layers.Dense(50, activation = 'relu')(dense_1)
dense_3 = tf.keras.layers.Dense(1, activation = 'sigmoid')(dense_2)
    
model = tf.keras.models.Model(inputs = inputs, outputs = dense_3)

# Adam
model.compile(loss = 'binary_crossentropy', optimizer = tf.keras.optimizers.Adam(0.00021122153321731643), metrics = ['accuracy'])
# SGD
# model.compile(loss= 'binary_crossentropy', optimizer= tf.keras.optimizers.SGD(learning_rate=0.0461300729767683, momentum=0.4411297369087802), metrics=['accuracy'])
    
# EarlyStopping 조기종료 및 모델 학습
early_stopping = tf.keras.callbacks.EarlyStopping(patience = 20)
check_point = MyModelCheckpoint('best_model_' + str(sub_num + 1) + '.h5', monitor = 'val_loss', mode = 'min', save_best_only = True, verbose = 1)

# EarlyStopping 사용
hist = model.fit(train_data_set, train_label_set, epochs = 200, batch_size = 32, validation_data = (val_data_set, val_label_set), callbacks = [early_stopping, check_point])
# EarlyStopping 미사용
# hist = model.fit(train_data_set, train_label_set, epochs = 200, batch_size = 32, validation_data = (val_data_set, val_label_set), callbacks = [check_point])

# model save .h5형식
model = tf.keras.models.load_model('best_model_' + str(sub_num + 1) + '.h5')
model.save('Binary_BOHB_' + str(sub_num + 1) + '.h5')
model.summary() 
        
val_loss, val_acc = model.evaluate(val_data_set, val_label_set, verbose = 2)

test_loss, test_acc = model.evaluate(test_data_n, test_label, verbose = 2)
test_pred = model.predict(test_data_n)
        
    
# 각 행은 1sec, 0.5 <= 자신, 0.5 > 타인
for i in range(len(test_pred)):
    if(test_pred[i] >= 0.5):
        test_pred[i] = 1
    
    else: 
        test_pred[i] = 0
    
    
val_loss_all.append(val_loss)
    
test_loss_all.append(test_loss)
test_acc_all.append(test_acc)
test_pre_all.append(test_pred)
    

conf_matrix = confusion_matrix(test_label, test_pred) 
conf_matrix_sco.append(conf_matrix)
    
conf_row = conf_matrix.sum(axis = 1)
conf_col = conf_matrix.sum(axis = 0)

precision = conf_matrix[1][1] / conf_col[1]
recall = conf_matrix[1][1] / conf_row[1]
specificity = conf_matrix[0][0] / conf_row[0]
sensitivity = conf_matrix[1][1] / conf_row[1]
frr = conf_matrix[1][0] / (conf_matrix[1][1]+conf_matrix[1][0])
far = conf_matrix[0][1] / (conf_matrix[0][1]+conf_matrix[0][0])
    
frr_all.append(frr)
far_all.append(far)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111)

cax = ax.matshow(conf_matrix)

fig.colorbar(cax)

for i, j in itertools.product(range(conf_matrix.shape[0]), range(conf_matrix.shape[1])):
    plt.text(j, i, conf_matrix[i, j], color="white")

plt.title('CNN+LSTM model')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.show()
 
    
test_pre_sco.append(precision)
test_rec_sco.append(recall)
test_spedi_sco.append(specificity)
test_sensi_sco.append(sensitivity)
    
print('val_loss:', val_loss)
print('test_loss:', test_loss)
print('test_acc:', test_acc)
    
print('precision:', precision)
print('recall:', recall)
print('specificity', specificity)
print('sensitivity : ', sensitivity)
print('far', far)
print('frr', frr)
# Out:
# Epoch 1/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.5052 - accuracy: 0.7544 - val_loss: 0.4624 - val_accuracy: 0.7367
# Epoch 2/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.4250 - accuracy: 0.7873
# Epoch 00002: val_loss improved from inf to 0.37340, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 29ms/step - loss: 0.4244 - accuracy: 0.7874 - val_loss: 0.3734 - val_accuracy: 0.8394
# Epoch 3/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3719 - accuracy: 0.8296
# Epoch 00003: val_loss improved from 0.37340 to 0.33867, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 30ms/step - loss: 0.3714 - accuracy: 0.8302 - val_loss: 0.3387 - val_accuracy: 0.8584
# Epoch 4/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3522 - accuracy: 0.8302
# Epoch 00004: val_loss did not improve from 0.33867
# 99/99 [==============================] - 3s 29ms/step - loss: 0.3530 - accuracy: 0.8295 - val_loss: 0.3772 - val_accuracy: 0.8137
# Epoch 5/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.3327 - accuracy: 0.8450
# Epoch 00005: val_loss improved from 0.33867 to 0.30657, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.3325 - accuracy: 0.8451 - val_loss: 0.3066 - val_accuracy: 0.8764
# Epoch 6/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.3210 - accuracy: 0.8575
# Epoch 00006: val_loss did not improve from 0.30657
# 99/99 [==============================] - 3s 30ms/step - loss: 0.3213 - accuracy: 0.8574 - val_loss: 0.3180 - val_accuracy: 0.8441
# Epoch 7/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.3120 - accuracy: 0.8619
# Epoch 00007: val_loss improved from 0.30657 to 0.29671, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 31ms/step - loss: 0.3111 - accuracy: 0.8628 - val_loss: 0.2967 - val_accuracy: 0.8698
# Epoch 8/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2708 - accuracy: 0.8834
# Epoch 00008: val_loss improved from 0.29671 to 0.27485, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2707 - accuracy: 0.8828 - val_loss: 0.2748 - val_accuracy: 0.8793
# Epoch 9/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.8707
# Epoch 00009: val_loss improved from 0.27485 to 0.27285, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2799 - accuracy: 0.8707 - val_loss: 0.2728 - val_accuracy: 0.8850
# Epoch 10/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2553 - accuracy: 0.8910
# Epoch 00010: val_loss improved from 0.27285 to 0.26732, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2553 - accuracy: 0.8910 - val_loss: 0.2673 - val_accuracy: 0.8831
# Epoch 11/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2556 - accuracy: 0.8904
# Epoch 00011: val_loss improved from 0.26732 to 0.22626, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2556 - accuracy: 0.8904 - val_loss: 0.2263 - val_accuracy: 0.9030
# Epoch 12/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2447 - accuracy: 0.8989
# Epoch 00012: val_loss did not improve from 0.22626
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2440 - accuracy: 0.8992 - val_loss: 0.2332 - val_accuracy: 0.9021
# Epoch 13/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2491 - accuracy: 0.8913
# Epoch 00013: val_loss did not improve from 0.22626
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2504 - accuracy: 0.8904 - val_loss: 0.2304 - val_accuracy: 0.9002
# Epoch 14/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2395 - accuracy: 0.9002
# Epoch 00014: val_loss did not improve from 0.22626
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2386 - accuracy: 0.9008 - val_loss: 0.2474 - val_accuracy: 0.8992
# Epoch 15/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2380 - accuracy: 0.8980
# Epoch 00015: val_loss did not improve from 0.22626
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2379 - accuracy: 0.8977 - val_loss: 0.2408 - val_accuracy: 0.8897
# Epoch 16/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2233 - accuracy: 0.9046
# Epoch 00016: val_loss improved from 0.22626 to 0.21582, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 33ms/step - loss: 0.2233 - accuracy: 0.9046 - val_loss: 0.2158 - val_accuracy: 0.9021
# Epoch 17/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2026 - accuracy: 0.9151
# Epoch 00017: val_loss improved from 0.21582 to 0.21549, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2026 - accuracy: 0.9151 - val_loss: 0.2155 - val_accuracy: 0.9087
# Epoch 18/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2225 - accuracy: 0.9056
# Epoch 00018: val_loss improved from 0.21549 to 0.20671, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2225 - accuracy: 0.9056 - val_loss: 0.2067 - val_accuracy: 0.9068
# Epoch 19/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2051 - accuracy: 0.9130
# Epoch 00019: val_loss did not improve from 0.20671
# 99/99 [==============================] - 3s 34ms/step - loss: 0.2050 - accuracy: 0.9132 - val_loss: 0.2113 - val_accuracy: 0.9078
# Epoch 20/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2008 - accuracy: 0.9157
# Epoch 00020: val_loss did not improve from 0.20671
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2008 - accuracy: 0.9157 - val_loss: 0.2112 - val_accuracy: 0.9040
# Epoch 21/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2023 - accuracy: 0.9174
# Epoch 00021: val_loss improved from 0.20671 to 0.20546, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2044 - accuracy: 0.9173 - val_loss: 0.2055 - val_accuracy: 0.9125
# Epoch 22/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1965 - accuracy: 0.9187
# Epoch 00022: val_loss improved from 0.20546 to 0.19639, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.1973 - accuracy: 0.9179 - val_loss: 0.1964 - val_accuracy: 0.9116
# Epoch 23/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1843 - accuracy: 0.9282
# Epoch 00023: val_loss did not improve from 0.19639
# 99/99 [==============================] - 3s 32ms/step - loss: 0.1855 - accuracy: 0.9274 - val_loss: 0.2086 - val_accuracy: 0.9106
# Epoch 24/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1891 - accuracy: 0.9214
# Epoch 00024: val_loss did not improve from 0.19639
# 99/99 [==============================] - 3s 30ms/step - loss: 0.1902 - accuracy: 0.9214 - val_loss: 0.2021 - val_accuracy: 0.9087
# Epoch 25/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1917 - accuracy: 0.9203
# Epoch 00025: val_loss improved from 0.19639 to 0.19334, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.1912 - accuracy: 0.9205 - val_loss: 0.1933 - val_accuracy: 0.9240
# Epoch 26/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1865 - accuracy: 0.9232
# Epoch 00026: val_loss did not improve from 0.19334
# 99/99 [==============================] - 3s 33ms/step - loss: 0.1860 - accuracy: 0.9233 - val_loss: 0.2187 - val_accuracy: 0.9068
# Epoch 27/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1766 - accuracy: 0.9268
# Epoch 00027: val_loss did not improve from 0.19334
# 99/99 [==============================] - 3s 33ms/step - loss: 0.1766 - accuracy: 0.9268 - val_loss: 0.1986 - val_accuracy: 0.9116
# Epoch 28/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1831 - accuracy: 0.9270
# Epoch 00028: val_loss did not improve from 0.19334
# 99/99 [==============================] - 3s 32ms/step - loss: 0.1839 - accuracy: 0.9268 - val_loss: 0.1984 - val_accuracy: 0.9173
# Epoch 29/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1789 - accuracy: 0.9289
# Epoch 00029: val_loss did not improve from 0.19334
# 99/99 [==============================] - 3s 33ms/step - loss: 0.1786 - accuracy: 0.9290 - val_loss: 0.1948 - val_accuracy: 0.9144
# Epoch 30/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1819 - accuracy: 0.9262
# Epoch 00030: val_loss did not improve from 0.19334
# 99/99 [==============================] - 3s 34ms/step - loss: 0.1819 - accuracy: 0.9262 - val_loss: 0.2281 - val_accuracy: 0.8954
# Epoch 31/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1776 - accuracy: 0.9260
# Epoch 00031: val_loss did not improve from 0.19334
# 99/99 [==============================] - 3s 34ms/step - loss: 0.1771 - accuracy: 0.9262 - val_loss: 0.2058 - val_accuracy: 0.9116
# Epoch 32/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1750 - accuracy: 0.9293
# Epoch 00032: val_loss did not improve from 0.19334
# 99/99 [==============================] - 3s 33ms/step - loss: 0.1750 - accuracy: 0.9293 - val_loss: 0.1979 - val_accuracy: 0.9192
# Epoch 33/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1726 - accuracy: 0.9337
# Epoch 00033: val_loss improved from 0.19334 to 0.18747, saving model to best_model_4.h5
# 99/99 [==============================] - 4s 36ms/step - loss: 0.1723 - accuracy: 0.9338 - val_loss: 0.1875 - val_accuracy: 0.9211
# Epoch 34/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1703 - accuracy: 0.9318
# Epoch 00034: val_loss improved from 0.18747 to 0.18128, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 35ms/step - loss: 0.1705 - accuracy: 0.9312 - val_loss: 0.1813 - val_accuracy: 0.9230
# Epoch 35/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1599 - accuracy: 0.9395
# Epoch 00035: val_loss did not improve from 0.18128
# 99/99 [==============================] - 3s 30ms/step - loss: 0.1599 - accuracy: 0.9395 - val_loss: 0.1932 - val_accuracy: 0.9240
# Epoch 36/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1619 - accuracy: 0.9379
# Epoch 00036: val_loss did not improve from 0.18128
# 99/99 [==============================] - 3s 34ms/step - loss: 0.1619 - accuracy: 0.9379 - val_loss: 0.1870 - val_accuracy: 0.9211
# Epoch 37/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1650 - accuracy: 0.9357
# Epoch 00037: val_loss did not improve from 0.18128
# 99/99 [==============================] - 4s 36ms/step - loss: 0.1650 - accuracy: 0.9357 - val_loss: 0.2644 - val_accuracy: 0.9040
# Epoch 38/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1640 - accuracy: 0.9327
# Epoch 00038: val_loss did not improve from 0.18128
# 99/99 [==============================] - 3s 34ms/step - loss: 0.1645 - accuracy: 0.9325 - val_loss: 0.2571 - val_accuracy: 0.9040
# Epoch 39/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1606 - accuracy: 0.9349
# Epoch 00039: val_loss did not improve from 0.18128
# 99/99 [==============================] - 3s 35ms/step - loss: 0.1605 - accuracy: 0.9347 - val_loss: 0.1986 - val_accuracy: 0.9173
# Epoch 40/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1545 - accuracy: 0.9369
# Epoch 00040: val_loss did not improve from 0.18128
# 99/99 [==============================] - 3s 34ms/step - loss: 0.1545 - accuracy: 0.9369 - val_loss: 0.1915 - val_accuracy: 0.9221
# Epoch 41/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1546 - accuracy: 0.9411
# Epoch 00041: val_loss did not improve from 0.18128
# 99/99 [==============================] - 3s 31ms/step - loss: 0.1546 - accuracy: 0.9411 - val_loss: 0.1872 - val_accuracy: 0.9240
# Epoch 42/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1548 - accuracy: 0.9432
# Epoch 00042: val_loss did not improve from 0.18128
# 99/99 [==============================] - 3s 33ms/step - loss: 0.1545 - accuracy: 0.9433 - val_loss: 0.1853 - val_accuracy: 0.9221
# Epoch 43/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1569 - accuracy: 0.9354
# Epoch 00043: val_loss did not improve from 0.18128
# 99/99 [==============================] - 3s 33ms/step - loss: 0.1569 - accuracy: 0.9354 - val_loss: 0.2273 - val_accuracy: 0.9021
# Epoch 44/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1510 - accuracy: 0.9369
# Epoch 00044: val_loss did not improve from 0.18128
# 99/99 [==============================] - 3s 33ms/step - loss: 0.1510 - accuracy: 0.9369 - val_loss: 0.1982 - val_accuracy: 0.9163
# Epoch 45/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1660 - accuracy: 0.9346
# Epoch 00045: val_loss improved from 0.18128 to 0.17908, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 33ms/step - loss: 0.1662 - accuracy: 0.9344 - val_loss: 0.1791 - val_accuracy: 0.9211
# Epoch 46/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1503 - accuracy: 0.9414
# Epoch 00046: val_loss did not improve from 0.17908
# 99/99 [==============================] - 4s 45ms/step - loss: 0.1503 - accuracy: 0.9414 - val_loss: 0.1827 - val_accuracy: 0.9230
# Epoch 47/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1436 - accuracy: 0.9448
# Epoch 00047: val_loss did not improve from 0.17908
# 99/99 [==============================] - 3s 33ms/step - loss: 0.1431 - accuracy: 0.9452 - val_loss: 0.1804 - val_accuracy: 0.9230
# Epoch 48/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1462 - accuracy: 0.9394
# Epoch 00048: val_loss did not improve from 0.17908
# 99/99 [==============================] - 3s 34ms/step - loss: 0.1455 - accuracy: 0.9398 - val_loss: 0.1845 - val_accuracy: 0.9240
# Epoch 49/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1677 - accuracy: 0.9359
# Epoch 00049: val_loss did not improve from 0.17908
# 99/99 [==============================] - 3s 33ms/step - loss: 0.1672 - accuracy: 0.9360 - val_loss: 0.1852 - val_accuracy: 0.9230
# Epoch 50/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1477 - accuracy: 0.9446
# Epoch 00050: val_loss did not improve from 0.17908
# 99/99 [==============================] - 3s 30ms/step - loss: 0.1478 - accuracy: 0.9446 - val_loss: 0.1865 - val_accuracy: 0.9192
# Epoch 51/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1578 - accuracy: 0.9407
# Epoch 00051: val_loss did not improve from 0.17908
# 99/99 [==============================] - 3s 31ms/step - loss: 0.1574 - accuracy: 0.9411 - val_loss: 0.1851 - val_accuracy: 0.9173
# Epoch 52/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1547 - accuracy: 0.9353
# Epoch 00052: val_loss did not improve from 0.17908
# 99/99 [==============================] - 3s 30ms/step - loss: 0.1543 - accuracy: 0.9350 - val_loss: 0.2360 - val_accuracy: 0.9068
# Epoch 53/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1355 - accuracy: 0.9467
# Epoch 00053: val_loss did not improve from 0.17908
# 99/99 [==============================] - 3s 30ms/step - loss: 0.1356 - accuracy: 0.9465 - val_loss: 0.1796 - val_accuracy: 0.9278
# Epoch 54/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1411 - accuracy: 0.9452
# Epoch 00054: val_loss did not improve from 0.17908
# 99/99 [==============================] - 3s 28ms/step - loss: 0.1411 - accuracy: 0.9452 - val_loss: 0.1796 - val_accuracy: 0.9240
# Epoch 55/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1350 - accuracy: 0.9488
# Epoch 00055: val_loss did not improve from 0.17908
# 99/99 [==============================] - 3s 29ms/step - loss: 0.1347 - accuracy: 0.9490 - val_loss: 0.1875 - val_accuracy: 0.9259
# Epoch 56/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1408 - accuracy: 0.9448
# Epoch 00056: val_loss did not improve from 0.17908
# 99/99 [==============================] - 3s 30ms/step - loss: 0.1401 - accuracy: 0.9452 - val_loss: 0.1807 - val_accuracy: 0.9211
# Epoch 57/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1374 - accuracy: 0.9477
# Epoch 00057: val_loss did not improve from 0.17908
# 99/99 [==============================] - 3s 28ms/step - loss: 0.1374 - accuracy: 0.9477 - val_loss: 0.2285 - val_accuracy: 0.9087
# Epoch 58/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1301 - accuracy: 0.9512
# Epoch 00058: val_loss improved from 0.17908 to 0.17678, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 30ms/step - loss: 0.1301 - accuracy: 0.9512 - val_loss: 0.1768 - val_accuracy: 0.9211
# Epoch 59/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9347
# Epoch 00059: val_loss did not improve from 0.17678
# 99/99 [==============================] - 3s 28ms/step - loss: 0.1609 - accuracy: 0.9347 - val_loss: 0.2075 - val_accuracy: 0.9087
# Epoch 60/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1343 - accuracy: 0.9474
# Epoch 00060: val_loss did not improve from 0.17678
# 99/99 [==============================] - 3s 29ms/step - loss: 0.1340 - accuracy: 0.9477 - val_loss: 0.1839 - val_accuracy: 0.9183
# Epoch 61/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1390 - accuracy: 0.9455
# Epoch 00061: val_loss did not improve from 0.17678
# 99/99 [==============================] - 3s 28ms/step - loss: 0.1395 - accuracy: 0.9452 - val_loss: 0.2096 - val_accuracy: 0.9125
# Epoch 62/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1417 - accuracy: 0.9407
# Epoch 00062: val_loss did not improve from 0.17678
# 99/99 [==============================] - 3s 29ms/step - loss: 0.1407 - accuracy: 0.9417 - val_loss: 0.1797 - val_accuracy: 0.9173
# Epoch 63/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1261 - accuracy: 0.9487
# Epoch 00063: val_loss did not improve from 0.17678
# 99/99 [==============================] - 3s 28ms/step - loss: 0.1266 - accuracy: 0.9480 - val_loss: 0.1794 - val_accuracy: 0.9221
# Epoch 64/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1320 - accuracy: 0.9526
# Epoch 00064: val_loss did not improve from 0.17678
# 99/99 [==============================] - 3s 29ms/step - loss: 0.1312 - accuracy: 0.9531 - val_loss: 0.1798 - val_accuracy: 0.9278
# Epoch 65/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1247 - accuracy: 0.9525
# Epoch 00065: val_loss did not improve from 0.17678
# 99/99 [==============================] - 3s 27ms/step - loss: 0.1247 - accuracy: 0.9525 - val_loss: 0.2025 - val_accuracy: 0.9125
# Epoch 66/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1276 - accuracy: 0.9474
# Epoch 00066: val_loss improved from 0.17678 to 0.17535, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 28ms/step - loss: 0.1281 - accuracy: 0.9471 - val_loss: 0.1753 - val_accuracy: 0.9249
# Epoch 67/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1435 - accuracy: 0.9439
# Epoch 00067: val_loss did not improve from 0.17535
# 99/99 [==============================] - 3s 28ms/step - loss: 0.1435 - accuracy: 0.9439 - val_loss: 0.1919 - val_accuracy: 0.9211
# Epoch 68/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1178 - accuracy: 0.9556
# Epoch 00068: val_loss did not improve from 0.17535
# 99/99 [==============================] - 3s 29ms/step - loss: 0.1178 - accuracy: 0.9556 - val_loss: 0.1888 - val_accuracy: 0.9221
# Epoch 69/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1292 - accuracy: 0.9522
# Epoch 00069: val_loss did not improve from 0.17535
# 99/99 [==============================] - 3s 28ms/step - loss: 0.1292 - accuracy: 0.9522 - val_loss: 0.1830 - val_accuracy: 0.9183
# Epoch 70/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1307 - accuracy: 0.9496
# Epoch 00070: val_loss improved from 0.17535 to 0.17198, saving model to best_model_4.h5
# 99/99 [==============================] - 3s 29ms/step - loss: 0.1310 - accuracy: 0.9496 - val_loss: 0.1720 - val_accuracy: 0.9249
# Epoch 71/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1316 - accuracy: 0.9465
# Epoch 00071: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 28ms/step - loss: 0.1307 - accuracy: 0.9468 - val_loss: 0.1875 - val_accuracy: 0.9268
# Epoch 72/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1199 - accuracy: 0.9541
# Epoch 00072: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 29ms/step - loss: 0.1201 - accuracy: 0.9541 - val_loss: 0.1980 - val_accuracy: 0.9230
# Epoch 73/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1240 - accuracy: 0.9525
# Epoch 00073: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 27ms/step - loss: 0.1241 - accuracy: 0.9522 - val_loss: 0.1795 - val_accuracy: 0.9240
# Epoch 74/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1142 - accuracy: 0.9595
# Epoch 00074: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 27ms/step - loss: 0.1136 - accuracy: 0.9598 - val_loss: 0.2213 - val_accuracy: 0.9116
# Epoch 75/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1139 - accuracy: 0.9539
# Epoch 00075: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 28ms/step - loss: 0.1156 - accuracy: 0.9534 - val_loss: 0.1820 - val_accuracy: 0.9287
# Epoch 76/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1116 - accuracy: 0.9572
# Epoch 00076: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 29ms/step - loss: 0.1105 - accuracy: 0.9575 - val_loss: 0.2018 - val_accuracy: 0.9287
# Epoch 77/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1225 - accuracy: 0.9534
# Epoch 00077: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 28ms/step - loss: 0.1225 - accuracy: 0.9534 - val_loss: 0.1831 - val_accuracy: 0.9278
# Epoch 78/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1173 - accuracy: 0.9570
# Epoch 00078: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 29ms/step - loss: 0.1177 - accuracy: 0.9569 - val_loss: 0.1801 - val_accuracy: 0.9240
# Epoch 79/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1154 - accuracy: 0.9560
# Epoch 00079: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 29ms/step - loss: 0.1154 - accuracy: 0.9560 - val_loss: 0.1843 - val_accuracy: 0.9259
# Epoch 80/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1408 - accuracy: 0.9427
# Epoch 00080: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 28ms/step - loss: 0.1390 - accuracy: 0.9436 - val_loss: 0.1736 - val_accuracy: 0.9306
# Epoch 81/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1082 - accuracy: 0.9623
# Epoch 00081: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 29ms/step - loss: 0.1093 - accuracy: 0.9620 - val_loss: 0.2097 - val_accuracy: 0.9202
# Epoch 82/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1095 - accuracy: 0.9595
# Epoch 00082: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 29ms/step - loss: 0.1097 - accuracy: 0.9594 - val_loss: 0.1789 - val_accuracy: 0.9259
# Epoch 83/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1135 - accuracy: 0.9572
# Epoch 00083: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 28ms/step - loss: 0.1140 - accuracy: 0.9566 - val_loss: 0.1783 - val_accuracy: 0.9268
# Epoch 84/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1174 - accuracy: 0.9536
# Epoch 00084: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 28ms/step - loss: 0.1175 - accuracy: 0.9537 - val_loss: 0.1901 - val_accuracy: 0.9230
# Epoch 85/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1165 - accuracy: 0.9566
# Epoch 00085: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 28ms/step - loss: 0.1159 - accuracy: 0.9569 - val_loss: 0.1999 - val_accuracy: 0.9287
# Epoch 86/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1147 - accuracy: 0.9559
# Epoch 00086: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 27ms/step - loss: 0.1142 - accuracy: 0.9560 - val_loss: 0.1838 - val_accuracy: 0.9268
# Epoch 87/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1148 - accuracy: 0.9572
# Epoch 00087: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 29ms/step - loss: 0.1150 - accuracy: 0.9569 - val_loss: 0.1958 - val_accuracy: 0.9325
# Epoch 88/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1097 - accuracy: 0.9550
# Epoch 00088: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 27ms/step - loss: 0.1097 - accuracy: 0.9550 - val_loss: 0.1828 - val_accuracy: 0.9249
# Epoch 89/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1043 - accuracy: 0.9576
# Epoch 00089: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 27ms/step - loss: 0.1042 - accuracy: 0.9575 - val_loss: 0.1931 - val_accuracy: 0.9183
# Epoch 90/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1025 - accuracy: 0.9553
# Epoch 00090: val_loss did not improve from 0.17198
# 99/99 [==============================] - 3s 26ms/step - loss: 0.1025 - accuracy: 0.9553 - val_loss: 0.2902 - val_accuracy: 0.9030
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 480, 32)           224
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 160, 32)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 160, 32)           3104
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 53, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 53, 36)            3492
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 17, 36)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 17, 36)            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 245)               276360
# _________________________________________________________________
# dense (Dense)                (None, 220)               54120
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                11050
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 348,401
# Trainable params: 348,401
# Non-trainable params: 0
# _________________________________________________________________
# 33/33 - 0s - loss: 0.1720 - accuracy: 0.9249
# 27/27 - 0s - loss: 0.1884 - accuracy: 0.9336
# val_loss: 0.17197534441947937
# test_loss: 0.1884324550628662
# test_acc: 0.9336493015289307
# precision: 0.8163265306122449
# recall: 0.9478672985781991
# specificity 0.9289099526066351
# sensitivity :  0.9478672985781991
# far 0.07109004739336493
# frr 0.052132701421800945
