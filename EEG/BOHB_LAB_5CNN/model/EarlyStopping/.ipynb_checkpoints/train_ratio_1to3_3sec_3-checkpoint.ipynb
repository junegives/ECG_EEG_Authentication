# %%
# -*- coding: utf-8 -*-

import scipy.io
import numpy as np
import tensorflow as tf
import sklearn as sk
import matplotlib.pyplot as plt
import itertools
import random

from numba import cuda
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

from tensorflow.keras.callbacks import  EarlyStopping

# %%
# tensorflow = 2.
# python = 3.6


seed = np.random.seed(777)

gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
    
  try:
      
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
      
  except RuntimeError as e:
      
    print(e)


val_loss_all = []

test_loss_all = []
test_acc_all = []
test_pre_all = []
frr_all = []
far_all = []

conf_matrix_sco = []
test_pre_sco = []
test_rec_sco = []
test_spedi_sco = []
test_sensi_sco = []

class MyModelCheckpoint(tf.keras.callbacks.ModelCheckpoint):

    def __init__(self, *args, **kwargs):
        super(MyModelCheckpoint, self).__init__(*args, **kwargs)

    # redefine the save so it only activates after 100 epochs
    def on_epoch_end(self, epoch, logs=None):
        if epoch >= 1: super(MyModelCheckpoint, self).on_epoch_end(epoch, logs)

# %%
train_data = scipy.io.loadmat('../../../datas/160hz/train_5day_160hz.mat', squeeze_me=True)['data']
test_data = scipy.io.loadmat('../../../datas/160hz/test_6day_160hz(2).mat', squeeze_me=True)['data']

# sub 수
sub_cnt = train_data.shape[0]

# 3sec 데이터 크기
data_size = 480

# 1명당 3초 데이터 개수
train_data_cnt = 1052
test_data_cnt = 211

# 3sec 480(= 160*3) 크기로 데이터 길이 설정
train_cut_size = 504960 # 480*1052 = 504960
test_cut_size = 101280 # 480*211 = 101280

# 3sec 데이터 길이 자르기
# train: 504,960 / test: 101,280
train_data = train_data[:,0:train_cut_size,:]
test_data = test_data[:,0:test_cut_size,:]

# flatten(): 3D -> 1D / reshape(-1,1): -1 마지막 인덱스
train_flatten = train_data.flatten().reshape(-1,1)
test_flatten = test_data.flatten().reshape(-1,1)

# StandardScaler(): train에 맞춰 표준화
data_scaler = StandardScaler()
    
data_scaler.fit(train_flatten)
train_scaler = data_scaler.transform(train_flatten)
test_scaler = data_scaler.transform(test_flatten)
    
# train, test 데이터 reshape
train_data = train_scaler.reshape(train_data_cnt * sub_cnt, data_size, 2) 
test_data = test_scaler.reshape(test_data_cnt * sub_cnt, data_size, 2)

#train data를 sub:other=1:1로 만들기 위해서 각 sub 추출
train_data_each = []
for i in range(sub_cnt):
    train_data_each.insert(i, train_data[i*train_data_cnt:(i+1)*train_data_cnt, :, :])
print(np.shape(train_data_each))

#test data를 sub:other=1:3로 만들기 위해서 각 sub 추출
test_data_each = []
for i in range(sub_cnt):
    test_data_each.insert(i, test_data[i*test_data_cnt:(i+1)*test_data_cnt, :, :])
print(np.shape(test_data_each))
# Out:
# (11, 1052, 480, 2)
# (11, 211, 480, 2)

# %%
# sub number
sub_num = 2

#1 to 3 비율로 설정
ratio = 3

train_data_n = train_data_each[sub_num]
test_data_n = test_data_each[sub_num]

# train data를 sub:other = 1:3으로 만들기
# 3초 덩어리 개수 1052 : 3156
# => 315 * 4 + 316 * 6 = 1260 + 1896 = 3156

# test data를 sub:other = 1:3로 만들기
# 3초 덩어리 개수 211 : 633
# 63 * 7 + 64 * 3 = 633

cnt = 0
for j in range(sub_cnt):
    if j != sub_num and cnt < 4:
        cnt = cnt + 1
        train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 315)), axis = 0)
    elif j != sub_num and cnt >= 4:
        train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 316)), axis = 0)
#     print("train_data_n.shape")
#     print(train_data_n.shape)
#     print("train_data_n")
#     print(train_data_n)
        
cnt = 0
for j in range(sub_cnt):
    if j != sub_num and cnt < 7:
        cnt = cnt + 1
        test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 63)), axis = 0)
    elif j != sub_num and cnt >= 7:
        test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 64)), axis = 0)
        
        
        
train_label = np.zeros(train_data_cnt*(ratio+1))
test_label = np.zeros(test_data_cnt*(ratio+1))

for j in range(len(train_label)):
    if (j < train_data_cnt):
        train_label[j] = 1

for j in range(len(test_label)):
    if (j < test_data_cnt):
        test_label[j] = 1
        
train_data_shuffled, train_label_shuffled = sk.utils.shuffle(train_data_n, train_label, random_state = 0)

val_data_set = train_data_shuffled[:train_data_cnt]
train_data_set = train_data_shuffled[train_data_cnt:]

val_label_set = train_label_shuffled[:train_data_cnt]
train_label_set = train_label_shuffled[train_data_cnt:]

# %%
# model CNN-LSTM    
inputs = tf.keras.Input(shape = (480, 2))
conv_1 = tf.keras.layers.Conv1D(filters = 18, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(inputs)
max_1 = tf.keras.layers.MaxPool1D(3)(conv_1)
    
conv_2 = tf.keras.layers.Conv1D(filters = 58, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(max_1)
max_2 = tf.keras.layers.MaxPool1D(3)(conv_2)
    
# conv_3 = tf.keras.layers.Conv1D(filters = 43, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(max_2)
# max_3 = tf.keras.layers.MaxPool1D(3)(conv_3)
    

D_out_1 = tf.keras.layers.Dropout(0.5201428691759254)(max_2)
    
    
lstm_1 = tf.keras.layers.LSTM(17)(D_out_1)
    
dense_1 = tf.keras.layers.Dense(85, activation = 'relu')(lstm_1)
dense_2 = tf.keras.layers.Dense(19, activation = 'relu')(dense_1)
dense_3 = tf.keras.layers.Dense(1, activation = 'sigmoid')(dense_2)
    
model = tf.keras.models.Model(inputs = inputs, outputs = dense_3)

# Adam
model.compile(loss = 'binary_crossentropy', optimizer = tf.keras.optimizers.Adam(0.0018805757938221066), metrics = ['accuracy'])
# SGD
# model.compile(loss= 'binary_crossentropy', optimizer= tf.keras.optimizers.SGD(learning_rate=0.0461300729767683, momentum=0.4411297369087802), metrics=['accuracy'])
    
# EarlyStopping 조기종료 및 모델 학습
early_stopping = tf.keras.callbacks.EarlyStopping(patience = 20)
check_point = MyModelCheckpoint('best_model_' + str(sub_num + 1) + '.h5', monitor = 'val_loss', mode = 'min', save_best_only = True, verbose = 1)

# EarlyStopping 사용
hist = model.fit(train_data_set, train_label_set, epochs = 200, batch_size = 32, validation_data = (val_data_set, val_label_set), callbacks = [early_stopping, check_point])
# EarlyStopping 미사용
# hist = model.fit(train_data_set, train_label_set, epochs = 200, batch_size = 32, validation_data = (val_data_set, val_label_set), callbacks = [check_point])

# model save .h5형식
model = tf.keras.models.load_model('best_model_' + str(sub_num + 1) + '.h5')
model.save('Binary_BOHB_' + str(sub_num + 1) + '.h5')
model.summary() 
        
val_loss, val_acc = model.evaluate(val_data_set, val_label_set, verbose = 2)

test_loss, test_acc = model.evaluate(test_data_n, test_label, verbose = 2)
test_pred = model.predict(test_data_n)
        
    
# 각 행은 1sec, 0.5 <= 자신, 0.5 > 타인
for i in range(len(test_pred)):
    if(test_pred[i] >= 0.5):
        test_pred[i] = 1
    
    else: 
        test_pred[i] = 0
    
    
val_loss_all.append(val_loss)
    
test_loss_all.append(test_loss)
test_acc_all.append(test_acc)
test_pre_all.append(test_pred)
    

conf_matrix = confusion_matrix(test_label, test_pred) 
conf_matrix_sco.append(conf_matrix)
    
conf_row = conf_matrix.sum(axis = 1)
conf_col = conf_matrix.sum(axis = 0)

precision = conf_matrix[1][1] / conf_col[1]
recall = conf_matrix[1][1] / conf_row[1]
specificity = conf_matrix[0][0] / conf_row[0]
sensitivity = conf_matrix[1][1] / conf_row[1]
frr = conf_matrix[1][0] / (conf_matrix[1][1]+conf_matrix[1][0])
far = conf_matrix[0][1] / (conf_matrix[0][1]+conf_matrix[0][0])
    
frr_all.append(frr)
far_all.append(far)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111)

cax = ax.matshow(conf_matrix)

fig.colorbar(cax)

for i, j in itertools.product(range(conf_matrix.shape[0]), range(conf_matrix.shape[1])):
    plt.text(j, i, conf_matrix[i, j], color="white")

plt.title('CNN+LSTM model')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.show()
 
    
test_pre_sco.append(precision)
test_rec_sco.append(recall)
test_spedi_sco.append(specificity)
test_sensi_sco.append(sensitivity)
    
print('val_loss:', val_loss)
print('test_loss:', test_loss)
print('test_acc:', test_acc)
    
print('precision:', precision)
print('recall:', recall)
print('specificity', specificity)
print('sensitivity : ', sensitivity)
print('far', far)
print('frr', frr)
# Out:
# Epoch 1/200
# 99/99 [==============================] - 2s 25ms/step - loss: 0.5342 - accuracy: 0.7563 - val_loss: 0.4223 - val_accuracy: 0.7861
# Epoch 2/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.4069 - accuracy: 0.7867
# Epoch 00002: val_loss improved from inf to 0.36698, saving model to best_model_3.h5
# 99/99 [==============================] - 2s 21ms/step - loss: 0.4076 - accuracy: 0.7861 - val_loss: 0.3670 - val_accuracy: 0.8270
# Epoch 3/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3713 - accuracy: 0.8143
# Epoch 00003: val_loss did not improve from 0.36698
# 99/99 [==============================] - 2s 22ms/step - loss: 0.3713 - accuracy: 0.8143 - val_loss: 0.3907 - val_accuracy: 0.7662
# Epoch 4/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3594 - accuracy: 0.8229
# Epoch 00004: val_loss improved from 0.36698 to 0.30514, saving model to best_model_3.h5
# 99/99 [==============================] - 2s 23ms/step - loss: 0.3594 - accuracy: 0.8229 - val_loss: 0.3051 - val_accuracy: 0.8565
# Epoch 5/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3206 - accuracy: 0.8505
# Epoch 00005: val_loss improved from 0.30514 to 0.28546, saving model to best_model_3.h5
# 99/99 [==============================] - 2s 22ms/step - loss: 0.3189 - accuracy: 0.8517 - val_loss: 0.2855 - val_accuracy: 0.8660
# Epoch 6/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3028 - accuracy: 0.8547
# Epoch 00006: val_loss did not improve from 0.28546
# 99/99 [==============================] - 2s 22ms/step - loss: 0.3050 - accuracy: 0.8530 - val_loss: 0.3282 - val_accuracy: 0.8574
# Epoch 7/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.3122 - accuracy: 0.8518
# Epoch 00007: val_loss did not improve from 0.28546
# 99/99 [==============================] - 2s 22ms/step - loss: 0.3119 - accuracy: 0.8527 - val_loss: 0.3039 - val_accuracy: 0.8793
# Epoch 8/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2807 - accuracy: 0.8734
# Epoch 00008: val_loss improved from 0.28546 to 0.26621, saving model to best_model_3.h5
# 99/99 [==============================] - 2s 24ms/step - loss: 0.2825 - accuracy: 0.8726 - val_loss: 0.2662 - val_accuracy: 0.8878
# Epoch 9/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2551 - accuracy: 0.8911
# Epoch 00009: val_loss improved from 0.26621 to 0.23810, saving model to best_model_3.h5
# 99/99 [==============================] - 2s 22ms/step - loss: 0.2552 - accuracy: 0.8910 - val_loss: 0.2381 - val_accuracy: 0.8992
# Epoch 10/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.2370 - accuracy: 0.8985
# Epoch 00010: val_loss improved from 0.23810 to 0.20648, saving model to best_model_3.h5
# 99/99 [==============================] - 2s 23ms/step - loss: 0.2365 - accuracy: 0.8986 - val_loss: 0.2065 - val_accuracy: 0.9183
# Epoch 11/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2231 - accuracy: 0.9037
# Epoch 00011: val_loss improved from 0.20648 to 0.19350, saving model to best_model_3.h5
# 99/99 [==============================] - 3s 26ms/step - loss: 0.2231 - accuracy: 0.9037 - val_loss: 0.1935 - val_accuracy: 0.9154
# Epoch 12/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2163 - accuracy: 0.9104
# Epoch 00012: val_loss did not improve from 0.19350
# 99/99 [==============================] - 2s 24ms/step - loss: 0.2163 - accuracy: 0.9106 - val_loss: 0.2601 - val_accuracy: 0.8793
# Epoch 13/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1962 - accuracy: 0.9186
# Epoch 00013: val_loss improved from 0.19350 to 0.16974, saving model to best_model_3.h5
# 99/99 [==============================] - 2s 24ms/step - loss: 0.1962 - accuracy: 0.9186 - val_loss: 0.1697 - val_accuracy: 0.9259
# Epoch 14/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2028 - accuracy: 0.9167
# Epoch 00014: val_loss did not improve from 0.16974
# 99/99 [==============================] - 2s 24ms/step - loss: 0.2028 - accuracy: 0.9167 - val_loss: 0.2619 - val_accuracy: 0.8802
# Epoch 15/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1802 - accuracy: 0.9259
# Epoch 00015: val_loss did not improve from 0.16974
# 99/99 [==============================] - 2s 23ms/step - loss: 0.1802 - accuracy: 0.9259 - val_loss: 0.1732 - val_accuracy: 0.9316
# Epoch 16/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1917 - accuracy: 0.9224
# Epoch 00016: val_loss improved from 0.16974 to 0.15666, saving model to best_model_3.h5
# 99/99 [==============================] - 2s 23ms/step - loss: 0.1917 - accuracy: 0.9224 - val_loss: 0.1567 - val_accuracy: 0.9392
# Epoch 17/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1769 - accuracy: 0.9278
# Epoch 00017: val_loss improved from 0.15666 to 0.15160, saving model to best_model_3.h5
# 99/99 [==============================] - 2s 24ms/step - loss: 0.1769 - accuracy: 0.9278 - val_loss: 0.1516 - val_accuracy: 0.9373
# Epoch 18/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1647 - accuracy: 0.9349
# Epoch 00018: val_loss improved from 0.15160 to 0.14391, saving model to best_model_3.h5
# 99/99 [==============================] - 2s 24ms/step - loss: 0.1636 - accuracy: 0.9354 - val_loss: 0.1439 - val_accuracy: 0.9420
# Epoch 19/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1687 - accuracy: 0.9356
# Epoch 00019: val_loss did not improve from 0.14391
# 99/99 [==============================] - 2s 24ms/step - loss: 0.1674 - accuracy: 0.9360 - val_loss: 0.2559 - val_accuracy: 0.9125
# Epoch 20/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1614 - accuracy: 0.9314
# Epoch 00020: val_loss did not improve from 0.14391
# 99/99 [==============================] - 2s 23ms/step - loss: 0.1594 - accuracy: 0.9325 - val_loss: 0.1676 - val_accuracy: 0.9354
# Epoch 21/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1489 - accuracy: 0.9423
# Epoch 00021: val_loss did not improve from 0.14391
# 99/99 [==============================] - 2s 23ms/step - loss: 0.1489 - accuracy: 0.9423 - val_loss: 0.1471 - val_accuracy: 0.9392
# Epoch 22/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1493 - accuracy: 0.9369
# Epoch 00022: val_loss did not improve from 0.14391
# 99/99 [==============================] - 2s 22ms/step - loss: 0.1511 - accuracy: 0.9366 - val_loss: 0.1790 - val_accuracy: 0.9240
# Epoch 23/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1458 - accuracy: 0.9404
# Epoch 00023: val_loss improved from 0.14391 to 0.13980, saving model to best_model_3.h5
# 99/99 [==============================] - 2s 24ms/step - loss: 0.1452 - accuracy: 0.9407 - val_loss: 0.1398 - val_accuracy: 0.9449
# Epoch 24/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1292 - accuracy: 0.9467
# Epoch 00024: val_loss did not improve from 0.13980
# 99/99 [==============================] - 2s 24ms/step - loss: 0.1291 - accuracy: 0.9468 - val_loss: 0.1438 - val_accuracy: 0.9449
# Epoch 25/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1278 - accuracy: 0.9461
# Epoch 00025: val_loss improved from 0.13980 to 0.13348, saving model to best_model_3.h5
# 99/99 [==============================] - 3s 26ms/step - loss: 0.1278 - accuracy: 0.9461 - val_loss: 0.1335 - val_accuracy: 0.9430
# Epoch 26/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1402 - accuracy: 0.9465
# Epoch 00026: val_loss did not improve from 0.13348
# 99/99 [==============================] - 2s 24ms/step - loss: 0.1402 - accuracy: 0.9465 - val_loss: 0.1348 - val_accuracy: 0.9458
# Epoch 27/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1363 - accuracy: 0.9449
# Epoch 00027: val_loss improved from 0.13348 to 0.13227, saving model to best_model_3.h5
# 99/99 [==============================] - 2s 25ms/step - loss: 0.1370 - accuracy: 0.9452 - val_loss: 0.1323 - val_accuracy: 0.9468
# Epoch 28/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1292 - accuracy: 0.9464
# Epoch 00028: val_loss did not improve from 0.13227
# 99/99 [==============================] - 2s 24ms/step - loss: 0.1296 - accuracy: 0.9465 - val_loss: 0.1419 - val_accuracy: 0.9477
# Epoch 29/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1167 - accuracy: 0.9504
# Epoch 00029: val_loss did not improve from 0.13227
# 99/99 [==============================] - 2s 24ms/step - loss: 0.1162 - accuracy: 0.9509 - val_loss: 0.1394 - val_accuracy: 0.9363
# Epoch 30/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1269 - accuracy: 0.9468
# Epoch 00030: val_loss improved from 0.13227 to 0.12386, saving model to best_model_3.h5
# 99/99 [==============================] - 2s 25ms/step - loss: 0.1269 - accuracy: 0.9468 - val_loss: 0.1239 - val_accuracy: 0.9468
# Epoch 31/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1225 - accuracy: 0.9534
# Epoch 00031: val_loss did not improve from 0.12386
# 99/99 [==============================] - 2s 25ms/step - loss: 0.1234 - accuracy: 0.9531 - val_loss: 0.1484 - val_accuracy: 0.9382
# Epoch 32/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1210 - accuracy: 0.9539
# Epoch 00032: val_loss improved from 0.12386 to 0.12084, saving model to best_model_3.h5
# 99/99 [==============================] - 3s 26ms/step - loss: 0.1217 - accuracy: 0.9534 - val_loss: 0.1208 - val_accuracy: 0.9534
# Epoch 33/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1159 - accuracy: 0.9515
# Epoch 00033: val_loss did not improve from 0.12084
# 99/99 [==============================] - 2s 24ms/step - loss: 0.1159 - accuracy: 0.9515 - val_loss: 0.1257 - val_accuracy: 0.9496
# Epoch 34/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1055 - accuracy: 0.9598
# Epoch 00034: val_loss did not improve from 0.12084
# 99/99 [==============================] - 2s 24ms/step - loss: 0.1055 - accuracy: 0.9598 - val_loss: 0.1215 - val_accuracy: 0.9487
# Epoch 35/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1298 - accuracy: 0.9452
# Epoch 00035: val_loss did not improve from 0.12084
# 99/99 [==============================] - 2s 25ms/step - loss: 0.1305 - accuracy: 0.9446 - val_loss: 0.1568 - val_accuracy: 0.9363
# Epoch 36/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1048 - accuracy: 0.9565
# Epoch 00036: val_loss did not improve from 0.12084
# 99/99 [==============================] - 3s 26ms/step - loss: 0.1056 - accuracy: 0.9563 - val_loss: 0.1344 - val_accuracy: 0.9430
# Epoch 37/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1122 - accuracy: 0.9562
# Epoch 00037: val_loss did not improve from 0.12084
# 99/99 [==============================] - 3s 26ms/step - loss: 0.1123 - accuracy: 0.9563 - val_loss: 0.1750 - val_accuracy: 0.9392
# Epoch 38/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.1150 - accuracy: 0.9520
# Epoch 00038: val_loss improved from 0.12084 to 0.10838, saving model to best_model_3.h5
# 99/99 [==============================] - 3s 26ms/step - loss: 0.1142 - accuracy: 0.9525 - val_loss: 0.1084 - val_accuracy: 0.9591
# Epoch 39/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1080 - accuracy: 0.9560
# Epoch 00039: val_loss did not improve from 0.10838
# 99/99 [==============================] - 2s 24ms/step - loss: 0.1080 - accuracy: 0.9560 - val_loss: 0.1283 - val_accuracy: 0.9553
# Epoch 40/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.9636
# Epoch 00040: val_loss did not improve from 0.10838
# 99/99 [==============================] - 2s 25ms/step - loss: 0.0942 - accuracy: 0.9636 - val_loss: 0.1249 - val_accuracy: 0.9544
# Epoch 41/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0952 - accuracy: 0.9632
# Epoch 00041: val_loss did not improve from 0.10838
# 99/99 [==============================] - 2s 24ms/step - loss: 0.0952 - accuracy: 0.9632 - val_loss: 0.1476 - val_accuracy: 0.9458
# Epoch 42/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0955 - accuracy: 0.9620
# Epoch 00042: val_loss did not improve from 0.10838
# 99/99 [==============================] - 2s 24ms/step - loss: 0.0955 - accuracy: 0.9620 - val_loss: 0.1489 - val_accuracy: 0.9430
# Epoch 43/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1052 - accuracy: 0.9594
# Epoch 00043: val_loss did not improve from 0.10838
# 99/99 [==============================] - 2s 25ms/step - loss: 0.1052 - accuracy: 0.9594 - val_loss: 0.1207 - val_accuracy: 0.9601
# Epoch 44/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0915 - accuracy: 0.9640
# Epoch 00044: val_loss did not improve from 0.10838
# 99/99 [==============================] - 2s 25ms/step - loss: 0.0918 - accuracy: 0.9636 - val_loss: 0.1122 - val_accuracy: 0.9601
# Epoch 45/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1019 - accuracy: 0.9582
# Epoch 00045: val_loss did not improve from 0.10838
# 99/99 [==============================] - 3s 25ms/step - loss: 0.1019 - accuracy: 0.9582 - val_loss: 0.1357 - val_accuracy: 0.9468
# Epoch 46/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0824 - accuracy: 0.9703
# Epoch 00046: val_loss did not improve from 0.10838
# 99/99 [==============================] - 3s 25ms/step - loss: 0.0825 - accuracy: 0.9702 - val_loss: 0.1273 - val_accuracy: 0.9563
# Epoch 47/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0965 - accuracy: 0.9582
# Epoch 00047: val_loss did not improve from 0.10838
# 99/99 [==============================] - 2s 25ms/step - loss: 0.0978 - accuracy: 0.9582 - val_loss: 0.1950 - val_accuracy: 0.9420
# Epoch 48/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0794 - accuracy: 0.9686
# Epoch 00048: val_loss did not improve from 0.10838
# 99/99 [==============================] - 3s 25ms/step - loss: 0.0794 - accuracy: 0.9686 - val_loss: 0.1258 - val_accuracy: 0.9582
# Epoch 49/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1053 - accuracy: 0.9608
# Epoch 00049: val_loss improved from 0.10838 to 0.10606, saving model to best_model_3.h5
# 99/99 [==============================] - 2s 25ms/step - loss: 0.1054 - accuracy: 0.9607 - val_loss: 0.1061 - val_accuracy: 0.9639
# Epoch 50/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0844 - accuracy: 0.9659
# Epoch 00050: val_loss did not improve from 0.10606
# 99/99 [==============================] - 3s 26ms/step - loss: 0.0840 - accuracy: 0.9661 - val_loss: 0.1729 - val_accuracy: 0.9325
# Epoch 51/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0887 - accuracy: 0.9646
# Epoch 00051: val_loss did not improve from 0.10606
# 99/99 [==============================] - 3s 26ms/step - loss: 0.0885 - accuracy: 0.9645 - val_loss: 0.1103 - val_accuracy: 0.9534
# Epoch 52/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0880 - accuracy: 0.9642
# Epoch 00052: val_loss did not improve from 0.10606
# 99/99 [==============================] - 2s 25ms/step - loss: 0.0880 - accuracy: 0.9642 - val_loss: 0.1196 - val_accuracy: 0.9496
# Epoch 53/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0805 - accuracy: 0.9691
# Epoch 00053: val_loss did not improve from 0.10606
# 99/99 [==============================] - 3s 27ms/step - loss: 0.0806 - accuracy: 0.9689 - val_loss: 0.1432 - val_accuracy: 0.9506
# Epoch 54/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0856 - accuracy: 0.9652
# Epoch 00054: val_loss did not improve from 0.10606
# 99/99 [==============================] - 3s 27ms/step - loss: 0.0856 - accuracy: 0.9651 - val_loss: 0.1144 - val_accuracy: 0.9553
# Epoch 55/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9728
# Epoch 00055: val_loss improved from 0.10606 to 0.10237, saving model to best_model_3.h5
# 99/99 [==============================] - 3s 28ms/step - loss: 0.0782 - accuracy: 0.9728 - val_loss: 0.1024 - val_accuracy: 0.9563
# Epoch 56/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0665 - accuracy: 0.9710
# Epoch 00056: val_loss did not improve from 0.10237
# 99/99 [==============================] - 3s 27ms/step - loss: 0.0666 - accuracy: 0.9708 - val_loss: 0.1201 - val_accuracy: 0.9468
# Epoch 57/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0742 - accuracy: 0.9696
# Epoch 00057: val_loss did not improve from 0.10237
# 99/99 [==============================] - 3s 27ms/step - loss: 0.0742 - accuracy: 0.9696 - val_loss: 0.1210 - val_accuracy: 0.9601
# Epoch 58/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.1002 - accuracy: 0.9598
# Epoch 00058: val_loss did not improve from 0.10237
# 99/99 [==============================] - 3s 28ms/step - loss: 0.0997 - accuracy: 0.9601 - val_loss: 0.1159 - val_accuracy: 0.9582
# Epoch 59/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0738 - accuracy: 0.9700
# Epoch 00059: val_loss did not improve from 0.10237
# 99/99 [==============================] - 3s 27ms/step - loss: 0.0734 - accuracy: 0.9702 - val_loss: 0.1703 - val_accuracy: 0.9306
# Epoch 60/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0707 - accuracy: 0.9712
# Epoch 00060: val_loss did not improve from 0.10237
# 99/99 [==============================] - 3s 27ms/step - loss: 0.0707 - accuracy: 0.9712 - val_loss: 0.1110 - val_accuracy: 0.9553
# Epoch 61/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0728 - accuracy: 0.9710
# Epoch 00061: val_loss did not improve from 0.10237
# 99/99 [==============================] - 3s 27ms/step - loss: 0.0732 - accuracy: 0.9708 - val_loss: 0.1204 - val_accuracy: 0.9582
# Epoch 62/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0629 - accuracy: 0.9774
# Epoch 00062: val_loss did not improve from 0.10237
# 99/99 [==============================] - 3s 27ms/step - loss: 0.0631 - accuracy: 0.9772 - val_loss: 0.1519 - val_accuracy: 0.9477
# Epoch 63/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1048 - accuracy: 0.9550
# Epoch 00063: val_loss did not improve from 0.10237
# 99/99 [==============================] - 2s 25ms/step - loss: 0.1048 - accuracy: 0.9550 - val_loss: 0.1110 - val_accuracy: 0.9601
# Epoch 64/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0699 - accuracy: 0.9719
# Epoch 00064: val_loss did not improve from 0.10237
# 99/99 [==============================] - 2s 25ms/step - loss: 0.0698 - accuracy: 0.9721 - val_loss: 0.1120 - val_accuracy: 0.9515
# Epoch 65/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0620 - accuracy: 0.9745
# Epoch 00065: val_loss did not improve from 0.10237
# 99/99 [==============================] - 3s 26ms/step - loss: 0.0617 - accuracy: 0.9747 - val_loss: 0.1487 - val_accuracy: 0.9373
# Epoch 66/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0736 - accuracy: 0.9716
# Epoch 00066: val_loss did not improve from 0.10237
# 99/99 [==============================] - 2s 24ms/step - loss: 0.0735 - accuracy: 0.9715 - val_loss: 0.1141 - val_accuracy: 0.9591
# Epoch 67/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0652 - accuracy: 0.9739
# Epoch 00067: val_loss did not improve from 0.10237
# 99/99 [==============================] - 3s 27ms/step - loss: 0.0653 - accuracy: 0.9737 - val_loss: 0.1124 - val_accuracy: 0.9620
# Epoch 68/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0638 - accuracy: 0.9758
# Epoch 00068: val_loss did not improve from 0.10237
# 99/99 [==============================] - 3s 25ms/step - loss: 0.0647 - accuracy: 0.9756 - val_loss: 0.1736 - val_accuracy: 0.9382
# Epoch 69/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0631 - accuracy: 0.9755
# Epoch 00069: val_loss did not improve from 0.10237
# 99/99 [==============================] - 5s 46ms/step - loss: 0.0646 - accuracy: 0.9750 - val_loss: 0.1243 - val_accuracy: 0.9572
# Epoch 70/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0625 - accuracy: 0.9765
# Epoch 00070: val_loss improved from 0.10237 to 0.10166, saving model to best_model_3.h5
# 99/99 [==============================] - 2s 25ms/step - loss: 0.0628 - accuracy: 0.9762 - val_loss: 0.1017 - val_accuracy: 0.9639
# Epoch 71/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0622 - accuracy: 0.9758
# Epoch 00071: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 24ms/step - loss: 0.0628 - accuracy: 0.9756 - val_loss: 0.1246 - val_accuracy: 0.9620
# Epoch 72/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0687 - accuracy: 0.9735
# Epoch 00072: val_loss did not improve from 0.10166
# 99/99 [==============================] - 3s 26ms/step - loss: 0.0685 - accuracy: 0.9737 - val_loss: 0.1208 - val_accuracy: 0.9639
# Epoch 73/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0774 - accuracy: 0.9721
# Epoch 00073: val_loss did not improve from 0.10166
# 99/99 [==============================] - 3s 27ms/step - loss: 0.0774 - accuracy: 0.9721 - val_loss: 0.1158 - val_accuracy: 0.9620
# Epoch 74/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0649 - accuracy: 0.9761
# Epoch 00074: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 25ms/step - loss: 0.0659 - accuracy: 0.9759 - val_loss: 0.1146 - val_accuracy: 0.9572
# Epoch 75/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0689 - accuracy: 0.9736
# Epoch 00075: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 25ms/step - loss: 0.0690 - accuracy: 0.9737 - val_loss: 0.1214 - val_accuracy: 0.9515
# Epoch 76/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0563 - accuracy: 0.9753
# Epoch 00076: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 24ms/step - loss: 0.0563 - accuracy: 0.9753 - val_loss: 0.1138 - val_accuracy: 0.9525
# Epoch 77/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0496 - accuracy: 0.9812
# Epoch 00077: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 23ms/step - loss: 0.0493 - accuracy: 0.9813 - val_loss: 0.1550 - val_accuracy: 0.9487
# Epoch 78/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.0614 - accuracy: 0.9764
# Epoch 00078: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 23ms/step - loss: 0.0623 - accuracy: 0.9762 - val_loss: 0.1526 - val_accuracy: 0.9430
# Epoch 79/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 0.9800
# Epoch 00079: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 23ms/step - loss: 0.0550 - accuracy: 0.9800 - val_loss: 0.1231 - val_accuracy: 0.9639
# Epoch 80/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0747 - accuracy: 0.9712
# Epoch 00080: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 23ms/step - loss: 0.0747 - accuracy: 0.9712 - val_loss: 0.1255 - val_accuracy: 0.9496
# Epoch 81/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0492 - accuracy: 0.9816
# Epoch 00081: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 22ms/step - loss: 0.0486 - accuracy: 0.9819 - val_loss: 0.1269 - val_accuracy: 0.9572
# Epoch 82/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 0.9813
# Epoch 00082: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 23ms/step - loss: 0.0468 - accuracy: 0.9813 - val_loss: 0.1102 - val_accuracy: 0.9582
# Epoch 83/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.9699
# Epoch 00083: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 24ms/step - loss: 0.0695 - accuracy: 0.9699 - val_loss: 0.1147 - val_accuracy: 0.9553
# Epoch 84/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9813
# Epoch 00084: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 23ms/step - loss: 0.0527 - accuracy: 0.9813 - val_loss: 0.1345 - val_accuracy: 0.9582
# Epoch 85/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.9743
# Epoch 00085: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 23ms/step - loss: 0.0661 - accuracy: 0.9743 - val_loss: 0.1411 - val_accuracy: 0.9458
# Epoch 86/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0638 - accuracy: 0.9734
# Epoch 00086: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 24ms/step - loss: 0.0638 - accuracy: 0.9734 - val_loss: 0.1403 - val_accuracy: 0.9572
# Epoch 87/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0601 - accuracy: 0.9765
# Epoch 00087: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 21ms/step - loss: 0.0593 - accuracy: 0.9769 - val_loss: 0.1536 - val_accuracy: 0.9487
# Epoch 88/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 0.9845
# Epoch 00088: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 23ms/step - loss: 0.0466 - accuracy: 0.9845 - val_loss: 0.1327 - val_accuracy: 0.9620
# Epoch 89/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0369 - accuracy: 0.9865
# Epoch 00089: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 24ms/step - loss: 0.0364 - accuracy: 0.9867 - val_loss: 0.1480 - val_accuracy: 0.9572
# Epoch 90/200
# 97/99 [============================>.] - ETA: 0s - loss: 0.0534 - accuracy: 0.9816
# Epoch 00090: val_loss did not improve from 0.10166
# 99/99 [==============================] - 2s 23ms/step - loss: 0.0527 - accuracy: 0.9819 - val_loss: 0.1155 - val_accuracy: 0.9601
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 480, 18)           126
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 160, 18)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 160, 58)           3190
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 53, 58)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 53, 58)            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 17)                5168
# _________________________________________________________________
# dense (Dense)                (None, 85)                1530
# _________________________________________________________________
# dense_1 (Dense)              (None, 19)                1634
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 20
# =================================================================
# Total params: 11,668
# Trainable params: 11,668
# Non-trainable params: 0
# _________________________________________________________________
# 33/33 - 0s - loss: 0.1017 - accuracy: 0.9639
# 27/27 - 0s - loss: 0.2138 - accuracy: 0.9206
# val_loss: 0.10165790468454361
# test_loss: 0.2137865573167801
# test_acc: 0.920616090297699
# precision: 0.8789473684210526
# recall: 0.7914691943127962
# specificity 0.9636650868878357
# sensitivity :  0.7914691943127962
# far 0.036334913112164295
# frr 0.20853080568720378
