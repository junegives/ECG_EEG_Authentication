# %%
# -*- coding: utf-8 -*-

import scipy.io
import numpy as np
import tensorflow as tf
import sklearn as sk
import matplotlib.pyplot as plt
import itertools
import random

from numba import cuda
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

from tensorflow.keras.callbacks import  EarlyStopping

# %%
# tensorflow = 2.
# python = 3.6


seed = np.random.seed(777)

gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
    
  try:
      
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
      
  except RuntimeError as e:
      
    print(e)


val_loss_all = []

test_loss_all = []
test_acc_all = []
test_pre_all = []
frr_all = []
far_all = []

conf_matrix_sco = []
test_pre_sco = []
test_rec_sco = []
test_spedi_sco = []
test_sensi_sco = []

class MyModelCheckpoint(tf.keras.callbacks.ModelCheckpoint):

    def __init__(self, *args, **kwargs):
        super(MyModelCheckpoint, self).__init__(*args, **kwargs)

    # redefine the save so it only activates after 100 epochs
    def on_epoch_end(self, epoch, logs=None):
        if epoch >= 1: super(MyModelCheckpoint, self).on_epoch_end(epoch, logs)

# %%
train_data = scipy.io.loadmat('../../datas/160hz/train_5day_160hz.mat', squeeze_me=True)['data']
test_data = scipy.io.loadmat('../../datas/160hz/test_6day_160hz(2).mat', squeeze_me=True)['data']

# sub 수
sub_cnt = train_data.shape[0]

# 3sec 데이터 크기
data_size = 480

# 1명당 3초 데이터 개수
train_data_cnt = 1052
test_data_cnt = 211

# 3sec 480(= 160*3) 크기로 데이터 길이 설정
train_cut_size = 504960 # 480*1052 = 504960
test_cut_size = 101280 # 480*211 = 101280

# 3sec 데이터 길이 자르기
# train: 504,960 / test: 101,280
train_data = train_data[:,0:train_cut_size,:]
test_data = test_data[:,0:test_cut_size,:]

# flatten(): 3D -> 1D / reshape(-1,1): -1 마지막 인덱스
train_flatten = train_data.flatten().reshape(-1,1)
test_flatten = test_data.flatten().reshape(-1,1)

# StandardScaler(): train에 맞춰 표준화
data_scaler = StandardScaler()
    
data_scaler.fit(train_flatten)
train_scaler = data_scaler.transform(train_flatten)
test_scaler = data_scaler.transform(test_flatten)
    
# train, test 데이터 reshape
train_data = train_scaler.reshape(train_data_cnt * sub_cnt, data_size, 2) 
test_data = test_scaler.reshape(test_data_cnt * sub_cnt, data_size, 2)

#train data를 sub:other=1:1로 만들기 위해서 각 sub 추출
train_data_each = []
for i in range(sub_cnt):
    train_data_each.insert(i, train_data[i*train_data_cnt:(i+1)*train_data_cnt, :, :])
print(np.shape(train_data_each))

#test data를 sub:other=1:3로 만들기 위해서 각 sub 추출
test_data_each = []
for i in range(sub_cnt):
    test_data_each.insert(i, test_data[i*test_data_cnt:(i+1)*test_data_cnt, :, :])
print(np.shape(test_data_each))
# Out:
# (11, 1052, 480, 2)
# (11, 211, 480, 2)

# %%
# sub number
sub_num = 8

#1 to 3 비율로 설정
ratio = 3

train_data_n = train_data_each[sub_num]
test_data_n = test_data_each[sub_num]

# train data를 sub:other = 1:3으로 만들기
# 3초 덩어리 개수 1052 : 3156
# => 315 * 4 + 316 * 6 = 1260 + 1896 = 3156

# test data를 sub:other = 1:3로 만들기
# 3초 덩어리 개수 211 : 633
# 63 * 7 + 64 * 3 = 633

cnt = 0
for j in range(sub_cnt):
    if j != sub_num and cnt < 4:
        cnt = cnt + 1
        train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 315)), axis = 0)
    elif j != sub_num and cnt >= 4:
        train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 316)), axis = 0)
#     print("train_data_n.shape")
#     print(train_data_n.shape)
#     print("train_data_n")
#     print(train_data_n)
        
cnt = 0
for j in range(sub_cnt):
    if j != sub_num and cnt < 7:
        cnt = cnt + 1
        test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 63)), axis = 0)
    elif j != sub_num and cnt >= 7:
        test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 64)), axis = 0)
        
        
        
train_label = np.zeros(train_data_cnt*(ratio+1))
test_label = np.zeros(test_data_cnt*(ratio+1))

for j in range(len(train_label)):
    if (j < train_data_cnt):
        train_label[j] = 1

for j in range(len(test_label)):
    if (j < test_data_cnt):
        test_label[j] = 1
        
train_data_shuffled, train_label_shuffled = sk.utils.shuffle(train_data_n, train_label, random_state = 0)

val_data_set = train_data_shuffled[:train_data_cnt]
train_data_set = train_data_shuffled[train_data_cnt:]

val_label_set = train_label_shuffled[:train_data_cnt]
train_label_set = train_label_shuffled[train_data_cnt:]

# %%
# model CNN-LSTM    
inputs = tf.keras.Input(shape = (480, 2))
conv_1 = tf.keras.layers.Conv1D(filters = 127, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(inputs)
max_1 = tf.keras.layers.MaxPool1D(3)(conv_1)
    
conv_2 = tf.keras.layers.Conv1D(filters = 20, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(max_1)
max_2 = tf.keras.layers.MaxPool1D(3)(conv_2)
    
# conv_3 = tf.keras.layers.Conv1D(filters = 47, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(max_2)
# max_3 = tf.keras.layers.MaxPool1D(3)(conv_3)
    

D_out_1 = tf.keras.layers.Dropout(0.7477320947302286)(max_2)
    
    
lstm_1 = tf.keras.layers.LSTM(107)(D_out_1)
    
dense_1 = tf.keras.layers.Dense(29, activation = 'relu')(lstm_1)
# dense_2 = tf.keras.layers.Dense(34, activation = 'relu')(dense_1)
# dense_3 = tf.keras.layers.Dense(55, activation = 'relu')(dense_2)
dense_4 = tf.keras.layers.Dense(1, activation = 'sigmoid')(dense_1)
    
model = tf.keras.models.Model(inputs = inputs, outputs = dense_4)

# Adam
model.compile(loss = 'binary_crossentropy', optimizer = tf.keras.optimizers.Adam(0.0005091769886330065), metrics = ['accuracy'])
# SGD
# model.compile(loss= 'binary_crossentropy', optimizer= tf.keras.optimizers.SGD(learning_rate=0.06347691327304918, momentum=0.027904272142875237), metrics=['accuracy'])
    
# EarlyStopping 조기종료 및 모델 학습
early_stopping = tf.keras.callbacks.EarlyStopping(patience = 20)
check_point = MyModelCheckpoint('best_model_' + str(sub_num + 1) + '.h5', monitor = 'val_loss', mode = 'min', save_best_only = True, verbose = 1)

# EarlyStopping 사용
hist = model.fit(train_data_set, train_label_set, epochs = 200, batch_size = 32, validation_data = (val_data_set, val_label_set), callbacks = [early_stopping, check_point])
# EarlyStopping 미사용
# hist = model.fit(train_data_set, train_label_set, epochs = 200, batch_size = 32, validation_data = (val_data_set, val_label_set), callbacks = [check_point])
        
# model save .h5형식
model = tf.keras.models.load_model('best_model_' + str(sub_num + 1) + '.h5')
model.save('Binary_BOHB_' + str(sub_num + 1) + '.h5')
model.summary() 
        
val_loss, val_acc = model.evaluate(val_data_set, val_label_set, verbose = 2)

test_loss, test_acc = model.evaluate(test_data_n, test_label, verbose = 2)
test_pred = model.predict(test_data_n)
        
    
# 각 행은 1sec, 0.5 <= 자신, 0.5 > 타인
for i in range(len(test_pred)):
    if(test_pred[i] >= 0.5):
        test_pred[i] = 1
    
    else: 
        test_pred[i] = 0
    
    
val_loss_all.append(val_loss)
    
test_loss_all.append(test_loss)
test_acc_all.append(test_acc)
test_pre_all.append(test_pred)
    

conf_matrix = confusion_matrix(test_label, test_pred) 
conf_matrix_sco.append(conf_matrix)
    
conf_row = conf_matrix.sum(axis = 1)
conf_col = conf_matrix.sum(axis = 0)

precision = conf_matrix[1][1] / conf_col[1]
recall = conf_matrix[1][1] / conf_row[1]
specificity = conf_matrix[0][0] / conf_row[0]
sensitivity = conf_matrix[1][1] / conf_row[1]
frr = conf_matrix[1][0] / (conf_matrix[1][1]+conf_matrix[1][0])
far = conf_matrix[0][1] / (conf_matrix[0][1]+conf_matrix[0][0])
    
frr_all.append(frr)
far_all.append(far)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111)

cax = ax.matshow(conf_matrix)

fig.colorbar(cax)

for i, j in itertools.product(range(conf_matrix.shape[0]), range(conf_matrix.shape[1])):
    plt.text(j, i, conf_matrix[i, j], color="white")

plt.title('CNN+LSTM model')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.show()
 
    
test_pre_sco.append(precision)
test_rec_sco.append(recall)
test_spedi_sco.append(specificity)
test_sensi_sco.append(sensitivity)
    
print('val_loss:', val_loss)
print('test_loss:', test_loss)
print('test_acc:', test_acc)
    
print('precision:', precision)
print('recall:', recall)
print('specificity', specificity)
print('sensitivity : ', sensitivity)
print('far', far)
print('frr', frr)
# Out:
# Epoch 1/200
# 99/99 [==============================] - 3s 34ms/step - loss: 0.5624 - accuracy: 0.7519 - val_loss: 0.5447 - val_accuracy: 0.7367
# Epoch 2/200
# 99/99 [==============================] - ETA: 0s - loss: 0.5157 - accuracy: 0.7646
# Epoch 00002: val_loss improved from inf to 0.48576, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.5157 - accuracy: 0.7646 - val_loss: 0.4858 - val_accuracy: 0.7776
# Epoch 3/200
# 99/99 [==============================] - ETA: 0s - loss: 0.4801 - accuracy: 0.7893
# Epoch 00003: val_loss improved from 0.48576 to 0.46776, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.4801 - accuracy: 0.7893 - val_loss: 0.4678 - val_accuracy: 0.7899
# Epoch 4/200
# 99/99 [==============================] - ETA: 0s - loss: 0.4567 - accuracy: 0.8070
# Epoch 00004: val_loss improved from 0.46776 to 0.43822, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 31ms/step - loss: 0.4567 - accuracy: 0.8070 - val_loss: 0.4382 - val_accuracy: 0.8042
# Epoch 5/200
# 99/99 [==============================] - ETA: 0s - loss: 0.4380 - accuracy: 0.8127
# Epoch 00005: val_loss improved from 0.43822 to 0.42831, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 31ms/step - loss: 0.4380 - accuracy: 0.8127 - val_loss: 0.4283 - val_accuracy: 0.8270
# Epoch 6/200
# 99/99 [==============================] - ETA: 0s - loss: 0.4165 - accuracy: 0.8200
# Epoch 00006: val_loss improved from 0.42831 to 0.40612, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.4165 - accuracy: 0.8200 - val_loss: 0.4061 - val_accuracy: 0.8232
# Epoch 7/200
# 99/99 [==============================] - ETA: 0s - loss: 0.4211 - accuracy: 0.8257
# Epoch 00007: val_loss improved from 0.40612 to 0.37271, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 31ms/step - loss: 0.4211 - accuracy: 0.8257 - val_loss: 0.3727 - val_accuracy: 0.8432
# Epoch 8/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3950 - accuracy: 0.8321
# Epoch 00008: val_loss improved from 0.37271 to 0.37176, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 31ms/step - loss: 0.3950 - accuracy: 0.8321 - val_loss: 0.3718 - val_accuracy: 0.8460
# Epoch 9/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3944 - accuracy: 0.8317
# Epoch 00009: val_loss did not improve from 0.37176
# 99/99 [==============================] - 3s 31ms/step - loss: 0.3944 - accuracy: 0.8317 - val_loss: 0.3868 - val_accuracy: 0.8394
# Epoch 10/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3869 - accuracy: 0.8378
# Epoch 00010: val_loss improved from 0.37176 to 0.33007, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 31ms/step - loss: 0.3869 - accuracy: 0.8378 - val_loss: 0.3301 - val_accuracy: 0.8641
# Epoch 11/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3840 - accuracy: 0.8352
# Epoch 00011: val_loss did not improve from 0.33007
# 99/99 [==============================] - 3s 31ms/step - loss: 0.3840 - accuracy: 0.8352 - val_loss: 0.3445 - val_accuracy: 0.8489
# Epoch 12/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3834 - accuracy: 0.8381
# Epoch 00012: val_loss did not improve from 0.33007
# 99/99 [==============================] - 3s 32ms/step - loss: 0.3834 - accuracy: 0.8381 - val_loss: 0.3645 - val_accuracy: 0.8327
# Epoch 13/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3791 - accuracy: 0.8371
# Epoch 00013: val_loss improved from 0.33007 to 0.31571, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.3791 - accuracy: 0.8371 - val_loss: 0.3157 - val_accuracy: 0.8641
# Epoch 14/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3620 - accuracy: 0.8533
# Epoch 00014: val_loss improved from 0.31571 to 0.31297, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 31ms/step - loss: 0.3620 - accuracy: 0.8533 - val_loss: 0.3130 - val_accuracy: 0.8707
# Epoch 15/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3525 - accuracy: 0.8530
# Epoch 00015: val_loss did not improve from 0.31297
# 99/99 [==============================] - 3s 31ms/step - loss: 0.3525 - accuracy: 0.8530 - val_loss: 0.3594 - val_accuracy: 0.8222
# Epoch 16/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3686 - accuracy: 0.8438
# Epoch 00016: val_loss did not improve from 0.31297
# 99/99 [==============================] - 3s 31ms/step - loss: 0.3686 - accuracy: 0.8438 - val_loss: 0.3441 - val_accuracy: 0.8441
# Epoch 17/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3526 - accuracy: 0.8485
# Epoch 00017: val_loss improved from 0.31297 to 0.29733, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.3526 - accuracy: 0.8485 - val_loss: 0.2973 - val_accuracy: 0.8774
# Epoch 18/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3528 - accuracy: 0.8485
# Epoch 00018: val_loss did not improve from 0.29733
# 99/99 [==============================] - 3s 31ms/step - loss: 0.3528 - accuracy: 0.8485 - val_loss: 0.2996 - val_accuracy: 0.8802
# Epoch 19/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3341 - accuracy: 0.8574
# Epoch 00019: val_loss did not improve from 0.29733
# 99/99 [==============================] - 3s 31ms/step - loss: 0.3341 - accuracy: 0.8574 - val_loss: 0.3464 - val_accuracy: 0.8394
# Epoch 20/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3393 - accuracy: 0.8555
# Epoch 00020: val_loss improved from 0.29733 to 0.28199, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.3393 - accuracy: 0.8555 - val_loss: 0.2820 - val_accuracy: 0.8812
# Epoch 21/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3362 - accuracy: 0.8558
# Epoch 00021: val_loss did not improve from 0.28199
# 99/99 [==============================] - 3s 31ms/step - loss: 0.3362 - accuracy: 0.8558 - val_loss: 0.3538 - val_accuracy: 0.8289
# Epoch 22/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3294 - accuracy: 0.8558
# Epoch 00022: val_loss did not improve from 0.28199
# 99/99 [==============================] - 3s 31ms/step - loss: 0.3294 - accuracy: 0.8558 - val_loss: 0.2997 - val_accuracy: 0.8736
# Epoch 23/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3253 - accuracy: 0.8552
# Epoch 00023: val_loss did not improve from 0.28199
# 99/99 [==============================] - 3s 31ms/step - loss: 0.3253 - accuracy: 0.8552 - val_loss: 0.2883 - val_accuracy: 0.8869
# Epoch 24/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3139 - accuracy: 0.8638
# Epoch 00024: val_loss improved from 0.28199 to 0.26138, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.3139 - accuracy: 0.8638 - val_loss: 0.2614 - val_accuracy: 0.8840
# Epoch 25/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3139 - accuracy: 0.8723
# Epoch 00025: val_loss did not improve from 0.26138
# 99/99 [==============================] - 3s 32ms/step - loss: 0.3139 - accuracy: 0.8723 - val_loss: 0.2973 - val_accuracy: 0.8717
# Epoch 26/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3085 - accuracy: 0.8685
# Epoch 00026: val_loss did not improve from 0.26138
# 99/99 [==============================] - 3s 32ms/step - loss: 0.3085 - accuracy: 0.8685 - val_loss: 0.2793 - val_accuracy: 0.8859
# Epoch 27/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2949 - accuracy: 0.8726
# Epoch 00027: val_loss did not improve from 0.26138
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2949 - accuracy: 0.8726 - val_loss: 0.3054 - val_accuracy: 0.8441
# Epoch 28/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3059 - accuracy: 0.8647
# Epoch 00028: val_loss did not improve from 0.26138
# 99/99 [==============================] - 3s 31ms/step - loss: 0.3059 - accuracy: 0.8647 - val_loss: 0.2632 - val_accuracy: 0.8888
# Epoch 29/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3093 - accuracy: 0.8676
# Epoch 00029: val_loss did not improve from 0.26138
# 99/99 [==============================] - 3s 31ms/step - loss: 0.3093 - accuracy: 0.8676 - val_loss: 0.2849 - val_accuracy: 0.8650
# Epoch 30/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3008 - accuracy: 0.8688
# Epoch 00030: val_loss did not improve from 0.26138
# 99/99 [==============================] - 3s 31ms/step - loss: 0.3008 - accuracy: 0.8688 - val_loss: 0.2647 - val_accuracy: 0.8850
# Epoch 31/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2982 - accuracy: 0.8707
# Epoch 00031: val_loss did not improve from 0.26138
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2982 - accuracy: 0.8707 - val_loss: 0.2632 - val_accuracy: 0.8888
# Epoch 32/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2932 - accuracy: 0.8736
# Epoch 00032: val_loss did not improve from 0.26138
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2932 - accuracy: 0.8736 - val_loss: 0.2746 - val_accuracy: 0.8764
# Epoch 33/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2973 - accuracy: 0.8691
# Epoch 00033: val_loss did not improve from 0.26138
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2973 - accuracy: 0.8691 - val_loss: 0.2746 - val_accuracy: 0.8736
# Epoch 34/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2980 - accuracy: 0.8720
# Epoch 00034: val_loss improved from 0.26138 to 0.24728, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2980 - accuracy: 0.8720 - val_loss: 0.2473 - val_accuracy: 0.9040
# Epoch 35/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2874 - accuracy: 0.8755
# Epoch 00035: val_loss did not improve from 0.24728
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2874 - accuracy: 0.8755 - val_loss: 0.2781 - val_accuracy: 0.8774
# Epoch 36/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2808 - accuracy: 0.8780
# Epoch 00036: val_loss did not improve from 0.24728
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2808 - accuracy: 0.8780 - val_loss: 0.2659 - val_accuracy: 0.8793
# Epoch 37/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2947 - accuracy: 0.8691
# Epoch 00037: val_loss did not improve from 0.24728
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2947 - accuracy: 0.8691 - val_loss: 0.2699 - val_accuracy: 0.8698
# Epoch 38/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2784 - accuracy: 0.8802
# Epoch 00038: val_loss improved from 0.24728 to 0.23737, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2784 - accuracy: 0.8802 - val_loss: 0.2374 - val_accuracy: 0.8992
# Epoch 39/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2887 - accuracy: 0.8733
# Epoch 00039: val_loss did not improve from 0.23737
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2887 - accuracy: 0.8733 - val_loss: 0.2448 - val_accuracy: 0.8983
# Epoch 40/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2856 - accuracy: 0.8758
# Epoch 00040: val_loss did not improve from 0.23737
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2856 - accuracy: 0.8758 - val_loss: 0.2585 - val_accuracy: 0.8907
# Epoch 41/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2875 - accuracy: 0.8726
# Epoch 00041: val_loss did not improve from 0.23737
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2875 - accuracy: 0.8726 - val_loss: 0.3066 - val_accuracy: 0.8612
# Epoch 42/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2809 - accuracy: 0.8783
# Epoch 00042: val_loss improved from 0.23737 to 0.23327, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2809 - accuracy: 0.8783 - val_loss: 0.2333 - val_accuracy: 0.9021
# Epoch 43/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2833 - accuracy: 0.8793
# Epoch 00043: val_loss did not improve from 0.23327
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2833 - accuracy: 0.8793 - val_loss: 0.2488 - val_accuracy: 0.8964
# Epoch 44/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2763 - accuracy: 0.8774
# Epoch 00044: val_loss did not improve from 0.23327
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2763 - accuracy: 0.8774 - val_loss: 0.2405 - val_accuracy: 0.8897
# Epoch 45/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2576 - accuracy: 0.8859
# Epoch 00045: val_loss did not improve from 0.23327
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2576 - accuracy: 0.8859 - val_loss: 0.2440 - val_accuracy: 0.9078
# Epoch 46/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2653 - accuracy: 0.8853
# Epoch 00046: val_loss did not improve from 0.23327
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2653 - accuracy: 0.8853 - val_loss: 0.2492 - val_accuracy: 0.8973
# Epoch 47/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2760 - accuracy: 0.8818
# Epoch 00047: val_loss did not improve from 0.23327
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2760 - accuracy: 0.8818 - val_loss: 0.2524 - val_accuracy: 0.8916
# Epoch 48/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2605 - accuracy: 0.8901
# Epoch 00048: val_loss did not improve from 0.23327
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2605 - accuracy: 0.8901 - val_loss: 0.2495 - val_accuracy: 0.8916
# Epoch 49/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2846 - accuracy: 0.8698
# Epoch 00049: val_loss did not improve from 0.23327
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2846 - accuracy: 0.8698 - val_loss: 0.2522 - val_accuracy: 0.8840
# Epoch 50/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2643 - accuracy: 0.8821
# Epoch 00050: val_loss did not improve from 0.23327
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2643 - accuracy: 0.8821 - val_loss: 0.2856 - val_accuracy: 0.8660
# Epoch 51/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.8891
# Epoch 00051: val_loss did not improve from 0.23327
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2663 - accuracy: 0.8891 - val_loss: 0.2773 - val_accuracy: 0.8717
# Epoch 52/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2634 - accuracy: 0.8866
# Epoch 00052: val_loss did not improve from 0.23327
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2634 - accuracy: 0.8866 - val_loss: 0.2583 - val_accuracy: 0.8916
# Epoch 53/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2700 - accuracy: 0.8881
# Epoch 00053: val_loss did not improve from 0.23327
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2700 - accuracy: 0.8881 - val_loss: 0.4166 - val_accuracy: 0.8222
# Epoch 54/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2851 - accuracy: 0.8729
# Epoch 00054: val_loss did not improve from 0.23327
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2851 - accuracy: 0.8729 - val_loss: 0.2855 - val_accuracy: 0.8831
# Epoch 55/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2607 - accuracy: 0.8939
# Epoch 00055: val_loss improved from 0.23327 to 0.22720, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2607 - accuracy: 0.8939 - val_loss: 0.2272 - val_accuracy: 0.9116
# Epoch 56/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2670 - accuracy: 0.8796
# Epoch 00056: val_loss did not improve from 0.22720
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2670 - accuracy: 0.8796 - val_loss: 0.2365 - val_accuracy: 0.8964
# Epoch 57/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2639 - accuracy: 0.8859
# Epoch 00057: val_loss did not improve from 0.22720
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2639 - accuracy: 0.8859 - val_loss: 0.2468 - val_accuracy: 0.9011
# Epoch 58/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2588 - accuracy: 0.8869
# Epoch 00058: val_loss did not improve from 0.22720
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2588 - accuracy: 0.8869 - val_loss: 0.2356 - val_accuracy: 0.9040
# Epoch 59/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2706 - accuracy: 0.8793
# Epoch 00059: val_loss did not improve from 0.22720
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2706 - accuracy: 0.8793 - val_loss: 0.2794 - val_accuracy: 0.8679
# Epoch 60/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2656 - accuracy: 0.8809
# Epoch 00060: val_loss did not improve from 0.22720
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2656 - accuracy: 0.8809 - val_loss: 0.2567 - val_accuracy: 0.8869
# Epoch 61/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2542 - accuracy: 0.8853
# Epoch 00061: val_loss did not improve from 0.22720
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2542 - accuracy: 0.8853 - val_loss: 0.2301 - val_accuracy: 0.9116
# Epoch 62/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2684 - accuracy: 0.8859
# Epoch 00062: val_loss did not improve from 0.22720
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2684 - accuracy: 0.8859 - val_loss: 0.2680 - val_accuracy: 0.8954
# Epoch 63/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2511 - accuracy: 0.8872
# Epoch 00063: val_loss did not improve from 0.22720
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2511 - accuracy: 0.8872 - val_loss: 0.2640 - val_accuracy: 0.8840
# Epoch 64/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2602 - accuracy: 0.8901
# Epoch 00064: val_loss did not improve from 0.22720
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2602 - accuracy: 0.8901 - val_loss: 0.2813 - val_accuracy: 0.8603
# Epoch 65/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2497 - accuracy: 0.8929
# Epoch 00065: val_loss improved from 0.22720 to 0.22604, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2497 - accuracy: 0.8929 - val_loss: 0.2260 - val_accuracy: 0.9106
# Epoch 66/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2505 - accuracy: 0.8897
# Epoch 00066: val_loss did not improve from 0.22604
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2505 - accuracy: 0.8897 - val_loss: 0.2563 - val_accuracy: 0.9011
# Epoch 67/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2595 - accuracy: 0.8881
# Epoch 00067: val_loss did not improve from 0.22604
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2595 - accuracy: 0.8881 - val_loss: 0.2705 - val_accuracy: 0.8745
# Epoch 68/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2594 - accuracy: 0.8856
# Epoch 00068: val_loss did not improve from 0.22604
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2594 - accuracy: 0.8856 - val_loss: 0.2267 - val_accuracy: 0.9049
# Epoch 69/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2516 - accuracy: 0.8897
# Epoch 00069: val_loss did not improve from 0.22604
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2516 - accuracy: 0.8897 - val_loss: 0.2440 - val_accuracy: 0.8945
# Epoch 70/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2551 - accuracy: 0.8859
# Epoch 00070: val_loss did not improve from 0.22604
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2551 - accuracy: 0.8859 - val_loss: 0.2342 - val_accuracy: 0.9059
# Epoch 71/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2603 - accuracy: 0.8856
# Epoch 00071: val_loss did not improve from 0.22604
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2603 - accuracy: 0.8856 - val_loss: 0.2463 - val_accuracy: 0.9030
# Epoch 72/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2468 - accuracy: 0.8964
# Epoch 00072: val_loss did not improve from 0.22604
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2468 - accuracy: 0.8964 - val_loss: 0.2472 - val_accuracy: 0.8983
# Epoch 73/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2473 - accuracy: 0.8897
# Epoch 00073: val_loss did not improve from 0.22604
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2473 - accuracy: 0.8897 - val_loss: 0.2308 - val_accuracy: 0.9059
# Epoch 74/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2463 - accuracy: 0.8901
# Epoch 00074: val_loss did not improve from 0.22604
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2463 - accuracy: 0.8901 - val_loss: 0.2504 - val_accuracy: 0.8888
# Epoch 75/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2479 - accuracy: 0.8945
# Epoch 00075: val_loss did not improve from 0.22604
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2479 - accuracy: 0.8945 - val_loss: 0.2478 - val_accuracy: 0.8859
# Epoch 76/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2465 - accuracy: 0.8954
# Epoch 00076: val_loss did not improve from 0.22604
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2465 - accuracy: 0.8954 - val_loss: 0.2478 - val_accuracy: 0.8850
# Epoch 77/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2514 - accuracy: 0.8881
# Epoch 00077: val_loss did not improve from 0.22604
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2514 - accuracy: 0.8881 - val_loss: 0.2473 - val_accuracy: 0.8992
# Epoch 78/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2439 - accuracy: 0.8961
# Epoch 00078: val_loss did not improve from 0.22604
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2439 - accuracy: 0.8961 - val_loss: 0.2466 - val_accuracy: 0.8926
# Epoch 79/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2442 - accuracy: 0.8945
# Epoch 00079: val_loss did not improve from 0.22604
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2442 - accuracy: 0.8945 - val_loss: 0.2892 - val_accuracy: 0.8660
# Epoch 80/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2343 - accuracy: 0.9059
# Epoch 00080: val_loss improved from 0.22604 to 0.22500, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2343 - accuracy: 0.9059 - val_loss: 0.2250 - val_accuracy: 0.9106
# Epoch 81/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2464 - accuracy: 0.8992
# Epoch 00081: val_loss did not improve from 0.22500
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2464 - accuracy: 0.8992 - val_loss: 0.2276 - val_accuracy: 0.9059
# Epoch 82/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2361 - accuracy: 0.8970
# Epoch 00082: val_loss did not improve from 0.22500
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2361 - accuracy: 0.8970 - val_loss: 0.2532 - val_accuracy: 0.8926
# Epoch 83/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2441 - accuracy: 0.8951
# Epoch 00083: val_loss improved from 0.22500 to 0.22350, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2441 - accuracy: 0.8951 - val_loss: 0.2235 - val_accuracy: 0.9135
# Epoch 84/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2340 - accuracy: 0.8989
# Epoch 00084: val_loss did not improve from 0.22350
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2340 - accuracy: 0.8989 - val_loss: 0.2613 - val_accuracy: 0.8840
# Epoch 85/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2590 - accuracy: 0.8916
# Epoch 00085: val_loss did not improve from 0.22350
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2590 - accuracy: 0.8916 - val_loss: 0.2932 - val_accuracy: 0.8650
# Epoch 86/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2385 - accuracy: 0.8989
# Epoch 00086: val_loss did not improve from 0.22350
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2385 - accuracy: 0.8989 - val_loss: 0.2313 - val_accuracy: 0.9068
# Epoch 87/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2390 - accuracy: 0.8961
# Epoch 00087: val_loss did not improve from 0.22350
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2390 - accuracy: 0.8961 - val_loss: 0.2500 - val_accuracy: 0.8878
# Epoch 88/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2458 - accuracy: 0.8961
# Epoch 00088: val_loss did not improve from 0.22350
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2458 - accuracy: 0.8961 - val_loss: 0.3011 - val_accuracy: 0.8517
# Epoch 89/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2460 - accuracy: 0.8970
# Epoch 00089: val_loss did not improve from 0.22350
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2460 - accuracy: 0.8970 - val_loss: 0.2561 - val_accuracy: 0.8945
# Epoch 90/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2413 - accuracy: 0.9002
# Epoch 00090: val_loss did not improve from 0.22350
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2413 - accuracy: 0.9002 - val_loss: 0.2513 - val_accuracy: 0.8964
# Epoch 91/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2425 - accuracy: 0.9008
# Epoch 00091: val_loss did not improve from 0.22350
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2425 - accuracy: 0.9008 - val_loss: 0.2331 - val_accuracy: 0.9011
# Epoch 92/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2348 - accuracy: 0.9005
# Epoch 00092: val_loss improved from 0.22350 to 0.22273, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2348 - accuracy: 0.9005 - val_loss: 0.2227 - val_accuracy: 0.9135
# Epoch 93/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2328 - accuracy: 0.8986
# Epoch 00093: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2328 - accuracy: 0.8986 - val_loss: 0.2430 - val_accuracy: 0.8992
# Epoch 94/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2348 - accuracy: 0.8999
# Epoch 00094: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2348 - accuracy: 0.8999 - val_loss: 0.2954 - val_accuracy: 0.8584
# Epoch 95/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2500 - accuracy: 0.8961
# Epoch 00095: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2500 - accuracy: 0.8961 - val_loss: 0.2356 - val_accuracy: 0.9087
# Epoch 96/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2412 - accuracy: 0.8945
# Epoch 00096: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2412 - accuracy: 0.8945 - val_loss: 0.2272 - val_accuracy: 0.9059
# Epoch 97/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2390 - accuracy: 0.8916
# Epoch 00097: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2390 - accuracy: 0.8916 - val_loss: 0.2293 - val_accuracy: 0.9097
# Epoch 98/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2297 - accuracy: 0.9030
# Epoch 00098: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2297 - accuracy: 0.9030 - val_loss: 0.2319 - val_accuracy: 0.9097
# Epoch 99/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2436 - accuracy: 0.8986
# Epoch 00099: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2436 - accuracy: 0.8986 - val_loss: 0.2472 - val_accuracy: 0.8954
# Epoch 100/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2444 - accuracy: 0.8973
# Epoch 00100: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2444 - accuracy: 0.8973 - val_loss: 0.2442 - val_accuracy: 0.8926
# Epoch 101/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2342 - accuracy: 0.8954
# Epoch 00101: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2342 - accuracy: 0.8954 - val_loss: 0.2299 - val_accuracy: 0.9011
# Epoch 102/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2348 - accuracy: 0.8996
# Epoch 00102: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2348 - accuracy: 0.8996 - val_loss: 0.2913 - val_accuracy: 0.8745
# Epoch 103/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2408 - accuracy: 0.8926
# Epoch 00103: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2408 - accuracy: 0.8926 - val_loss: 0.2333 - val_accuracy: 0.9068
# Epoch 104/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2329 - accuracy: 0.8964
# Epoch 00104: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2329 - accuracy: 0.8964 - val_loss: 0.2318 - val_accuracy: 0.9002
# Epoch 105/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2291 - accuracy: 0.9011
# Epoch 00105: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2291 - accuracy: 0.9011 - val_loss: 0.2657 - val_accuracy: 0.8964
# Epoch 106/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2297 - accuracy: 0.9011
# Epoch 00106: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2297 - accuracy: 0.9011 - val_loss: 0.3548 - val_accuracy: 0.8394
# Epoch 107/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2289 - accuracy: 0.9040
# Epoch 00107: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2289 - accuracy: 0.9040 - val_loss: 0.2538 - val_accuracy: 0.8935
# Epoch 108/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2270 - accuracy: 0.9046
# Epoch 00108: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2270 - accuracy: 0.9046 - val_loss: 0.2291 - val_accuracy: 0.9097
# Epoch 109/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2296 - accuracy: 0.9049
# Epoch 00109: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2296 - accuracy: 0.9049 - val_loss: 0.2538 - val_accuracy: 0.8973
# Epoch 110/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2192 - accuracy: 0.9027
# Epoch 00110: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2192 - accuracy: 0.9027 - val_loss: 0.3078 - val_accuracy: 0.8508
# Epoch 111/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2330 - accuracy: 0.8983
# Epoch 00111: val_loss did not improve from 0.22273
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2330 - accuracy: 0.8983 - val_loss: 0.2582 - val_accuracy: 0.9021
# Epoch 112/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2228 - accuracy: 0.9078
# Epoch 00112: val_loss improved from 0.22273 to 0.22014, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2228 - accuracy: 0.9078 - val_loss: 0.2201 - val_accuracy: 0.9135
# Epoch 113/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2264 - accuracy: 0.8948
# Epoch 00113: val_loss did not improve from 0.22014
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2264 - accuracy: 0.8948 - val_loss: 0.2459 - val_accuracy: 0.9011
# Epoch 114/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2233 - accuracy: 0.9053
# Epoch 00114: val_loss did not improve from 0.22014
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2233 - accuracy: 0.9053 - val_loss: 0.2222 - val_accuracy: 0.9125
# Epoch 115/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2286 - accuracy: 0.9002
# Epoch 00115: val_loss did not improve from 0.22014
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2286 - accuracy: 0.9002 - val_loss: 0.2985 - val_accuracy: 0.8555
# Epoch 116/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2318 - accuracy: 0.9008
# Epoch 00116: val_loss did not improve from 0.22014
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2318 - accuracy: 0.9008 - val_loss: 0.2246 - val_accuracy: 0.9087
# Epoch 117/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2274 - accuracy: 0.9078
# Epoch 00117: val_loss improved from 0.22014 to 0.21238, saving model to best_model_9.h5
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2274 - accuracy: 0.9078 - val_loss: 0.2124 - val_accuracy: 0.9202
# Epoch 118/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2240 - accuracy: 0.9075
# Epoch 00118: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 31ms/step - loss: 0.2240 - accuracy: 0.9075 - val_loss: 0.2325 - val_accuracy: 0.9059
# Epoch 119/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2296 - accuracy: 0.9091
# Epoch 00119: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2296 - accuracy: 0.9091 - val_loss: 0.2266 - val_accuracy: 0.9125
# Epoch 120/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2240 - accuracy: 0.9059
# Epoch 00120: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2240 - accuracy: 0.9059 - val_loss: 0.2327 - val_accuracy: 0.9040
# Epoch 121/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2097 - accuracy: 0.9072
# Epoch 00121: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2097 - accuracy: 0.9072 - val_loss: 0.2781 - val_accuracy: 0.8764
# Epoch 122/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2260 - accuracy: 0.9021
# Epoch 00122: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2260 - accuracy: 0.9021 - val_loss: 0.2759 - val_accuracy: 0.8821
# Epoch 123/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2336 - accuracy: 0.9008
# Epoch 00123: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2336 - accuracy: 0.9008 - val_loss: 0.2552 - val_accuracy: 0.8897
# Epoch 124/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2247 - accuracy: 0.9018
# Epoch 00124: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2247 - accuracy: 0.9018 - val_loss: 0.2312 - val_accuracy: 0.9087
# Epoch 125/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2346 - accuracy: 0.8977
# Epoch 00125: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2346 - accuracy: 0.8977 - val_loss: 0.2525 - val_accuracy: 0.8945
# Epoch 126/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2205 - accuracy: 0.9034
# Epoch 00126: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2205 - accuracy: 0.9034 - val_loss: 0.2326 - val_accuracy: 0.9068
# Epoch 127/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2037 - accuracy: 0.9151
# Epoch 00127: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2037 - accuracy: 0.9151 - val_loss: 0.2352 - val_accuracy: 0.9135
# Epoch 128/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2152 - accuracy: 0.9053
# Epoch 00128: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2152 - accuracy: 0.9053 - val_loss: 0.2712 - val_accuracy: 0.8869
# Epoch 129/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2224 - accuracy: 0.9084
# Epoch 00129: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2224 - accuracy: 0.9084 - val_loss: 0.2209 - val_accuracy: 0.9097
# Epoch 130/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2331 - accuracy: 0.9043
# Epoch 00130: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2331 - accuracy: 0.9043 - val_loss: 0.2333 - val_accuracy: 0.9154
# Epoch 131/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2178 - accuracy: 0.9043
# Epoch 00131: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2178 - accuracy: 0.9043 - val_loss: 0.2934 - val_accuracy: 0.8774
# Epoch 132/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2173 - accuracy: 0.9021
# Epoch 00132: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2173 - accuracy: 0.9021 - val_loss: 0.2816 - val_accuracy: 0.8812
# Epoch 133/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2222 - accuracy: 0.9106
# Epoch 00133: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2222 - accuracy: 0.9106 - val_loss: 0.2475 - val_accuracy: 0.8983
# Epoch 134/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2221 - accuracy: 0.9047
# Epoch 00134: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 33ms/step - loss: 0.2217 - accuracy: 0.9049 - val_loss: 0.2192 - val_accuracy: 0.9173
# Epoch 135/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2165 - accuracy: 0.9078
# Epoch 00135: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 33ms/step - loss: 0.2164 - accuracy: 0.9078 - val_loss: 0.2438 - val_accuracy: 0.9021
# Epoch 136/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2153 - accuracy: 0.9062
# Epoch 00136: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 33ms/step - loss: 0.2153 - accuracy: 0.9062 - val_loss: 0.2481 - val_accuracy: 0.8916
# Epoch 137/200
# 98/99 [============================>.] - ETA: 0s - loss: 0.2152 - accuracy: 0.9072
# Epoch 00137: val_loss did not improve from 0.21238
# 99/99 [==============================] - 3s 32ms/step - loss: 0.2160 - accuracy: 0.9065 - val_loss: 0.2367 - val_accuracy: 0.9049
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 480, 127)          889
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 160, 127)          0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 160, 20)           7640
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 53, 20)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 53, 20)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 107)               54784
# _________________________________________________________________
# dense_6 (Dense)              (None, 29)                3132
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 30
# =================================================================
# Total params: 66,475
# Trainable params: 66,475
# Non-trainable params: 0
# _________________________________________________________________
# 33/33 - 0s - loss: 0.2124 - accuracy: 0.9202
# 27/27 - 0s - loss: 0.1522 - accuracy: 0.9313
# val_loss: 0.21238261461257935
# test_loss: 0.15220099687576294
# test_acc: 0.9312795996665955
# precision: 0.834061135371179
# recall: 0.9052132701421801
# specificity 0.9399684044233807
# sensitivity :  0.9052132701421801
# far 0.06003159557661927
# frr 0.0947867298578199
