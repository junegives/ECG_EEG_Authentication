# %%
# -*- coding: utf-8 -*-

import scipy.io
import numpy as np
import tensorflow as tf
import sklearn as sk
import matplotlib.pyplot as plt
import itertools
import random

from numba import cuda
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

from tensorflow.keras.callbacks import  EarlyStopping

# %%
# tensorflow = 2.
# python = 3.6


seed = np.random.seed(777)

gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
    
  try:
      
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
      
  except RuntimeError as e:
      
    print(e)


val_loss_all = []

test_loss_all = []
test_acc_all = []
test_pre_all = []
frr_all = []
far_all = []

conf_matrix_sco = []
test_pre_sco = []
test_rec_sco = []
test_spedi_sco = []
test_sensi_sco = []

class MyModelCheckpoint(tf.keras.callbacks.ModelCheckpoint):

    def __init__(self, *args, **kwargs):
        super(MyModelCheckpoint, self).__init__(*args, **kwargs)

    # redefine the save so it only activates after 100 epochs
    def on_epoch_end(self, epoch, logs=None):
        if epoch >= 1: super(MyModelCheckpoint, self).on_epoch_end(epoch, logs)

# %%
train_data = scipy.io.loadmat('../../datas/160hz/train_5day_160hz.mat', squeeze_me=True)['data']
test_data = scipy.io.loadmat('../../datas/160hz/test_6day_160hz(2).mat', squeeze_me=True)['data']

# sub 수
sub_cnt = train_data.shape[0]

# 3sec 데이터 크기
data_size = 480

# 1명당 3초 데이터 개수
train_data_cnt = 1052
test_data_cnt = 211

# 3sec 480(= 160*3) 크기로 데이터 길이 설정
train_cut_size = 504960 # 480*1052 = 504960
test_cut_size = 101280 # 480*211 = 101280

# 3sec 데이터 길이 자르기
# train: 504,960 / test: 101,280
train_data = train_data[:,0:train_cut_size,:]
test_data = test_data[:,0:test_cut_size,:]

# flatten(): 3D -> 1D / reshape(-1,1): -1 마지막 인덱스
train_flatten = train_data.flatten().reshape(-1,1)
test_flatten = test_data.flatten().reshape(-1,1)

# StandardScaler(): train에 맞춰 표준화
data_scaler = StandardScaler()
    
data_scaler.fit(train_flatten)
train_scaler = data_scaler.transform(train_flatten)
test_scaler = data_scaler.transform(test_flatten)
    
# train, test 데이터 reshape
train_data = train_scaler.reshape(train_data_cnt * sub_cnt, data_size, 2) 
test_data = test_scaler.reshape(test_data_cnt * sub_cnt, data_size, 2)

#train data를 sub:other=1:1로 만들기 위해서 각 sub 추출
train_data_each = []
for i in range(sub_cnt):
    train_data_each.insert(i, train_data[i*train_data_cnt:(i+1)*train_data_cnt, :, :])
print(np.shape(train_data_each))

#test data를 sub:other=1:3로 만들기 위해서 각 sub 추출
test_data_each = []
for i in range(sub_cnt):
    test_data_each.insert(i, test_data[i*test_data_cnt:(i+1)*test_data_cnt, :, :])
print(np.shape(test_data_each))
# Out:
# (11, 1052, 480, 2)
# (11, 211, 480, 2)

# %%
# sub number
sub_num = 9

#1 to 3 비율로 설정
ratio = 3

train_data_n = train_data_each[sub_num]
test_data_n = test_data_each[sub_num]

# train data를 sub:other = 1:3으로 만들기
# 3초 덩어리 개수 1052 : 3156
# => 315 * 4 + 316 * 6 = 1260 + 1896 = 3156

# test data를 sub:other = 1:3로 만들기
# 3초 덩어리 개수 211 : 633
# 63 * 7 + 64 * 3 = 633

cnt = 0
for j in range(sub_cnt):
    if j != sub_num and cnt < 4:
        cnt = cnt + 1
        train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 315)), axis = 0)
    elif j != sub_num and cnt >= 4:
        train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 316)), axis = 0)
#     print("train_data_n.shape")
#     print(train_data_n.shape)
#     print("train_data_n")
#     print(train_data_n)
        
cnt = 0
for j in range(sub_cnt):
    if j != sub_num and cnt < 7:
        cnt = cnt + 1
        test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 63)), axis = 0)
    elif j != sub_num and cnt >= 7:
        test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 64)), axis = 0)
        
        
        
train_label = np.zeros(train_data_cnt*(ratio+1))
test_label = np.zeros(test_data_cnt*(ratio+1))

for j in range(len(train_label)):
    if (j < train_data_cnt):
        train_label[j] = 1

for j in range(len(test_label)):
    if (j < test_data_cnt):
        test_label[j] = 1
        
train_data_shuffled, train_label_shuffled = sk.utils.shuffle(train_data_n, train_label, random_state = 0)

val_data_set = train_data_shuffled[:train_data_cnt]
train_data_set = train_data_shuffled[train_data_cnt:]

val_label_set = train_label_shuffled[:train_data_cnt]
train_label_set = train_label_shuffled[train_data_cnt:]

# %%
# model CNN-LSTM    
inputs = tf.keras.Input(shape = (480, 2))
conv_1 = tf.keras.layers.Conv1D(filters = 6, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(inputs)
max_1 = tf.keras.layers.MaxPool1D(3)(conv_1)
    
# conv_2 = tf.keras.layers.Conv1D(filters = 57, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(max_1)
# max_2 = tf.keras.layers.MaxPool1D(3)(conv_2)
    
# conv_3 = tf.keras.layers.Conv1D(filters = 47, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(max_2)
# max_3 = tf.keras.layers.MaxPool1D(3)(conv_3)
    

D_out_1 = tf.keras.layers.Dropout(0.09862278733188111)(max_1)
    
    
lstm_1 = tf.keras.layers.LSTM(232)(D_out_1)
    
dense_1 = tf.keras.layers.Dense(27, activation = 'relu')(lstm_1)
dense_2 = tf.keras.layers.Dense(10, activation = 'relu')(dense_1)
dense_3 = tf.keras.layers.Dense(37, activation = 'relu')(dense_2)
dense_4 = tf.keras.layers.Dense(1, activation = 'sigmoid')(dense_3)
    
model = tf.keras.models.Model(inputs = inputs, outputs = dense_4)

# Adam
model.compile(loss = 'binary_crossentropy', optimizer = tf.keras.optimizers.Adam(0.0018588411375133871), metrics = ['accuracy'])
# SGD
# model.compile(loss= 'binary_crossentropy', optimizer= tf.keras.optimizers.SGD(learning_rate=0.0461300729767683, momentum=0.4411297369087802), metrics=['accuracy'])
    
# EarlyStopping 조기종료 및 모델 학습
early_stopping = tf.keras.callbacks.EarlyStopping(patience = 20)
check_point = MyModelCheckpoint('best_model_' + str(sub_num + 1) + '.h5', monitor = 'val_loss', mode = 'min', save_best_only = True, verbose = 1)

# EarlyStopping 사용
hist = model.fit(train_data_set, train_label_set, epochs = 200, batch_size = 32, validation_data = (val_data_set, val_label_set), callbacks = [early_stopping, check_point])
# EarlyStopping 미사용
# hist = model.fit(train_data_set, train_label_set, epochs = 200, batch_size = 32, validation_data = (val_data_set, val_label_set), callbacks = [check_point])
        
# model save .h5형식
model = tf.keras.models.load_model('best_model_' + str(sub_num + 1) + '.h5')
model.save('Binary_BOHB_' + str(sub_num + 1) + '.h5')
model.summary() 
        
val_loss, val_acc = model.evaluate(val_data_set, val_label_set, verbose = 2)

test_loss, test_acc = model.evaluate(test_data_n, test_label, verbose = 2)
test_pred = model.predict(test_data_n)
        
    
# 각 행은 1sec, 0.5 <= 자신, 0.5 > 타인
for i in range(len(test_pred)):
    if(test_pred[i] >= 0.5):
        test_pred[i] = 1
    
    else: 
        test_pred[i] = 0
    
    
val_loss_all.append(val_loss)
    
test_loss_all.append(test_loss)
test_acc_all.append(test_acc)
test_pre_all.append(test_pred)
    

conf_matrix = confusion_matrix(test_label, test_pred) 
conf_matrix_sco.append(conf_matrix)
    
conf_row = conf_matrix.sum(axis = 1)
conf_col = conf_matrix.sum(axis = 0)

precision = conf_matrix[1][1] / conf_col[1]
recall = conf_matrix[1][1] / conf_row[1]
specificity = conf_matrix[0][0] / conf_row[0]
sensitivity = conf_matrix[1][1] / conf_row[1]
frr = conf_matrix[1][0] / (conf_matrix[1][1]+conf_matrix[1][0])
far = conf_matrix[0][1] / (conf_matrix[0][1]+conf_matrix[0][0])
    
frr_all.append(frr)
far_all.append(far)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111)

cax = ax.matshow(conf_matrix)

fig.colorbar(cax)

for i, j in itertools.product(range(conf_matrix.shape[0]), range(conf_matrix.shape[1])):
    plt.text(j, i, conf_matrix[i, j], color="white")

plt.title('CNN+LSTM model')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.show()
 
    
test_pre_sco.append(precision)
test_rec_sco.append(recall)
test_spedi_sco.append(specificity)
test_sensi_sco.append(sensitivity)
    
print('val_loss:', val_loss)
print('test_loss:', test_loss)
print('test_acc:', test_acc)
    
print('precision:', precision)
print('recall:', recall)
print('specificity', specificity)
print('sensitivity : ', sensitivity)
print('far', far)
print('frr', frr)
# Out:
# Epoch 1/200
# 99/99 [==============================] - 13s 129ms/step - loss: 0.5653 - accuracy: 0.7516 - val_loss: 0.5594 - val_accuracy: 0.7367
# Epoch 2/200
# 99/99 [==============================] - ETA: 0s - loss: 0.5378 - accuracy: 0.7544
# Epoch 00002: val_loss improved from inf to 0.55816, saving model to best_model_10.h5
# 99/99 [==============================] - 13s 126ms/step - loss: 0.5378 - accuracy: 0.7544 - val_loss: 0.5582 - val_accuracy: 0.7367
# Epoch 3/200
# 99/99 [==============================] - ETA: 0s - loss: 0.5259 - accuracy: 0.7329
# Epoch 00003: val_loss did not improve from 0.55816
# 99/99 [==============================] - 12s 126ms/step - loss: 0.5259 - accuracy: 0.7329 - val_loss: 0.5705 - val_accuracy: 0.7367
# Epoch 4/200
# 99/99 [==============================] - ETA: 0s - loss: 0.5450 - accuracy: 0.7544
# Epoch 00004: val_loss improved from 0.55816 to 0.53573, saving model to best_model_10.h5
# 99/99 [==============================] - 13s 127ms/step - loss: 0.5450 - accuracy: 0.7544 - val_loss: 0.5357 - val_accuracy: 0.7367
# Epoch 5/200
# 99/99 [==============================] - ETA: 0s - loss: 0.4519 - accuracy: 0.7544
# Epoch 00005: val_loss improved from 0.53573 to 0.46068, saving model to best_model_10.h5
# 99/99 [==============================] - 13s 127ms/step - loss: 0.4519 - accuracy: 0.7544 - val_loss: 0.4607 - val_accuracy: 0.7367
# Epoch 6/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3861 - accuracy: 0.7684
# Epoch 00006: val_loss improved from 0.46068 to 0.43759, saving model to best_model_10.h5
# 99/99 [==============================] - 13s 127ms/step - loss: 0.3861 - accuracy: 0.7684 - val_loss: 0.4376 - val_accuracy: 0.7481
# Epoch 7/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3674 - accuracy: 0.8260
# Epoch 00007: val_loss improved from 0.43759 to 0.37958, saving model to best_model_10.h5
# 99/99 [==============================] - 13s 127ms/step - loss: 0.3674 - accuracy: 0.8260 - val_loss: 0.3796 - val_accuracy: 0.8175
# Epoch 8/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3354 - accuracy: 0.8416
# Epoch 00008: val_loss did not improve from 0.37958
# 99/99 [==============================] - 13s 126ms/step - loss: 0.3354 - accuracy: 0.8416 - val_loss: 0.4396 - val_accuracy: 0.8498
# Epoch 9/200
# 99/99 [==============================] - ETA: 0s - loss: 0.3040 - accuracy: 0.8676
# Epoch 00009: val_loss improved from 0.37958 to 0.28206, saving model to best_model_10.h5
# 99/99 [==============================] - 13s 126ms/step - loss: 0.3040 - accuracy: 0.8676 - val_loss: 0.2821 - val_accuracy: 0.8983
# Epoch 10/200
# 99/99 [==============================] - ETA: 0s - loss: 0.2596 - accuracy: 0.8942
# Epoch 00010: val_loss improved from 0.28206 to 0.22091, saving model to best_model_10.h5
# 99/99 [==============================] - 13s 126ms/step - loss: 0.2596 - accuracy: 0.8942 - val_loss: 0.2209 - val_accuracy: 0.9097
# Epoch 11/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1981 - accuracy: 0.9255
# Epoch 00011: val_loss improved from 0.22091 to 0.16642, saving model to best_model_10.h5
# 99/99 [==============================] - 13s 127ms/step - loss: 0.1981 - accuracy: 0.9255 - val_loss: 0.1664 - val_accuracy: 0.9411
# Epoch 12/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1533 - accuracy: 0.9430
# Epoch 00012: val_loss improved from 0.16642 to 0.11216, saving model to best_model_10.h5
# 99/99 [==============================] - 13s 127ms/step - loss: 0.1533 - accuracy: 0.9430 - val_loss: 0.1122 - val_accuracy: 0.9553
# Epoch 13/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1217 - accuracy: 0.9566
# Epoch 00013: val_loss improved from 0.11216 to 0.10470, saving model to best_model_10.h5
# 99/99 [==============================] - 13s 127ms/step - loss: 0.1217 - accuracy: 0.9566 - val_loss: 0.1047 - val_accuracy: 0.9658
# Epoch 14/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0963 - accuracy: 0.9658
# Epoch 00014: val_loss did not improve from 0.10470
# 99/99 [==============================] - 12s 126ms/step - loss: 0.0963 - accuracy: 0.9658 - val_loss: 0.1068 - val_accuracy: 0.9648
# Epoch 15/200
# 99/99 [==============================] - ETA: 0s - loss: 0.1209 - accuracy: 0.9588
# Epoch 00015: val_loss did not improve from 0.10470
# 99/99 [==============================] - 13s 126ms/step - loss: 0.1209 - accuracy: 0.9588 - val_loss: 0.1067 - val_accuracy: 0.9629
# Epoch 16/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0983 - accuracy: 0.9658
# Epoch 00016: val_loss improved from 0.10470 to 0.07934, saving model to best_model_10.h5
# 99/99 [==============================] - 12s 126ms/step - loss: 0.0983 - accuracy: 0.9658 - val_loss: 0.0793 - val_accuracy: 0.9705
# Epoch 17/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9715
# Epoch 00017: val_loss improved from 0.07934 to 0.07684, saving model to best_model_10.h5
# 99/99 [==============================] - 13s 127ms/step - loss: 0.0858 - accuracy: 0.9715 - val_loss: 0.0768 - val_accuracy: 0.9743
# Epoch 18/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0948 - accuracy: 0.9667
# Epoch 00018: val_loss did not improve from 0.07684
# 99/99 [==============================] - 13s 127ms/step - loss: 0.0948 - accuracy: 0.9667 - val_loss: 0.0796 - val_accuracy: 0.9753
# Epoch 19/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0860 - accuracy: 0.9667
# Epoch 00019: val_loss improved from 0.07684 to 0.07071, saving model to best_model_10.h5
# 99/99 [==============================] - 14s 140ms/step - loss: 0.0860 - accuracy: 0.9667 - val_loss: 0.0707 - val_accuracy: 0.9724
# Epoch 20/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.9712
# Epoch 00020: val_loss did not improve from 0.07071
# 99/99 [==============================] - 15s 147ms/step - loss: 0.0825 - accuracy: 0.9712 - val_loss: 0.0776 - val_accuracy: 0.9705
# Epoch 21/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0790 - accuracy: 0.9737
# Epoch 00021: val_loss did not improve from 0.07071
# 99/99 [==============================] - 14s 144ms/step - loss: 0.0790 - accuracy: 0.9737 - val_loss: 0.0808 - val_accuracy: 0.9715
# Epoch 22/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9689
# Epoch 00022: val_loss did not improve from 0.07071
# 99/99 [==============================] - 14s 145ms/step - loss: 0.0820 - accuracy: 0.9689 - val_loss: 0.1121 - val_accuracy: 0.9629
# Epoch 23/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0748 - accuracy: 0.9737
# Epoch 00023: val_loss improved from 0.07071 to 0.06366, saving model to best_model_10.h5
# 99/99 [==============================] - 14s 146ms/step - loss: 0.0748 - accuracy: 0.9737 - val_loss: 0.0637 - val_accuracy: 0.9753
# Epoch 24/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0769 - accuracy: 0.9756
# Epoch 00024: val_loss did not improve from 0.06366
# 99/99 [==============================] - 14s 145ms/step - loss: 0.0769 - accuracy: 0.9756 - val_loss: 0.1169 - val_accuracy: 0.9506
# Epoch 25/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0721 - accuracy: 0.9737
# Epoch 00025: val_loss did not improve from 0.06366
# 99/99 [==============================] - 14s 144ms/step - loss: 0.0721 - accuracy: 0.9737 - val_loss: 0.0685 - val_accuracy: 0.9705
# Epoch 26/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9775
# Epoch 00026: val_loss did not improve from 0.06366
# 99/99 [==============================] - 14s 145ms/step - loss: 0.0642 - accuracy: 0.9775 - val_loss: 0.0704 - val_accuracy: 0.9762
# Epoch 27/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.9778
# Epoch 00027: val_loss did not improve from 0.06366
# 99/99 [==============================] - 14s 146ms/step - loss: 0.0629 - accuracy: 0.9778 - val_loss: 0.0666 - val_accuracy: 0.9743
# Epoch 28/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0579 - accuracy: 0.9794
# Epoch 00028: val_loss did not improve from 0.06366
# 99/99 [==============================] - 15s 148ms/step - loss: 0.0579 - accuracy: 0.9794 - val_loss: 0.0886 - val_accuracy: 0.9743
# Epoch 29/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9794
# Epoch 00029: val_loss did not improve from 0.06366
# 99/99 [==============================] - 13s 128ms/step - loss: 0.0545 - accuracy: 0.9794 - val_loss: 0.0845 - val_accuracy: 0.9696
# Epoch 30/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9769
# Epoch 00030: val_loss improved from 0.06366 to 0.06204, saving model to best_model_10.h5
# 99/99 [==============================] - 12s 121ms/step - loss: 0.0621 - accuracy: 0.9769 - val_loss: 0.0620 - val_accuracy: 0.9800
# Epoch 31/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0510 - accuracy: 0.9816
# Epoch 00031: val_loss improved from 0.06204 to 0.05777, saving model to best_model_10.h5
# 99/99 [==============================] - 12s 121ms/step - loss: 0.0510 - accuracy: 0.9816 - val_loss: 0.0578 - val_accuracy: 0.9838
# Epoch 32/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0571 - accuracy: 0.9785
# Epoch 00032: val_loss improved from 0.05777 to 0.05541, saving model to best_model_10.h5
# 99/99 [==============================] - 12s 121ms/step - loss: 0.0571 - accuracy: 0.9785 - val_loss: 0.0554 - val_accuracy: 0.9800
# Epoch 33/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0529 - accuracy: 0.9794
# Epoch 00033: val_loss improved from 0.05541 to 0.05422, saving model to best_model_10.h5
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0529 - accuracy: 0.9794 - val_loss: 0.0542 - val_accuracy: 0.9781
# Epoch 34/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.9851
# Epoch 00034: val_loss did not improve from 0.05422
# 99/99 [==============================] - 12s 121ms/step - loss: 0.0419 - accuracy: 0.9851 - val_loss: 0.0602 - val_accuracy: 0.9829
# Epoch 35/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0498 - accuracy: 0.9819
# Epoch 00035: val_loss improved from 0.05422 to 0.04921, saving model to best_model_10.h5
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0498 - accuracy: 0.9819 - val_loss: 0.0492 - val_accuracy: 0.9819
# Epoch 36/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.9851
# Epoch 00036: val_loss did not improve from 0.04921
# 99/99 [==============================] - 12s 121ms/step - loss: 0.0419 - accuracy: 0.9851 - val_loss: 0.0789 - val_accuracy: 0.9734
# Epoch 37/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9823
# Epoch 00037: val_loss improved from 0.04921 to 0.04268, saving model to best_model_10.h5
# 99/99 [==============================] - 12s 120ms/step - loss: 0.0509 - accuracy: 0.9823 - val_loss: 0.0427 - val_accuracy: 0.9857
# Epoch 38/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9804
# Epoch 00038: val_loss did not improve from 0.04268
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0469 - accuracy: 0.9804 - val_loss: 0.0546 - val_accuracy: 0.9791
# Epoch 39/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0454 - accuracy: 0.9838
# Epoch 00039: val_loss did not improve from 0.04268
# 99/99 [==============================] - 12s 125ms/step - loss: 0.0454 - accuracy: 0.9838 - val_loss: 0.0528 - val_accuracy: 0.9829
# Epoch 40/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0383 - accuracy: 0.9870
# Epoch 00040: val_loss did not improve from 0.04268
# 99/99 [==============================] - 13s 128ms/step - loss: 0.0383 - accuracy: 0.9870 - val_loss: 0.0545 - val_accuracy: 0.9848
# Epoch 41/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0429 - accuracy: 0.9864
# Epoch 00041: val_loss did not improve from 0.04268
# 99/99 [==============================] - 13s 129ms/step - loss: 0.0429 - accuracy: 0.9864 - val_loss: 0.0509 - val_accuracy: 0.9848
# Epoch 42/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0481 - accuracy: 0.9851
# Epoch 00042: val_loss did not improve from 0.04268
# 99/99 [==============================] - 13s 128ms/step - loss: 0.0481 - accuracy: 0.9851 - val_loss: 0.0933 - val_accuracy: 0.9601
# Epoch 43/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9838
# Epoch 00043: val_loss did not improve from 0.04268
# 99/99 [==============================] - 13s 129ms/step - loss: 0.0409 - accuracy: 0.9838 - val_loss: 0.0740 - val_accuracy: 0.9791
# Epoch 44/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9832
# Epoch 00044: val_loss did not improve from 0.04268
# 99/99 [==============================] - 13s 129ms/step - loss: 0.0403 - accuracy: 0.9832 - val_loss: 0.0552 - val_accuracy: 0.9848
# Epoch 45/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9832
# Epoch 00045: val_loss did not improve from 0.04268
# 99/99 [==============================] - 13s 127ms/step - loss: 0.0480 - accuracy: 0.9832 - val_loss: 0.0521 - val_accuracy: 0.9829
# Epoch 46/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9819
# Epoch 00046: val_loss did not improve from 0.04268
# 99/99 [==============================] - 13s 128ms/step - loss: 0.0430 - accuracy: 0.9819 - val_loss: 0.0723 - val_accuracy: 0.9715
# Epoch 47/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9880
# Epoch 00047: val_loss did not improve from 0.04268
# 99/99 [==============================] - 13s 128ms/step - loss: 0.0348 - accuracy: 0.9880 - val_loss: 0.0704 - val_accuracy: 0.9810
# Epoch 48/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9857
# Epoch 00048: val_loss did not improve from 0.04268
# 99/99 [==============================] - 13s 128ms/step - loss: 0.0378 - accuracy: 0.9857 - val_loss: 0.0743 - val_accuracy: 0.9715
# Epoch 49/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9886
# Epoch 00049: val_loss did not improve from 0.04268
# 99/99 [==============================] - 13s 128ms/step - loss: 0.0311 - accuracy: 0.9886 - val_loss: 0.0681 - val_accuracy: 0.9781
# Epoch 50/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 0.9889
# Epoch 00050: val_loss did not improve from 0.04268
# 99/99 [==============================] - 13s 127ms/step - loss: 0.0333 - accuracy: 0.9889 - val_loss: 0.0844 - val_accuracy: 0.9753
# Epoch 51/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9864
# Epoch 00051: val_loss did not improve from 0.04268
# 99/99 [==============================] - 12s 125ms/step - loss: 0.0362 - accuracy: 0.9864 - val_loss: 0.0654 - val_accuracy: 0.9781
# Epoch 52/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0347 - accuracy: 0.9886
# Epoch 00052: val_loss did not improve from 0.04268
# 99/99 [==============================] - 12s 121ms/step - loss: 0.0347 - accuracy: 0.9886 - val_loss: 0.0465 - val_accuracy: 0.9829
# Epoch 53/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9861
# Epoch 00053: val_loss did not improve from 0.04268
# 99/99 [==============================] - 12s 121ms/step - loss: 0.0378 - accuracy: 0.9861 - val_loss: 0.0474 - val_accuracy: 0.9848
# Epoch 54/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9905
# Epoch 00054: val_loss did not improve from 0.04268
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0259 - accuracy: 0.9905 - val_loss: 0.0769 - val_accuracy: 0.9762
# Epoch 55/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9886
# Epoch 00055: val_loss did not improve from 0.04268
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0284 - accuracy: 0.9886 - val_loss: 0.0927 - val_accuracy: 0.9715
# Epoch 56/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9914
# Epoch 00056: val_loss improved from 0.04268 to 0.04133, saving model to best_model_10.h5
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0289 - accuracy: 0.9914 - val_loss: 0.0413 - val_accuracy: 0.9876
# Epoch 57/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0328 - accuracy: 0.9883
# Epoch 00057: val_loss improved from 0.04133 to 0.04032, saving model to best_model_10.h5
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0328 - accuracy: 0.9883 - val_loss: 0.0403 - val_accuracy: 0.9867
# Epoch 58/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9883
# Epoch 00058: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0241 - accuracy: 0.9883 - val_loss: 0.0507 - val_accuracy: 0.9857
# Epoch 59/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9899
# Epoch 00059: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0312 - accuracy: 0.9899 - val_loss: 0.0427 - val_accuracy: 0.9838
# Epoch 60/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9918
# Epoch 00060: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 121ms/step - loss: 0.0189 - accuracy: 0.9918 - val_loss: 0.0617 - val_accuracy: 0.9867
# Epoch 61/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.9892
# Epoch 00061: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 121ms/step - loss: 0.0322 - accuracy: 0.9892 - val_loss: 0.0669 - val_accuracy: 0.9800
# Epoch 62/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9911
# Epoch 00062: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0236 - accuracy: 0.9911 - val_loss: 0.0721 - val_accuracy: 0.9819
# Epoch 63/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9905
# Epoch 00063: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 121ms/step - loss: 0.0252 - accuracy: 0.9905 - val_loss: 0.0574 - val_accuracy: 0.9800
# Epoch 64/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9921
# Epoch 00064: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0214 - accuracy: 0.9921 - val_loss: 0.0638 - val_accuracy: 0.9829
# Epoch 65/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9918
# Epoch 00065: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0210 - accuracy: 0.9918 - val_loss: 0.0653 - val_accuracy: 0.9819
# Epoch 66/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9889
# Epoch 00066: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 121ms/step - loss: 0.0364 - accuracy: 0.9889 - val_loss: 0.0536 - val_accuracy: 0.9810
# Epoch 67/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9905
# Epoch 00067: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0205 - accuracy: 0.9905 - val_loss: 0.0836 - val_accuracy: 0.9772
# Epoch 68/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9902
# Epoch 00068: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0265 - accuracy: 0.9902 - val_loss: 0.0608 - val_accuracy: 0.9876
# Epoch 69/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9933
# Epoch 00069: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0201 - accuracy: 0.9933 - val_loss: 0.0803 - val_accuracy: 0.9800
# Epoch 70/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9933
# Epoch 00070: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 121ms/step - loss: 0.0174 - accuracy: 0.9933 - val_loss: 0.0844 - val_accuracy: 0.9762
# Epoch 71/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0271 - accuracy: 0.9899
# Epoch 00071: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0271 - accuracy: 0.9899 - val_loss: 0.0664 - val_accuracy: 0.9829
# Epoch 72/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9924
# Epoch 00072: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 121ms/step - loss: 0.0207 - accuracy: 0.9924 - val_loss: 0.0662 - val_accuracy: 0.9838
# Epoch 73/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0242 - accuracy: 0.9921
# Epoch 00073: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0242 - accuracy: 0.9921 - val_loss: 0.0664 - val_accuracy: 0.9810
# Epoch 74/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9930
# Epoch 00074: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 121ms/step - loss: 0.0213 - accuracy: 0.9930 - val_loss: 0.0651 - val_accuracy: 0.9857
# Epoch 75/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9952
# Epoch 00075: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0167 - accuracy: 0.9952 - val_loss: 0.0886 - val_accuracy: 0.9829
# Epoch 76/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9952
# Epoch 00076: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 121ms/step - loss: 0.0134 - accuracy: 0.9952 - val_loss: 0.0947 - val_accuracy: 0.9772
# Epoch 77/200
# 99/99 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9965
# Epoch 00077: val_loss did not improve from 0.04032
# 99/99 [==============================] - 12s 122ms/step - loss: 0.0127 - accuracy: 0.9965 - val_loss: 0.0741 - val_accuracy: 0.9800
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 480, 6)            42
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 160, 6)            0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 160, 6)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 232)               221792
# _________________________________________________________________
# dense_16 (Dense)             (None, 27)                6291
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                280
# _________________________________________________________________
# dense_18 (Dense)             (None, 37)                407
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 38
# =================================================================
# Total params: 228,850
# Trainable params: 228,850
# Non-trainable params: 0
# _________________________________________________________________
# 33/33 - 1s - loss: 0.0403 - accuracy: 0.9867
# 27/27 - 1s - loss: 0.0611 - accuracy: 0.9870
# val_loss: 0.040317222476005554
# test_loss: 0.061102647334337234
# test_acc: 0.9869668483734131
# precision: 0.9629629629629629
# recall: 0.985781990521327
# specificity 0.9873617693522907
# sensitivity :  0.985781990521327
# far 0.01263823064770932
# frr 0.014218009478672985
